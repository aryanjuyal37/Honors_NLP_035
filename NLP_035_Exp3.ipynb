# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data = pd.read_csv("/content/tweets.csv")
first_column = data.iloc[:, 0]
first_column = first_column.astype(str)
combined_text = " ".join(first_column)
tokens = [word for word in word_tokenize(combined_text) if word.isalpha()]
tokens = tokens[:5000]
print(tokens)
# Out:
# ['Feeling', 'thankful', 'Tag', 'friends', 'XboxSweepstakes', 'for', 'a', 'chance', 'to', 'win', 'M', 'digital', 'codes', 'Rules', 'http', 'Holiday', 'parties', 'are', 'the', 'worst', 'M', 'http', 'Now', 'through', 'Monday', 'enjoy', 'free', 'engraving', 'on', 'all', 'XboxDesignLab', 'controllers', 'Start', 'building', 'yours', 'at', 'http', 'Make', 'your', 'own', 'zombie', 'musical', 'number', 'inspired', 'by', 'M', 'http', 'This', 'Week', 'on', 'Xbox', 'FFXV', 'T', 'The', 'Division', 'M', 'Survival', 'and', 'Episode', 'of', 'telltalegames', 'Batman', 'M', 'http', 'Celebrate', 'woodyinho', 'jamesrodriguez', 'anthonymartial', 'in', 'the', 'E', 'free', 'trial', 'out', 'now', 'http', 'Sounds', 'like', 'Austin', 'is', 'a', 'pretty', 'good', 'player', 'huh', 'We', 'glad', 'you', 'had', 'a', 'successful', 'Black', 'Friday', 'What', 'games', 'did', 'you', 'get', 'Which', 'did', 'you', 'end', 'up', 'choosing', 'If', 'that', 'is', 'true', 'love', 'then', 'we', 'do', 'know', 'what', 'is', 'Which', 'bundle', 'did', 'you', 'get', 'him', 'Awesome', 'is', 'right', 'Did', 'you', 'end', 'up', 'getting', 'it', 'Those', 'are', 'the', 'best', 'What', 'you', 'playing', 'right', 'now', 'We', 'say', 'you', 'were', 'pretty', 'successful', 'We', 'love', 'that', 'idea', 'What', 'did', 'you', 'play', 'Welcome', 'to', 'the', 'Xbox', 'One', 'family', 'What', 'games', 'did', 'you', 'get', 'We', 'glad', 'you', 'could', 'take', 'advantage', 'of', 'this', 'great', 'deal', 'Which', 'will', 'you', 'play', 'first', 'We', 'like', 'the', 'way', 'you', 'think', 'Which', 'games', 'did', 'you', 'pick', 'We', 'love', 'to', 'hear', 'that', 'Do', 'you', 'think', 'you', 'replay', 'it', 'anytime', 'soon', 'We', 'know', 'what', 'that', 'like', 'You', 'get', 'home', 'and', 'game', 'yet', 'We', 'love', 'the', 'sound', 'of', 'that', 'Are', 'you', 'hoping', 'for', 'any', 'specific', 'bundles', 'We', 'ca', 'wait', 'either', 'When', 'do', 'you', 'plan', 'on', 'getting', 'one', 'Personalized', 'just', 'for', 'you', 'We', 'loving', 'this', 'design', 'Sounds', 'like', 'the', 'perfect', 'birthday', 'Which', 'games', 'did', 'you', 'end', 'up', 'getting', 'for', 'Black', 'Friday', 'Boom', 'That', 'going', 'to', 'keep', 'you', 'busy', 'Awesome', 'Sounds', 'like', 'a', 'pretty', 'good', 'Black', 'Friday', 'huh', 'Thanks', 'for', 'the', 'shoutout', 'Did', 'you', 'get', 'any', 'other', 'games', 'along', 'with', 'Fifa', 'Sometimes', 'it', 'good', 'to', 'upgrade', 'Is', 'this', 'all', 'you', 'got', 'for', 'your', 'gaming', 'set', 'up', 'Live', 'now', 'Tune', 'in', 'to', 'the', 'Gears', 'Pro', 'Circuit', 'Open', 'for', 'a', 'chance', 'to', 'win', 'an', 'XboxOneS', 'http', 'GearsofWar', 'M', 'Sounds', 'like', 'a', 'pretty', 'great', 'holiday', 'Did', 'you', 'get', 'a', 'specific', 'bundle', 'We', 'loving', 'the', 'color', 'scheme', 'You', 'take', 'it', 'for', 'a', 'spin', 'already', 'Sounds', 'like', 'your', 'Black', 'Friday', 'was', 'a', 'huge', 'success', 'That', 'a', 'very', 'good', 'way', 'to', 'celebrate', 'if', 'you', 'ask', 'us', 'You', 'better', 'believe', 'it', 'For', 'some', 'things', 'an', 'exception', 'must', 'be', 'made', 'Looks', 'like', 'you', 'made', 'the', 'most', 'of', 'Black', 'Friday', 'this', 'year', 'At', 'least', 'you', 'got', 'the', 'essentials', 'Technically', 'we', 'do', 'play', 'DVD', 'and', 'Blu', 'Rays', 'sounds', 'like', 'a', 'Looks', 'like', 'it', 'was', 'your', 'Destiny', 'to', 'get', 'great', 'deals', 'today', 'Sounds', 'like', 'a', 'very', 'successful', 'day', 'Sounds', 'like', 'it', 'was', 'a', 'good', 'day', 'We', 'loving', 'the', 'color', 'Browse', 'BlackFriday', 'deals', 'on', 'top', 'Xbox', 'games', 'like', 'Skyrim', 'Special', 'Edition', 'M', 'DOOM', 'M', 'and', 'more', 'http', 'Awesome', 'Trust', 'us', 'the', 'Horizon', 'Festival', 'just', 'keeps', 'getting', 'better', 'Get', 'the', 'undead', 'party', 'started', 'Check', 'out', 'the', 'M', 'lens', 'now', 'on', 'Snapchat', 'Sounds', 'like', 'it', 'gon', 'na', 'be', 'a', 'good', 'day', 'Feel', 'the', 'd ...

# %% [markdown]
# ## Porter Stemming

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for token in tokens:
  print(token,"--->", porter.stem(token))
# Out:
# Feeling ---> feel
# thankful ---> thank
# Tag ---> tag
# friends ---> friend
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# M ---> m
# digital ---> digit
# codes ---> code
# Rules ---> rule
# http ---> http
# Holiday ---> holiday
# parties ---> parti
# are ---> are
# the ---> the
# worst ---> worst
# M ---> m
# http ---> http
# Now ---> now
# through ---> through
# Monday ---> monday
# enjoy ---> enjoy
# free ---> free
# engraving ---> engrav
# on ---> on
# all ---> all
# XboxDesignLab ---> xboxdesignlab
# controllers ---> control
# Start ---> start
# building ---> build
# yours ---> your
# at ---> at
# http ---> http
# Make ---> make
# your ---> your
# own ---> own
# zombie ---> zombi
# musical ---> music
# number ---> number
# inspired ---> inspir
# by ---> by
# M ---> m
# http ---> http
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# FFXV ---> ffxv
# T ---> t
# The ---> the
# Division ---> divis
# M ---> m
# Survival ---> surviv
# and ---> and
# Episode ---> episod
# of ---> of
# telltalegames ---> telltalegam
# Batman ---> batman
# M ---> m
# http ---> http
# Celebrate ---> celebr
# woodyinho ---> woodyinho
# jamesrodriguez ---> jamesrodriguez
# anthonymartial ---> anthonymarti
# in ---> in
# the ---> the
# E ---> e
# free ---> free
# trial ---> trial
# out ---> out
# now ---> now
# http ---> http
# Sounds ---> sound
# like ---> like
# Austin ---> austin
# is ---> is
# a ---> a
# pretty ---> pretti
# good ---> good
# player ---> player
# huh ---> huh
# We ---> we
# glad ---> glad
# you ---> you
# had ---> had
# a ---> a
# successful ---> success
# Black ---> black
# Friday ---> friday
# What ---> what
# games ---> game
# did ---> did
# you ---> you
# get ---> get
# Which ---> which
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# choosing ---> choos
# If ---> if
# that ---> that
# is ---> is
# true ---> true
# love ---> love
# then ---> then
# we ---> we
# do ---> do
# know ---> know
# what ---> what
# is ---> is
# Which ---> which
# bundle ---> bundl
# did ---> did
# you ---> you
# get ---> get
# him ---> him
# Awesome ---> awesom
# is ---> is
# right ---> right
# Did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# it ---> it
# Those ---> those
# are ---> are
# the ---> the
# best ---> best
# What ---> what
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# We ---> we
# say ---> say
# you ---> you
# were ---> were
# pretty ---> pretti
# successful ---> success
# We ---> we
# love ---> love
# that ---> that
# idea ---> idea
# What ---> what
# did ---> did
# you ---> you
# play ---> play
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> one
# family ---> famili
# What ---> what
# games ---> game
# did ---> did
# you ---> you
# get ---> get
# We ---> we
# glad ---> glad
# you ---> you
# could ---> could
# take ---> take
# advantage ---> advantag
# of ---> of
# this ---> thi
# great ---> great
# deal ---> deal
# Which ---> which
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Which ---> which
# games ---> game
# did ---> did
# you ---> you
# pick ---> pick
# We ---> we
# love ---> love
# to ---> to
# hear ---> hear
# that ---> that
# Do ---> do
# you ---> you
# think ---> think
# you ---> you
# replay ---> replay
# it ---> it
# anytime ---> anytim
# soon ---> soon
# We ---> we
# know ---> know
# what ---> what
# that ---> that
# like ---> like
# You ---> you
# get ---> get
# home ---> home
# and ---> and
# game ---> game
# yet ---> yet
# We ---> we
# love ---> love
# the ---> the
# sound ---> sound
# of ---> of
# that ---> that
# Are ---> are
# you ---> you
# hoping ---> hope
# for ---> for
# any ---> ani
# specific ---> specif
# bundles ---> bundl
# We ---> we
# ca ---> ca
# wait ---> wait
# either ---> either
# When ---> when
# do ---> do
# you ---> you
# plan ---> plan
# on ---> on
# getting ---> get
# one ---> one
# Personalized ---> person
# just ---> just
# for ---> for
# you ---> you
# We ---> we
# loving ---> love
# this ---> thi
# design ---> design
# Sounds ---> sound
# like ---> like
# the ---> the
# perfect ---> perfect
# birthday ---> birthday
# Which ---> which
# games ---> game
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# for ---> for
# Black ---> black
# Friday ---> friday
# Boom ---> boom
# That ---> that
# going ---> go
# to ---> to
# keep ---> keep
# you ---> you
# busy ---> busi
# Awesome ---> awesom
# Sounds ---> sound
# like ---> like
# a ---> a
# pretty ---> pretti
# good ---> good
# Black ---> black
# Friday ---> friday
# huh ---> huh
# Thanks ---> thank
# for ---> for
# the ---> the
# shoutout ---> shoutout
# Did ---> did
# you ---> you
# get ---> get
# any ---> ani
# other ---> other
# games ---> game
# along ---> along
# with ---> with
# Fifa ---> fifa
# Sometimes ---> sometim
# it ---> it
# good ---> good
# to ---> to
# upgrade ---> upgrad
# Is ---> is
# this ---> thi
# all ---> all
# you ---> you
# got ---> got
# for ---> for
# your ---> your
# gaming ---> game
# set ---> set
# up ---> up
# Live ---> live
# now ---> now
# Tune ---> tune
# in ---> in
# to ---> to
# the ---> the
# Gears ---> gear
# Pro ---> pro
# Circuit ---> circuit
# Open ---> open
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# http ---> http
# GearsofWar ---> gearsofwar
# M ---> m
# Sounds ---> sound
# like ---> like
# a ---> a
# pretty ---> pretti
# great ---> great
# holiday ---> holiday
# Did ---> did
# you ---> you
# get ---> get
# a ---> a
# specific ---> specif
# bundle ---> bundl
# We ---> we
# loving ---> love
# the ---> the
# color ---> color
# scheme ---> scheme
# You ---> you
# take ---> take
# it ---> it
# for ---> for
# a ---> a
# spin ---> spin
# already ---> alreadi
# Sounds ---> sound
# like ---> like
# your ---> your
# Black ---> black
# Friday ---> friday
# was ---> wa
# a ---> a
# huge ---> huge
# success ---> success
# That ---> that
# a ---> a
# very ---> veri
# good ---> good
# way ---> way
# to ---> to
# celebrate ---> celebr
# if ---> if
# you ---> you
# ask ---> ask
# us ---> us
# You ---> you
# better ---> better
# believe ---> believ
# it ---> it
# For ---> for
# some ---> some
# things ---> thing
# an ---> an
# exception ---> except
# must ---> must
# be ---> be
# made ---> made
# Looks ---> look
# like ---> like
# you ---> you
# made ---> made
# the ---> the
# most ---> most
# of ---> of
# Black ---> black
# Friday ---> friday
# this ---> thi
# year ---> year
# At ---> at
# least ---> least
# you ---> you
# got ---> got
# the ---> the
# essentials ---> essenti
# Technically ---> technic
# we ---> we
# do ---> do
# play ---> play
# DVD ---> dvd
# and ---> and
# Blu ---> blu
# Rays ---> ray
# sounds ---> sound
# like ---> like
# a ---> a
# Looks ---> look
# like ---> like
# it ---> it
# was ---> wa
# your ---> your
# Destiny ---> destini
# to ---> to
# get ---> get
# great ---> great
# deals ---> deal
# today ---> today
# Sounds ---> sound
# like ---> like
# a ---> a
# very ---> veri
# successful ---> success
# day ---> day
# Sounds ---> sound
# like ---> like
# it ---> it
# was ---> wa
# a ---> a
# good ---> good
# day ---> day
# We ---> we
# loving ---> love
# the ---> the
# color ---> color
# Browse ---> brows
# BlackFriday ---> blackfriday
# deals ---> deal
# on ---> on
# top ---> top
# Xbox ---> xbox
# games ---> game
# like ---> like
# Skyrim ---> skyrim
# Special ---> special
# Edition ---> edit
# M ---> m
# DOOM ---> doom
# M ---> m
# and ---> and
# more ---> more
# http ---> http
# Awesome ---> awesom
# Trust ---> trust
# us ---> us
# the ---> the
# Horizon ---> horizon
# Festival ---> festiv
# just ---> just
# keeps ---> keep
# getting ---> get
# better ---> better
# Get ---> get
# the ---> the
# undead ---> undead
# party ---> parti
# started ---> start
# Check ---> check
# out ---> out
# the ---> the
# M ---> m
# lens ---> len
# now ---> now
# on ---> on
# Snapchat ---> snapchat
# Sounds ---> sound
# like ---> like
# it ---> it
# gon ---> gon
# na ---> na
# be ---> be
# a ---> a
# good ---> good
# day ---> day
# Feel ---> feel
# the ---> the
# difference ---> differ
# Pick ---> pick
# up ---> up
# the ---> the
# XboxElite ---> xboxelit
# at ---> at
# a ---> a
# MicrosoftStore ---> microsoftstor
# near ---> near
# you ---> you
# http ---> http
# Have ---> have
# fun ---> fun
# Holli ---> holli
# Epic ---> epic
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# fun ---> fun
# That ---> that
# makes ---> make
# you ---> you
# an ---> an
# awesome ---> awesom
# human ---> human
# being ---> be
# You ---> you
# know ---> know
# it ---> it
# What ---> what
# have ---> have
# you ---> you
# picked ---> pick
# up ---> up
# so ---> so
# far ---> far
# Woot ---> woot
# woot ---> woot
# Now ---> now
# that ---> that
# an ---> an
# awesome ---> awesom
# pick ---> pick
# up ---> up
# Grab ---> grab
# ahold ---> ahold
# of ---> of
# happiness ---> happi
# BlackFriday ---> blackfriday
# Get ---> get
# the ---> the
# XboxOneS ---> xboxon
# at ---> at
# our ---> our
# lowest ---> lowest
# price ---> price
# yet ---> yet
# Shop ---> shop
# the ---> the
# BlackFriday ---> blackfriday
# sale ---> sale
# at ---> at
# http ---> http
# Every ---> everi
# achievement ---> achiev
# is ---> is
# a ---> a
# tiny ---> tini
# parade ---> parad
# Celebrate ---> celebr
# yours ---> your
# this ---> thi
# Thanksgiving ---> thanksgiv
# Our ---> our
# gear ---> gear
# Your ---> your
# design ---> design
# Start ---> start
# building ---> build
# your ---> your
# Xbox ---> xbox
# controller ---> control
# at ---> at
# http ---> http
# XboxDesignLab ---> xboxdesignlab
# It ---> it
# just ---> just
# that ---> that
# many ---> mani
# more ---> more
# achievements ---> achiev
# for ---> for
# you ---> you
# to ---> to
# hunt ---> hunt
# XboxOne ---> xboxon
# The ---> the
# best ---> best
# controller ---> control
# make ---> make
# no ---> no
# XboxOne ---> xboxon
# Tag ---> tag
# friends ---> friend
# you ---> you
# thankful ---> thank
# for ---> for
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# digital ---> digit
# codes ---> code
# of ---> of
# M ---> m
# Rules ---> rule
# http ---> http
# Ooh ---> ooh
# that ---> that
# a ---> a
# tough ---> tough
# one ---> one
# At ---> at
# least ---> least
# it ---> it
# a ---> a
# choice ---> choic
# No ---> no
# sweat ---> sweat
# Have ---> have
# a ---> a
# blast ---> blast
# Anthony ---> anthoni
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> have
# so ---> so
# much ---> much
# fun ---> fun
# streaming ---> stream
# There ---> there
# absolutely ---> absolut
# is ---> is
# just ---> just
# follow ---> follow
# this ---> thi
# guide ---> guid
# UI ---> ui
# may ---> may
# differ ---> differ
# http ---> http
# It ---> it
# does ---> doe
# look ---> look
# amazing ---> amaz
# Good ---> good
# plan ---> plan
# Have ---> have
# fun ---> fun
# The ---> the
# only ---> onli
# people ---> peopl
# who ---> who
# should ---> should
# be ---> be
# alarmed ---> alarm
# are ---> are
# your ---> your
# opponents ---> oppon
# We ---> we
# sure ---> sure
# you ---> you
# can ---> can
# find ---> find
# time ---> time
# for ---> for
# both ---> both
# Cruise ---> cruis
# into ---> into
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# E ---> e
# now ---> now
# through ---> through
# November ---> novemb
# http ---> http
# Time ---> time
# to ---> to
# find ---> find
# some ---> some
# savings ---> save
# XboxOne ---> xboxon
# Join ---> join
# Clubs ---> club
# find ---> find
# players ---> player
# and ---> and
# download ---> download
# GamesWithGold ---> gameswithgold
# from ---> from
# your ---> your
# smartphone ---> smartphon
# with ---> with
# the ---> the
# Xbox ---> xbox
# app ---> app
# Download ---> download
# http ---> http
# Thanks ---> thank
# Brandon ---> brandon
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# The ---> the
# big ---> big
# question ---> question
# is ---> is
# which ---> which
# game ---> game
# will ---> will
# you ---> you
# be ---> be
# booting ---> boot
# up ---> up
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Looks ---> look
# like ---> like
# quite ---> quit
# the ---> the
# haul ---> haul
# We ---> we
# right ---> right
# there ---> there
# with ---> with
# you ---> you
# Save ---> save
# cash ---> cash
# Save ---> save
# Sera ---> sera
# M ---> m
# is ---> is
# on ---> on
# sale ---> sale
# now ---> now
# http ---> http
# BlackFriday ---> blackfriday
# How ---> how
# did ---> did
# it ---> it
# end ---> end
# up ---> up
# working ---> work
# out ---> out
# for ---> for
# you ---> you
# Emily ---> emili
# That ---> that
# the ---> the
# way ---> way
# to ---> to
# go ---> go
# Buy ---> buy
# digital ---> digit
# Play ---> play
# anywhere ---> anywher
# Learn ---> learn
# how ---> how
# at ---> at
# http ---> http
# XboxPlayAnywhere ---> xboxplayanywher
# Hard ---> hard
# weather ---> weather
# heads ---> head
# to ---> to
# New ---> new
# York ---> york
# with ---> with
# today ---> today
# release ---> releas
# of ---> of
# TheDivision ---> thedivis
# M ---> m
# Survival ---> surviv
# Get ---> get
# the ---> the
# new ---> new
# DLC ---> dlc
# at ---> at
# http ---> http
# Battlepacks ---> battlepack
# are ---> are
# now ---> now
# available ---> avail
# for ---> for
# purchase ---> purchas
# in ---> in
# Battlefield ---> battlefield
# M ---> m
# http ---> http
# Forge ---> forg
# an ---> an
# alliance ---> allianc
# with ---> with
# The ---> the
# Clown ---> clown
# Prince ---> princ
# of ---> of
# Crime ---> crime
# in ---> in
# BATMAN ---> batman
# The ---> the
# Telltale ---> telltal
# Series ---> seri
# M ---> m
# Episode ---> episod
# is ---> is
# out ---> out
# now ---> now
# http ---> http
# The ---> the
# only ---> onli
# question ---> question
# is ---> is
# which ---> which
# squad ---> squad
# member ---> member
# did ---> did
# you ---> you
# use ---> use
# for ---> for
# gaming ---> game
# today ---> today
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# be ---> be
# shouting ---> shout
# out ---> out
# a ---> a
# game ---> game
# that ---> that
# you ---> you
# worked ---> work
# on ---> on
# over ---> over
# our ---> our
# channels ---> channel
# Thanks ---> thank
# for ---> for
# awesome ---> awesom
# years ---> year
# Mason ---> mason
# Oh ---> oh
# no ---> no
# Guess ---> guess
# it ---> it
# the ---> the
# only ---> onli
# way ---> way
# to ---> to
# keep ---> keep
# both ---> both
# your ---> your
# mind ---> mind
# and ---> and
# your ---> your
# gaming ---> game
# skills ---> skill
# sharp ---> sharp
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# What ---> what
# game ---> game
# did ---> did
# you ---> you
# get ---> get
# it ---> it
# with ---> with
# Whoa ---> whoa
# Now ---> now
# those ---> those
# are ---> are
# some ---> some
# serious ---> seriou
# classics ---> classic
# Gear ---> gear
# up ---> up
# on ---> on
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# M ---> m
# available ---> avail
# now ---> now
# at ---> at
# http ---> http
# We ---> we
# could ---> could
# think ---> think
# of ---> of
# a ---> a
# better ---> better
# XboxOne ---> xboxon
# It ---> it
# coming ---> come
# together ---> togeth
# nicely ---> nice
# Thanks ---> thank
# for ---> for
# sharing ---> share
# the ---> the
# pic ---> pic
# Have ---> have
# a ---> a
# great ---> great
# week ---> week
# We ---> we
# looking ---> look
# forward ---> forward
# Xbox ---> xbox
# heavy ---> heavi
# holidays ---> holiday
# as ---> as
# well ---> well
# No ---> no
# arguments ---> argument
# here ---> here
# You ---> you
# should ---> should
# pick ---> pick
# it ---> it
# up ---> up
# Devin ---> devin
# That ---> that
# awesome ---> awesom
# We ---> we
# sure ---> sure
# it ---> it
# will ---> will
# make ---> make
# an ---> an
# amazing ---> amaz
# early ---> earli
# present ---> present
# We ---> we
# got ---> got
# to ---> to
# agree ---> agre
# with ---> with
# you ---> you
# there ---> there
# Hopefully ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Hello ---> hello
# there ---> there
# Oh ---> oh
# nice ---> nice
# That ---> that
# pretty ---> pretti
# creative ---> creativ
# We ---> we
# were ---> were
# always ---> alway
# fans ---> fan
# of ---> of
# their ---> their
# logo ---> logo
# There ---> there
# always ---> alway
# tomorrow ---> tomorrow
# and ---> and
# there ---> there
# ca ---> ca
# be ---> be
# an ---> an
# essay ---> essay
# every ---> everi
# day ---> day
# D ---> d
# Good ---> good
# plan ---> plan
# JJ ---> jj
# Pick ---> pick
# up ---> up
# some ---> some
# snacks ---> snack
# while ---> while
# you ---> you
# there ---> there
# We ---> we
# have ---> have
# http ---> http
# What ---> what
# better ---> better
# way ---> way
# to ---> to
# weather ---> weather
# winter ---> winter
# than ---> than
# with ---> with
# new ---> new
# GamesWithGold ---> gameswithgold
# Learn ---> learn
# more ---> more
# about ---> about
# December ---> decemb
# picks ---> pick
# at ---> at
# http ---> http
# Awesome ---> awesom
# work ---> work
# You ---> you
# know ---> know
# it ---> it
# You ---> you
# kept ---> kept
# it ---> it
# all ---> all
# this ---> thi
# time ---> time
# Now ---> now
# we ---> we
# blushing ---> blush
# There ---> there
# nothing ---> noth
# wrong ---> wrong
# with ---> with
# being ---> be
# an ---> an
# Xbox ---> xbox
# fan ---> fan
# Have ---> have
# fun ---> fun
# Awesome ---> awesom
# Have ---> have
# fun ---> fun
# with ---> with
# it ---> it
# when ---> when
# it ---> it
# arrives ---> arriv
# XboxOne ---> xboxon
# to ---> to
# Oculus ---> oculu
# streaming ---> stream
# arrives ---> arriv
# December ---> decemb
# with ---> with
# the ---> the
# XboxOne ---> xboxon
# Streaming ---> stream
# app ---> app
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# It ---> it
# definitely ---> definit
# worth ---> worth
# checking ---> check
# out ---> out
# Carlos ---> carlo
# Have ---> have
# fun ---> fun
# Thanks ---> thank
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chanc
# to ---> to
# play ---> play
# them ---> them
# all ---> all
# The ---> the
# best ---> best
# time ---> time
# of ---> of
# the ---> the
# day ---> day
# We ---> we
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Have ---> have
# fun ---> fun
# with ---> with
# them ---> them
# We ---> we
# wrapping ---> wrap
# up ---> up
# with ---> with
# a ---> a
# bang ---> bang
# D ---> d
# Burnout ---> burnout
# Paradise ---> paradis
# is ---> is
# now ---> now
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Get ---> get
# it ---> it
# free ---> free
# on ---> on
# GamesWithGold ---> gameswithgold
# http ---> http
# You ---> you
# did ---> did
# a ---> a
# good ---> good
# thing ---> thing
# It ---> it
# the ---> the
# little ---> littl
# things ---> thing
# right ---> right
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Dylan ---> dylan
# What ---> what
# an ---> an
# awesome ---> awesom
# gift ---> gift
# We ---> we
# sure ---> sure
# he ---> he
# love ---> love
# it ---> it
# We ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Josh ---> josh
# Sounds ---> sound
# like ---> like
# a ---> a
# relaxing ---> relax
# morning ---> morn
# to ---> to
# us ---> us
# It ---> it
# quite ---> quit
# beautiful ---> beauti
# is ---> is
# it ---> it
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# We ---> we
# appreciate ---> appreci
# it ---> it
# You ---> you
# sure ---> sure
# know ---> know
# how ---> how
# to ---> to
# spread ---> spread
# the ---> the
# love ---> love
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Ashley ---> ashley
# You ---> you
# got ---> got
# real ---> real
# good ---> good
# taste ---> tast
# in ---> in
# games ---> game
# That ---> that
# looks ---> look
# awesome ---> awesom
# How ---> how
# did ---> did
# you ---> you
# come ---> come
# up ---> up
# with ---> with
# red ---> red
# and ---> and
# blue ---> blue
# Timeless ---> timeless
# as ---> as
# always ---> alway
# We ---> we
# love ---> love
# it ---> it
# Thanks ---> thank
# for ---> for
# participating ---> particip
# Sylvia ---> sylvia
# Thanks ---> thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gamer
# Hunter ---> hunter
# You ---> you
# kept ---> kept
# the ---> the
# box ---> box
# How ---> how
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# celebrate ---> celebr
# BlackFriday ---> blackfriday
# is ---> is
# here ---> here
# Save ---> save
# up ---> up
# to ---> to
# on ---> on
# Xbox ---> xbox
# games ---> game
# and ---> and
# go ---> go
# Gold ---> gold
# to ---> to
# save ---> save
# up ---> up
# to ---> to
# more ---> more
# See ---> see
# the ---> the
# deals ---> deal
# http ---> http
# Thanks ---> thank
# We ---> we
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Thanks ---> thank
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# about ---> about
# to ---> to
# go ---> go
# down ---> down
# Woot ---> woot
# woot ---> woot
# Awesome ---> awesom
# deal ---> deal
# Oh ---> oh
# hey ---> hey
# Whaddup ---> whaddup
# Sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Which ---> which
# bundle ---> bundl
# do ---> do
# you ---> you
# have ---> have
# your ---> your
# eye ---> eye
# on ---> on
# Thanks ---> thank
# for ---> for
# the ---> the
# Dustin ---> dustin
# Glad ---> glad
# to ---> to
# see ---> see
# that ---> that
# we ---> we
# could ---> could
# help ---> help
# hook ---> hook
# you ---> you
# up ---> up
# Right ---> right
# What ---> what
# an ---> an
# awesome ---> awesom
# deal ---> deal
# Adam ---> adam
# speaks ---> speak
# the ---> the
# truth ---> truth
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# so ---> so
# hyped ---> hype
# that ---> that
# awesome ---> awesom
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> one
# family ---> famili
# Very ---> veri
# nice ---> nice
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# We ---> we
# be ---> be
# waiting ---> wait
# You ---> you
# got ---> got
# good ---> good
# taste ---> tast
# in ---> in
# games ---> game
# Be ---> be
# sure ---> sure
# to ---> to
# let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# The ---> the
# best ---> best
# kind ---> kind
# of ---> of
# break ---> break
# You ---> you
# know ---> know
# what ---> what
# up ---> up
# Matt ---> matt
# Sometimes ---> sometim
# it ---> it
# just ---> just
# takes ---> take
# a ---> a
# little ---> littl
# motivation ---> motiv
# It ---> it
# is ---> is
# not ---> not
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# managed ---> manag
# to ---> to
# make ---> make
# it ---> it
# Looking ---> look
# good ---> good
# It ---> it
# Gearing ---> gear
# up ---> up
# to ---> to
# be ---> be
# a ---> a
# great ---> great
# day ---> day
# Awesome ---> awesom
# The ---> the
# sign ---> sign
# of ---> of
# a ---> a
# great ---> great
# Pilot ---> pilot
# You ---> you
# doing ---> do
# great ---> great
# Angel ---> angel
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# No ---> no
# problem ---> problem
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Playing ---> play
# M ---> m
# Try ---> tri
# out ---> out
# these ---> these
# maps ---> map
# for ---> for
# your ---> your
# XboxElite ---> xboxelit
# http ---> http
# You ---> you
# got ---> got
# so ---> so
# much ---> much
# gaming ---> game
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# envious ---> enviou
# Have ---> have
# another ---> anoth
# great ---> great
# stream ---> stream
# Peter ---> peter
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# it ---> it
# This ---> thi
# is ---> is
# a ---> a
# great ---> great
# time ---> time
# to ---> to
# pick ---> pick
# both ---> both
# of ---> of
# them ---> them
# up ---> up
# http ---> http
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# loving ---> love
# it ---> it
# Alyssa ---> alyssa
# Pizza ---> pizza
# party ---> parti
# at ---> at
# your ---> your
# house ---> hous
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# liking ---> like
# it ---> it
# What ---> what
# clubs ---> club
# have ---> have
# you ---> you
# joined ---> join
# so ---> so
# far ---> far
# Do ---> do
# worry ---> worri
# we ---> we
# got ---> got
# your ---> your
# back ---> back
# We ---> we
# see ---> see
# you ---> you
# at ---> at
# the ---> the
# Horizon ---> horizon
# Festival ---> festiv
# Forza ---> forza
# Horizon ---> horizon
# is ---> is
# also ---> also
# available ---> avail
# for ---> for
# Windows ---> window
# Good ---> good
# luck ---> luck
# getting ---> get
# to ---> to
# the ---> the
# wave ---> wave
# We ---> we
# ca ---> ca
# argue ---> argu
# with ---> with
# that ---> that
# We ---> we
# loving ---> love
# it ---> it
# too ---> too
# Enter ---> enter
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# when ---> when
# you ---> you
# order ---> order
# a ---> a
# Triple ---> tripl
# Treat ---> treat
# Box ---> box
# from ---> from
# PizzaHut ---> pizzahut
# Offer ---> offer
# ends ---> end
# Rules ---> rule
# http ---> http
# Be ---> be
# sure ---> sure
# to ---> to
# report ---> report
# the ---> the
# account ---> account
# http ---> http
# Our ---> our
# condolences ---> condol
# But ---> but
# we ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# got ---> got
# some ---> some
# great ---> great
# memories ---> memori
# together ---> togeth
# on ---> on
# the ---> the
# Xbox ---> xbox
# Awesome ---> awesom
# article ---> articl
# Michael ---> michael
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# been ---> been
# with ---> with
# us ---> us
# since ---> sinc
# the ---> the
# very ---> veri
# beginning ---> begin
# From ---> from
# behind ---> behind
# Great ---> great
# clip ---> clip
# Awesome ---> awesom
# work ---> work
# We ---> we
# love ---> love
# chatting ---> chat
# with ---> with
# our ---> our
# awesome ---> awesom
# fans ---> fan
# Great ---> great
# choice ---> choic
# with ---> with
# Mafia ---> mafia
# III ---> iii
# Looking ---> look
# great ---> great
# so ---> so
# far ---> far
# What ---> what
# game ---> game
# have ---> have
# you ---> you
# played ---> play
# the ---> the
# most ---> most
# Smart ---> smart
# thinking ---> think
# Dessmond ---> dessmond
# Looking ---> look
# for ---> for
# a ---> a
# holiday ---> holiday
# escape ---> escap
# M ---> m
# today ---> today
# and ---> and
# play ---> play
# it ---> it
# December ---> decemb
# http ---> http
# Awesome ---> awesom
# Which ---> which
# game ---> game
# were ---> were
# you ---> you
# playing ---> play
# Watch ---> watch
# Lesnar ---> lesnar
# battle ---> battl
# Goldberg ---> goldberg
# live ---> live
# tonight ---> tonight
# at ---> at
# PM ---> pm
# PT ---> pt
# on ---> on
# the ---> the
# WWENetwork ---> wwenetwork
# app ---> app
# Learn ---> learn
# more ---> more
# http ---> http
# WWESurvivorSeries ---> wwesurvivorseri
# Catch ---> catch
# the ---> the
# final ---> final
# day ---> day
# of ---> of
# HCS ---> hc
# Las ---> la
# Vegas ---> vega
# live ---> live
# on ---> on
# Twitch ---> twitch
# Halo ---> halo
# top ---> top
# players ---> player
# are ---> are
# competing ---> compet
# now ---> now
# http ---> http
# Now ---> now
# through ---> through
# November ---> novemb
# save ---> save
# when ---> when
# you ---> you
# buy ---> buy
# any ---> ani
# XboxOneS ---> xboxon
# console ---> consol
# or ---> or
# console ---> consol
# bundle ---> bundl
# http ---> http
# Halos ---> halo
# and ---> and
# Death ---> death
# Stars ---> star
# superweapons ---> superweapon
# are ---> are
# your ---> your
# specialty ---> specialti
# Stream ---> stream
# movies ---> movi
# and ---> and
# TV ---> tv
# with ---> with
# the ---> the
# new ---> new
# FandangoNOW ---> fandangonow
# app ---> app
# plus ---> plu
# get ---> get
# off ---> off
# your ---> your
# first ---> first
# transaction ---> transact
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Watch ---> watch
# UFC ---> ufc
# Fight ---> fight
# Night ---> night
# Mousasi ---> mousasi
# vs ---> vs
# Hall ---> hall
# today ---> today
# on ---> on
# the ---> the
# Xbox ---> xbox
# UFC ---> ufc
# app ---> app
# Learn ---> learn
# more ---> more
# http ---> http
# MLG ---> mlg
# and ---> and
# GearsofWar ---> gearsofwar
# M ---> m
# are ---> are
# back ---> back
# together ---> togeth
# for ---> for
# the ---> the
# first ---> first
# Pro ---> pro
# Circuit ---> circuit
# in ---> in
# years ---> year
# Be ---> be
# there ---> there
# November ---> novemb
# Passes ---> pass
# http ---> http
# Stand ---> stand
# by ---> by
# for ---> for
# savings ---> save
# M ---> m
# is ---> is
# now ---> now
# off ---> off
# http ---> http
# We ---> we
# down ---> down
# with ---> with
# this ---> thi
# plan ---> plan
# Only ---> onli
# because ---> becaus
# of ---> of
# awesome ---> awesom
# fans ---> fan
# like ---> like
# you ---> you
# We ---> we
# love ---> love
# living ---> live
# in ---> in
# the ---> the
# future ---> futur
# Better ---> better
# catnip ---> catnip
# than ---> than
# something ---> someth
# like ---> like
# skooma ---> skooma
# Get ---> get
# days ---> day
# free ---> free
# of ---> of
# Sling ---> sling
# TV ---> tv
# exclusively ---> exclus
# on ---> on
# XboxOne ---> xboxon
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# You ---> you
# a ---> a
# five ---> five
# star ---> star
# fan ---> fan
# Sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Very ---> veri
# nice ---> nice
# Talk ---> talk
# about ---> about
# a ---> a
# classic ---> classic
# Play ---> play
# E ---> e
# free ---> free
# this ---> thi
# weekend ---> weekend
# with ---> with
# XboxLive ---> xboxliv
# Gold ---> gold
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# You ---> you
# got ---> got
# this ---> thi
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# That ---> that
# what ---> what
# up ---> up
# Looks ---> look
# like ---> like
# you ---> you
# got ---> got
# a ---> a
# ton ---> ton
# of ---> of
# awesome ---> awesom
# gaming ---> game
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Very ---> veri
# nice ---> nice
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# Thanks ---> thank
# so ---> so
# much ---> much
# Mark ---> mark
# Glad ---> glad
# we ---> we
# could ---> could
# hook ---> hook
# you ---> you
# up ---> up
# with ---> with
# so ---> so
# many ---> mani
# other ---> other
# awesome ---> awesom
# gamers ---> gamer
# This ---> thi
# weekend ---> weekend
# play ---> play
# Overwatch ---> overwatch
# T ---> t
# for ---> for
# free ---> free
# Start ---> start
# playing ---> play
# today ---> today
# on ---> on
# XboxOne ---> xboxon
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Thanks ---> thank
# for ---> for
# picking ---> pick
# up ---> up
# so ---> so
# many ---> mani
# cool ---> cool
# games ---> game
# Are ---> are
# you ---> you
# all ---> all
# set ---> set
# for ---> for
# the ---> the
# winter ---> winter
# It ---> it
# so ---> so
# hard ---> hard
# to ---> to
# narrow ---> narrow
# down ---> down
# that ---> that
# wish ---> wish
# list ---> list
# Have ---> have
# fun ---> fun
# with ---> with
# whatever ---> whatev
# you ---> you
# decide ---> decid
# to ---> to
# pick ---> pick
# up ---> up
# Scott ---> scott
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# join ---> join
# us ---> us
# for ---> for
# the ---> the
# release ---> releas
# of ---> of
# M ---> m
# and ---> and
# a ---> a
# look ---> look
# at ---> at
# BlackFriday ---> blackfriday
# http ---> http
# That ---> that
# what ---> what
# up ---> up
# What ---> what
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# your ---> your
# clips ---> clip
# That ---> that
# a ---> a
# good ---> good
# problem ---> problem
# to ---> to
# have ---> have
# in ---> in
# our ---> our
# opinions ---> opinion
# D ---> d
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# Here ---> here
# to ---> to
# many ---> mani
# more ---> more
# awesome ---> awesom
# gaming ---> game
# moments ---> moment
# in ---> in
# the ---> the
# future ---> futur
# This ---> thi
# holiday ---> holiday
# make ---> make
# it ---> it
# theirs ---> their
# with ---> with
# an ---> an
# XboxDesignLab ---> xboxdesignlab
# Digital ---> digit
# Code ---> code
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Cry ---> cri
# havoc ---> havoc
# and ---> and
# let ---> let
# slip ---> slip
# the ---> the
# huskies ---> huski
# of ---> of
# war ---> war
# Go ---> go
# Gold ---> gold
# for ---> for
# and ---> and
# enjoy ---> enjoy
# early ---> earli
# access ---> access
# to ---> to
# this ---> thi
# year ---> year
# Xbox ---> xbox
# BlackFriday ---> blackfriday
# savings ---> save
# Learn ---> learn
# more ---> more
# http ---> http
# Looks ---> look
# like ---> like
# Player ---> player
# has ---> ha
# entered ---> enter
# the ---> the
# game ---> game
# We ---> we
# got ---> got
# some ---> some
# extra ---> extra
# deals ---> deal
# coming ---> come
# up ---> up
# next ---> next
# weekend ---> weekend
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# that ---> that
# it ---> it
# such ---> such
# a ---> a
# vivid ---> vivid
# memory ---> memori
# No ---> no
# problem ---> problem
# Everyone ---> everyon
# getting ---> get
# excited ---> excit
# for ---> for
# it ---> it
# Design ---> design
# share ---> share
# and ---> and
# tag ---> tag
# a ---> a
# controller ---> control
# with ---> with
# XboxDesignLab ---> xboxdesignlab
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# Rules ---> rule
# http ---> http
# So ---> so
# fresh ---> fresh
# and ---> and
# so ---> so
# clean ---> clean
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Joe ---> joe
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# Hopefully ---> hope
# you ---> you
# get ---> get
# some ---> some
# epic ---> epic
# games ---> game
# with ---> with
# the ---> the
# club ---> club
# Got ---> got
# ta ---> ta
# rep ---> rep
# the ---> the
# Ravens ---> raven
# Flock ---> flock
# right ---> right
# Awesome ---> awesom
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# Lindsey ---> lindsey
# Wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Shawn ---> shawn
# Nice ---> nice
# What ---> what
# do ---> do
# you ---> you
# think ---> think
# of ---> of
# it ---> it
# so ---> so
# far ---> far
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Drew ---> drew
# It ---> it
# for ---> for
# project ---> project
# Scorpio ---> scorpio
# They ---> they
# tell ---> tell
# stories ---> stori
# of ---> of
# your ---> your
# time ---> time
# in ---> in
# Tamriel ---> tamriel
# We ---> we
# already ---> alreadi
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Thanks ---> thank
# so ---> so
# much ---> much
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# all ---> all
# the ---> the
# awesome ---> awesom
# stuff ---> stuff
# ahead ---> ahead
# Great ---> great
# work ---> work
# The ---> the
# gun ---> gun
# looks ---> look
# awesome ---> awesom
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# all ---> all
# set ---> set
# to ---> to
# go ---> go
# Have ---> have
# fun ---> fun
# We ---> we
# hope ---> hope
# to ---> to
# see ---> see
# you ---> you
# soon ---> soon
# Andrew ---> andrew
# We ---> we
# wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# You ---> you
# have ---> have
# great ---> great
# taste ---> tast
# in ---> in
# games ---> game
# RT ---> rt
# now ---> now
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# M ---> m
# bundle ---> bundl
# Sweepstakes ---> sweepstak
# Rules ---> rule
# http ---> http
# Let ---> let
# just ---> just
# assume ---> assum
# it ---> it
# all ---> all
# the ---> the
# clips ---> clip
# Awesome ---> awesom
# work ---> work
# Thanks ---> thank
# Joe ---> joe
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Sounds ---> sound
# like ---> like
# you ---> you
# on ---> on
# your ---> your
# way ---> way
# to ---> to
# your ---> your
# dream ---> dream
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# There ---> there
# no ---> no
# words ---> word
# that ---> that
# could ---> could
# describe ---> describ
# our ---> our
# love ---> love
# Good ---> good
# plan ---> plan
# Briana ---> briana
# What ---> what
# are ---> are
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# And ---> and
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Haden ---> haden
# Very ---> veri
# nice ---> nice
# Here ---> here
# to ---> to
# many ---> mani
# more ---> more
# rare ---> rare
# achievements ---> achiev
# in ---> in
# the ---> the
# future ---> futur
# Awesome ---> awesom
# Which ---> which
# achievement ---> achiev
# was ---> wa
# it ---> it
# Sounds ---> sound
# like ---> like
# it ---> it
# about ---> about
# to ---> to
# be ---> be
# an ---> an
# awesome ---> awesom
# birthday ---> birthday
# We ---> we
# glad ---> glad
# you ---> you
# loving ---> love
# it ---> it
# Joey ---> joey
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# It ---> it
# still ---> still
# as ---> as
# beautiful ---> beauti
# as ---> as
# ever ---> ever
# Sounds ---> sound
# like ---> like
# a ---> a
# good ---> good
# day ---> day
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# We ---> we
# hear ---> hear
# that ---> that
# At ---> at
# least ---> least
# we ---> we
# on ---> on
# the ---> the
# home ---> home
# stretch ---> stretch
# You ---> you
# ca ---> ca
# help ---> help
# but ---> but
# be ---> be
# holly ---> holli
# and ---> and
# jolly ---> jolli
# Congrats ---> congrat
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# play ---> play
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> have
# so ---> so
# much ---> much
# fun ---> fun
# You ---> you
# still ---> still
# got ---> got
# great ---> great
# skills ---> skill
# Dylan ---> dylan
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# still ---> still
# finding ---> find
# some ---> some
# play ---> play
# time ---> time
# Emmarie ---> emmari
# We ---> we
# love ---> love
# that ---> that
# series ---> seri
# That ---> that
# sounds ---> sound
# like ---> like
# a ---> a
# great ---> great
# idea ---> idea
# to ---> to
# us ---> us
# Sometimes ---> sometim
# you ---> you
# just ---> just
# got ---> got
# to ---> to
# play ---> play
# You ---> you
# got ---> got
# this ---> thi
# There ---> there
# plenty ---> plenti
# of ---> of
# great ---> great
# games ---> game
# ahead ---> ahead
# to ---> to
# help ---> help
# you ---> you
# out ---> out
# It ---> it
# sure ---> sure
# does ---> doe
# Fans ---> fan
# like ---> like
# you ---> you
# are ---> are
# why ---> whi
# we ---> we
# do ---> do
# what ---> what
# we ---> we
# do ---> do
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Nice ---> nice
# What ---> what
# was ---> wa
# your ---> your
# favorite ---> favorit
# game ---> game
# to ---> to
# play ---> play
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# BlackFriday ---> blackfriday
# deals ---> deal
# are ---> are
# coming ---> come
# soon ---> soon
# Get ---> get
# early ---> earli
# access ---> access
# with ---> with
# XboxLive ---> xboxliv
# Gold ---> gold
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Good ---> good
# luck ---> luck
# with ---> with
# your ---> your
# new ---> new
# club ---> club
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# Have ---> have
# fun ---> fun
# with ---> with
# the ---> the
# new ---> new
# features ---> featur
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# Unlock ---> unlock
# the ---> the
# true ---> true
# colors ---> color
# of ---> of
# your ---> your
# games ---> game
# and ---> and
# entertainment ---> entertain
# with ---> with
# HDR ---> hdr
# http ---> http
# XboxOneS ---> xboxon
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# share ---> share
# the ---> the
# next ---> next
# years ---> year
# Great ---> great
# clip ---> clip
# Nice ---> nice
# shot ---> shot
# It ---> it
# definitely ---> definit
# worth ---> worth
# writing ---> write
# home ---> home
# about ---> about
# Now ---> now
# that ---> that
# one ---> one
# look ---> look
# you ---> you
# can ---> can
# never ---> never
# outgrow ---> outgrow
# Have ---> have
# fun ---> fun
# Commander ---> command
# That ---> that
# the ---> the
# plan ---> plan
# Ryan ---> ryan
# That ---> that
# must ---> must
# been ---> been
# a ---> a
# very ---> veri
# happy ---> happi
# Christmas ---> christma
# day ---> day
# Making ---> make
# great ---> great
# friends ---> friend
# online ---> onlin
# is ---> is
# definitely ---> definit
# our ---> our
# favorite ---> favorit
# feature ---> featur
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# Scorpio ---> scorpio
# either ---> either
# Thanks ---> thank
# for ---> for
# sharing ---> share
# your ---> your
# pride ---> pride
# Thanks ---> thank
# for ---> for
# the ---> the
# birthday ---> birthday
# wishes ---> wish
# Mark ---> mark
# We ---> we
# just ---> just
# getting ---> get
# started ---> start
# It ---> it
# never ---> never
# too ---> too
# late ---> late
# We ---> we
# glad ---> glad
# to ---> to
# have ---> have
# you ---> you
# with ---> with
# us ---> us
# Xbox ---> xbox
# fans ---> fan
# can ---> can
# be ---> be
# any ---> ani
# age ---> age
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# so ---> so
# long ---> long
# Thanks ---> thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# fan ---> fan
# We ---> we
# love ---> love
# you ---> you
# too ---> too
# Thanks ---> thank
# Eric ---> eric
# Game ---> game
# on ---> on
# Sounds ---> sound
# like ---> like
# an ---> an
# awesome ---> awesom
# club ---> club
# That ---> that
# was ---> wa
# an ---> an
# epic ---> epic
# console ---> consol
# too ---> too
# Game ---> game
# on ---> on
# Welcome ---> welcom
# back ---> back
# Glad ---> glad
# that ---> that
# it ---> it
# held ---> held
# such ---> such
# an ---> an
# important ---> import
# place ---> place
# in ---> in
# your ---> your
# life ---> life
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Aww ---> aww
# thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# What ---> what
# an ---> an
# awesome ---> awesom
# family ---> famili
# portrait ---> portrait
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Blood ---> blood
# Dragon ---> dragon
# M ---> m
# and ---> and
# Murdered ---> murder
# Soul ---> soul
# Suspect ---> suspect
# M ---> m
# are ---> are
# now ---> now
# on ---> on
# GamesWithGold ---> gameswithgold
# Start ---> start
# playing ---> play
# today ---> today
# http ---> http
# Nice ---> nice
# to ---> to
# hear ---> hear
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# That ---> that
# awesome ---> awesom
# Travis ---> travi
# Sounds ---> sound
# like ---> like
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# quite ---> quit
# some ---> some
# time ---> time
# Thanks ---> thank
# for ---> for
# all ---> all
# the ---> the
# awesome ---> awesom
# years ---> year
# of ---> of
# gaming ---> game
# with ---> with
# us ---> us
# And ---> and
# that ---> that
# you ---> you
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesom
# gamer ---> gamer
# and ---> and
# fan ---> fan
# Canvas ---> canva
# does ---> doe
# matter ---> matter
# without ---> without
# artists ---> artist
# like ---> like
# yourself ---> yourself
# Thanks ---> thank
# for ---> for
# all ---> all
# your ---> your
# awesome ---> awesom
# work ---> work
# You ---> you
# very ---> veri
# welcome ---> welcom
# Have ---> have
# you ---> you
# set ---> set
# up ---> up
# your ---> your
# own ---> own
# yet ---> yet
# Or ---> or
# have ---> have
# you ---> you
# found ---> found
# some ---> some
# fun ---> fun
# ones ---> one
# to ---> to
# join ---> join
# Thanks ---> thank
# much ---> much
# We ---> we
# so ---> so
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Aditya ---> aditya
# It ---> it
# been ---> been
# a ---> a
# wild ---> wild
# ride ---> ride
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# The ---> the
# future ---> futur
# is ---> is
# bright ---> bright
# Ben ---> ben
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# this ---> thi
# time ---> time
# Thanks ---> thank
# so ---> so
# much ---> much
# Jeff ---> jeff
# And ---> and
# thank ---> thank
# you ---> you
# Nathan ---> nathan
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# gamer ---> gamer
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# it ---> it
# That ---> that
# alright ---> alright
# The ---> the
# party ---> parti
# still ---> still
# going ---> go
# Thank ---> thank
# you ---> you
# LFG ---> lfg
# on ---> on
# XBL ---> xbl
# Our ---> our
# newest ---> newest
# update ---> updat
# lets ---> let
# you ---> you
# search ---> search
# for ---> for
# teammates ---> teammat
# by ---> by
# objective ---> object
# playstyle ---> playstyl
# and ---> and
# more ---> more
# XboxLive ---> xboxliv
# http ---> http
# They ---> they
# be ---> be
# many ---> mani
# more ---> more
# for ---> for
# sure ---> sure
# Jay ---> jay
# Thanks ---> thank
# for ---> for
# the ---> the
# greeting ---> greet
# Got ---> got
# ta ---> ta
# agree ---> agre
# with ---> with
# you ---> you
# there ---> there
# Andrew ---> andrew
# Here ---> here
# to ---> to
# years ---> year
# of ---> of
# games ---> game
# achievements ---> achiev
# friendships ---> friendship
# and ---> and
# memories ---> memori
# Thank ---> thank
# you ---> you
# Hack ---> hack
# Everything ---> everyth
# M ---> m
# comes ---> come
# to ---> to
# XboxOne ---> xboxon
# today ---> today
# http ---> http
# And ---> and
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Totally ---> total
# radical ---> radic
# controller ---> control
# We ---> we
# so ---> so
# thankful ---> thank
# for ---> for
# fans ---> fan
# like ---> like
# you ---> you
# Anthony ---> anthoni
# What ---> what
# been ---> been
# your ---> your
# favorite ---> favorit
# gaming ---> game
# moment ---> moment
# It ---> it
# a ---> a
# deathmatch ---> deathmatch
# made ---> made
# in ---> in
# heaven ---> heaven
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# RT ---> rt
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# a ---> a
# Military ---> militari
# Green ---> green
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# bundle ---> bundl
# Rules ---> rule
# http ---> http
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# From ---> from
# the ---> the
# beginning ---> begin
# It ---> it
# great ---> great
# to ---> to
# have ---> have
# awesome ---> awesom
# fans ---> fan
# That ---> that
# awesome ---> awesom
# Thanks ---> thank
# for ---> for
# sharing ---> share
# your ---> your
# memory ---> memori
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# chance ---> chanc
# to ---> to
# pick ---> pick
# one ---> one
# up ---> up
# Thanks ---> thank
# Thanks ---> thank
# for ---> for
# years ---> year
# of ---> of
# awesomeness ---> awesom
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Talan ---> talan
# Stay ---> stay
# awesome ---> awesom
# And ---> and
# thank ---> thank
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gamer
# You ---> you
# know ---> know
# it ---> it
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# of ---> of
# Halo ---> halo
# awesomeness ---> awesom
# Which ---> which
# one ---> one
# did ---> did
# you ---> you
# grow ---> grow
# up ---> up
# with ---> with
# Thanks ---> thank
# Here ---> here
# to ---> to
# more ---> more
# That ---> that
# a ---> a
# great ---> great
# story ---> stori
# Mac ---> mac
# Thanks ---> thank
# for ---> for
# sharing ---> share
# The ---> the
# ride ---> ride
# not ---> not
# over ---> over
# yet ---> yet
# Christian ---> christian
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Why ---> whi
# thank ---> thank
# you ---> you
# Daniel ---> daniel
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# If ---> if
# you ---> you
# like ---> like
# we ---> we
# highly ---> highli
# recommend ---> recommend
# Super ---> super
# Dungeon ---> dungeon
# Bros ---> bro
# and ---> and
# Overcooked ---> overcook
# Cheers ---> cheer
# You ---> you
# have ---> have
# very ---> veri
# good ---> good
# taste ---> tast
# in ---> in
# birthdays ---> birthday
# We ---> we
# definitely ---> definit
# will ---> will
# You ---> you
# can ---> can
# celebrate ---> celebr
# by ---> by
# playing ---> play
# some ---> some
# Xbox ---> xbox
# tonight ---> tonight
# Today ---> today
# players ---> player
# get ---> get
# a ---> a
# Ford ---> ford
# Raptor ---> raptor
# with ---> with
# livery ---> liveri
# new ---> new
# Rivals ---> rival
# events ---> event
# and ---> and
# more ---> more
# http ---> http
# Thanks ---> thank
# Rodolfo ---> rodolfo
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# We ---> we
# forever ---> forev
# young ---> young
# Aiden ---> aiden
# Thanks ---> thank
# for ---> for
# being ---> be
# a ---> a
# great ---> great
# fan ---> fan
# Time ---> time
# flies ---> fli
# but ---> but
# the ---> the
# awesome ---> awesom
# memories ---> memori
# are ---> are
# here ---> here
# to ---> to
# stay ---> stay
# We ---> we
# loving ---> love
# the ---> the
# photo ---> photo
# Keep ---> keep
# on ---> on
# gaming ---> game
# and ---> and
# keep ---> keep
# on ---> on
# raging ---> rage
# Hunter ---> hunter
# It ---> it
# gamers ---> gamer
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# moving ---> move
# forward ---> forward
# Thanks ---> thank
# Zachary ---> zachari
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Thank ---> thank
# you ---> you
# Shaun ---> shaun
# Thanks ---> thank
# for ---> for
# being ---> be
# part ---> part
# of ---> of
# the ---> the
# team ---> team
# We ---> we
# appreciate ---> appreci
# it ---> it
# With ---> with
# the ---> the
# best ---> best
# fans ---> fan
# of ---> of
# all ---> all
# time ---> time
# And ---> and
# thank ---> thank
# you ---> you
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# amazing ---> amaz
# fan ---> fan
# It ---> it
# our ---> our
# pleasure ---> pleasur
# We ---> we
# love ---> love
# to ---> to
# hear ---> hear
# you ---> you
# enjoying ---> enjoy
# it ---> it
# so ---> so
# ...
# CallofDuty ---> callofduti
# InfiniteWarfare ---> infinitewarfar
# M ---> m
# pack ---> pack
# XboxSweepstakes ---> xboxsweepstak
# rules ---> rule
# http ---> http
# In ---> in
# the ---> the
# last ---> last
# year ---> year
# we ---> we
# added ---> ad
# over ---> over
# games ---> game
# to ---> to
# BackwardCompatibility ---> backwardcompat
# Which ---> which
# were ---> were
# your ---> your
# favs ---> fav
# http ---> http
# Tune ---> tune
# in ---> in
# to ---> to
# see ---> see
# who ---> who
# qualifies ---> qualifi
# for ---> for
# the ---> the
# SMITE ---> smite
# T ---> t
# Console ---> consol
# World ---> world
# Championship ---> championship
# http ---> http
# SmitePro ---> smitepro
# Take ---> take
# back ---> back
# what ---> what
# yours ---> your
# M ---> m
# is ---> is
# available ---> avail
# now ---> now
# http ---> http
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# BackwardCompatibility ---> backwardcompat
# turns ---> turn
# one ---> one
# M ---> m
# comes ---> come
# to ---> to
# Xbox ---> xbox
# and ---> and
# more ---> more
# http ---> http
# We ---> we
# most ---> most
# certainly ---> certainli
# okay ---> okay
# with ---> with
# this ---> thi
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# December ---> decemb
# We ---> we
# see ---> see
# if ---> if
# the ---> the
# other ---> other
# Koopa ---> koopa
# keep ---> keep
# up ---> up
# XboxOne ---> xboxon
# EASPORTSUFC ---> easportsufc
# T ---> t
# is ---> is
# now ---> now
# in ---> in
# the ---> the
# EAAccess ---> eaaccess
# Vault ---> vault
# Get ---> get
# a ---> a
# round ---> round
# in ---> in
# http ---> http
# Time ---> time
# to ---> to
# start ---> start
# marathoning ---> marathon
# in ---> in
# your ---> your
# Batcave ---> batcav
# XboxOne ---> xboxon
# Catch ---> catch
# today ---> today
# T ---> t
# Twitch ---> twitch
# stream ---> stream
# at ---> at
# PM ---> pm
# PT ---> pt
# PM ---> pm
# ET ---> et
# Tune ---> tune
# in ---> in
# at ---> at
# http ---> http
# That ---> that
# always ---> alway
# a ---> a
# great ---> great
# feeling ---> feel
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# playing ---> play
# You ---> you
# never ---> never
# gon ---> gon
# na ---> na
# have ---> have
# a ---> a
# good ---> good
# sauce ---> sauc
# again ---> again
# M ---> m
# http ---> http
# Follow ---> follow
# RT ---> rt
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# EAAccess ---> eaaccess
# code ---> code
# MassEffect ---> masseffect
# M ---> m
# M ---> m
# and ---> and
# M ---> m
# are ---> are
# waiting ---> wait
# http ---> http
# Sweepstakes ---> sweepstak
# Dishonored ---> dishonor
# M ---> m
# is ---> is
# live ---> live
# on ---> on
# Twitch ---> twitch
# Join ---> join
# the ---> the
# stream ---> stream
# for ---> for
# gameplay ---> gameplay
# chat ---> chat
# and ---> and
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# a ---> a
# prize ---> prize
# http ---> http
# STEEP ---> steep
# T ---> t
# Early ---> earli
# Access ---> access
# beta ---> beta
# is ---> is
# live ---> live
# Watch ---> watch
# the ---> the
# trailer ---> trailer
# and ---> and
# start ---> start
# your ---> your
# descent ---> descent
# at ---> at
# http ---> http
# The ---> the
# feeling ---> feel
# is ---> is
# mutual ---> mutual
# You ---> you
# welcome ---> welcom
# so ---> so
# much ---> much
# Jennifer ---> jennif
# Grab ---> grab
# your ---> your
# running ---> run
# gear ---> gear
# MirrorsEdge ---> mirrorsedg
# T ---> t
# and ---> and
# MirrorsEdgeCatalyst ---> mirrorsedgecatalyst
# T ---> t
# are ---> are
# now ---> now
# part ---> part
# of ---> of
# EAAccess ---> eaaccess
# http ---> http
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# Will ---> will
# you ---> you
# be ---> be
# streaming ---> stream
# the ---> the
# game ---> game
# It ---> it
# a ---> a
# very ---> veri
# important ---> import
# aspect ---> aspect
# of ---> of
# his ---> hi
# character ---> charact
# that ---> that
# people ---> peopl
# must ---> must
# know ---> know
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# Got ---> got
# your ---> your
# copy ---> copi
# preordered ---> preorder
# yet ---> yet
# Talk ---> talk
# about ---> about
# a ---> a
# blast ---> blast
# from ---> from
# the ---> the
# past ---> past
# Stay ---> stay
# awesome ---> awesom
# birthday ---> birthday
# buddy ---> buddi
# As ---> as
# a ---> a
# journalist ---> journalist
# Frank ---> frank
# is ---> is
# naturally ---> natur
# witty ---> witti
# He ---> he
# covered ---> cover
# wars ---> war
# you ---> you
# know ---> know
# Glad ---> glad
# that ---> that
# you ---> you
# liking ---> like
# what ---> what
# you ---> you
# seeing ---> see
# What ---> what
# part ---> part
# are ---> are
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# not ---> not
# too ---> too
# terrible ---> terribl
# of ---> of
# a ---> a
# problem ---> problem
# to ---> to
# have ---> have
# That ---> that
# because ---> becaus
# you ---> you
# are ---> are
# Glad ---> glad
# you ---> you
# think ---> think
# so ---> so
# We ---> we
# guess ---> guess
# you ---> you
# still ---> still
# got ---> got
# the ---> the
# flick ---> flick
# then ---> then
# That ---> that
# awesome ---> awesom
# to ---> to
# hear ---> hear
# You ---> you
# going ---> go
# to ---> to
# have ---> have
# an ---> an
# amazing ---> amaz
# holiday ---> holiday
# season ---> season
# Looking ---> look
# good ---> good
# Aaron ---> aaron
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# break ---> break
# it ---> it
# in ---> in
# with ---> with
# Xbox ---> xbox
# is ---> is
# love ---> love
# It ---> it
# been ---> been
# a ---> a
# great ---> great
# day ---> day
# for ---> for
# Backwards ---> backward
# Compatibility ---> compat
# D ---> d
# Shoutouts ---> shoutout
# to ---> to
# your ---> your
# son ---> son
# Thanks ---> thank
# for ---> for
# sharing ---> share
# The ---> the
# anticipation ---> anticip
# is ---> is
# already ---> alreadi
# getting ---> get
# hard ---> hard
# to ---> to
# handle ---> handl
# We ---> we
# guessing ---> guess
# someone ---> someon
# excited ---> excit
# The ---> the
# first ---> first
# of ---> of
# many ---> mani
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# the ---> the
# feature ---> featur
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Woot ---> woot
# woot ---> woot
# Have ---> have
# fun ---> fun
# T ---> t
# is ---> is
# now ---> now
# playable ---> playabl
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Buy ---> buy
# it ---> it
# today ---> today
# and ---> and
# save ---> save
# http ---> http
# Happy ---> happi
# birthday ---> birthday
# in ---> in
# advance ---> advanc
# Dear ---> dear
# Chris ---> chri
# Thank ---> thank
# you ---> you
# for ---> for
# taking ---> take
# the ---> the
# time ---> time
# to ---> to
# slay ---> slay
# bosses ---> boss
# with ---> with
# us ---> us
# It ---> it
# has ---> ha
# been ---> been
# too ---> too
# long ---> long
# and ---> and
# we ---> we
# missed ---> miss
# you ---> you
# Love ---> love
# Xbox ---> xbox
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# it ---> it
# You ---> you
# better ---> better
# believe ---> believ
# it ---> it
# Here ---> here
# to ---> to
# that ---> that
# birthday ---> birthday
# twin ---> twin
# We ---> we
# hope ---> hope
# you ---> you
# had ---> had
# a ---> a
# great ---> great
# night ---> night
# Great ---> great
# work ---> work
# Meet ---> meet
# XboxLive ---> xboxliv
# newest ---> newest
# features ---> featur
# Looking ---> look
# for ---> for
# Group ---> group
# and ---> and
# Clubs ---> club
# http ---> http
# FUS ---> fu
# RO ---> ro
# MOD ---> mod
# Skyrim ---> skyrim
# Special ---> special
# Edition ---> edit
# M ---> m
# is ---> is
# now ---> now
# available ---> avail
# and ---> and
# moddable ---> moddabl
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Playing ---> play
# games ---> game
# is ---> is
# a ---> a
# great ---> great
# way ---> way
# to ---> to
# unwind ---> unwind
# We ---> we
# hope ---> hope
# you ---> you
# feel ---> feel
# better ---> better
# afterward ---> afterward
# Sounds ---> sound
# like ---> like
# the ---> the
# perfect ---> perfect
# way ---> way
# to ---> to
# unwind ---> unwind
# Fight ---> fight
# like ---> like
# hell ---> hell
# Intense ---> intens
# Thanks ---> thank
# for ---> for
# sharing ---> share
# the ---> the
# clip ---> clip
# That ---> that
# probably ---> probabl
# because ---> becaus
# it ---> it
# is ---> is
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# well ---> well
# We ---> we
# got ---> got
# your ---> your
# back ---> back
# Very ---> veri
# nice ---> nice
# choice ---> choic
# So ---> so
# much ---> much
# replay ---> replay
# value ---> valu
# Great ---> great
# work ---> work
# Shane ---> shane
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# What ---> what
# game ---> game
# is ---> is
# up ---> up
# next ---> next
# Good ---> good
# call ---> call
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chanc
# to ---> to
# pick ---> pick
# it ---> it
# up ---> up
# soon ---> soon
# You ---> you
# welcome ---> welcom
# Are ---> are
# you ---> you
# going ---> go
# Paragon ---> paragon
# or ---> or
# Renegade ---> renegad
# Very ---> veri
# nice ---> nice
# Standby ---> standbi
# for ---> for
# awesomeness ---> awesom
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# Absolutely ---> absolut
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# working ---> work
# on ---> on
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# enjoying ---> enjoy
# the ---> the
# game ---> game
# Nice ---> nice
# Have ---> have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# all ---> all
# of ---> of
# them ---> them
# You ---> you
# know ---> know
# it ---> it
# Have ---> have
# fun ---> fun
# and ---> and
# good ---> good
# luck ---> luck
# on ---> on
# your ---> your
# test ---> test
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# call ---> call
# an ---> an
# army ---> armi
# of ---> of
# two ---> two
# XboxOne ---> xboxon
# It ---> it
# fans ---> fan
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# going ---> go
# It ---> it
# great ---> great
# seeing ---> see
# those ---> those
# enemies ---> enemi
# just ---> just
# hanging ---> hang
# up ---> up
# there ---> there
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# No ---> no
# problem ---> problem
# But ---> but
# with ---> with
# your ---> your
# skill ---> skill
# we ---> we
# think ---> think
# you ---> you
# got ---> got
# this ---> thi
# Game ---> game
# on ---> on
# Nathan ---> nathan
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# videos ---> video
# Awesome ---> awesom
# Have ---> have
# you ---> you
# been ---> been
# playing ---> play
# Infinite ---> infinit
# Warfare ---> warfar
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# Family ---> famili
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# be ---> be
# playing ---> play
# You ---> you
# have ---> have
# great ---> great
# taste ---> tast
# in ---> in
# games ---> game
# Leah ---> leah
# Good ---> good
# luck ---> luck
# against ---> against
# the ---> the
# hordes ---> hord
# Alex ---> alex
# Massive ---> massiv
# You ---> you
# welcome ---> welcom
# Korie ---> kori
# A ---> a
# good ---> good
# night ---> night
# indeed ---> inde
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# blast ---> blast
# There ---> there
# a ---> a
# lot ---> lot
# of ---> of
# stuff ---> stuff
# to ---> to
# take ---> take
# care ---> care
# of ---> of
# in ---> in
# Gotham ---> gotham
# Good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# love ---> love
# it ---> it
# so ---> so
# much ---> much
# What ---> what
# your ---> your
# favorite ---> favorit
# game ---> game
# to ---> to
# play ---> play
# on ---> on
# it ---> it
# This ---> thi
# week ---> week
# XboxCharityChallenge ---> xboxcharitychalleng
# throws ---> throw
# back ---> back
# to ---> to
# with ---> with
# Watch ---> watch
# live ---> live
# now ---> now
# http ---> http
# It ---> it
# nothing ---> noth
# but ---> but
# love ---> love
# here ---> here
# Clifton ---> clifton
# Stay ---> stay
# awesome ---> awesom
# Well ---> well
# the ---> the
# colors ---> color
# do ---> do
# match ---> match
# your ---> your
# avatar ---> avatar
# so ---> so
# we ---> we
# think ---> think
# they ---> they
# cool ---> cool
# Have ---> have
# a ---> a
# great ---> great
# stream ---> stream
# Nyree ---> nyre
# Glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# so ---> so
# far ---> far
# It ---> it
# really ---> realli
# is ---> is
# worth ---> worth
# it ---> it
# Keith ---> keith
# Terminal ---> termin
# was ---> wa
# easily ---> easili
# one ---> one
# of ---> of
# our ---> our
# favorite ---> favorit
# maps ---> map
# You ---> you
# have ---> have
# good ---> good
# taste ---> tast
# If ---> if
# not ---> not
# you ---> you
# can ---> can
# always ---> alway
# grab ---> grab
# an ---> an
# external ---> extern
# hard ---> hard
# drive ---> drive
# How ---> how
# are ---> are
# you ---> you
# liking ---> like
# it ---> it
# so ---> so
# far ---> far
# Nice ---> nice
# plan ---> plan
# Which ---> which
# squad ---> squad
# mate ---> mate
# are ---> are
# you ---> you
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# again ---> again
# the ---> the
# most ---> most
# What ---> what
# up ---> up
# Troy ---> troy
# That ---> that
# an ---> an
# excellent ---> excel
# option ---> option
# Good ---> good
# luck ---> luck
# Breaks ---> break
# your ---> your
# heart ---> heart
# and ---> and
# forces ---> forc
# a ---> a
# restart ---> restart
# from ---> from
# the ---> the
# beginning ---> begin
# We ---> we
# also ---> also
# make ---> make
# sure ---> sure
# that ---> that
# it ---> it
# a ---> a
# Suicide ---> suicid
# Mission ---> mission
# in ---> in
# name ---> name
# only ---> onli
# Mass ---> mass
# Effect ---> effect
# and ---> and
# are ---> are
# available ---> avail
# digitally ---> digit
# through ---> through
# EA ---> ea
# Access ---> access
# here ---> here
# Thank ---> thank
# goodness ---> good
# Whatcha ---> whatcha
# playing ---> play
# We ---> we
# love ---> love
# Jack ---> jack
# Though ---> though
# we ---> we
# ca ---> ca
# really ---> realli
# repeat ---> repeat
# any ---> ani
# of ---> of
# our ---> our
# favorite ---> favorit
# quotes ---> quot
# though ---> though
# There ---> there
# is ---> is
# an ---> an
# option ---> option
# to ---> to
# go ---> go
# back ---> back
# to ---> to
# Xbox ---> xbox
# commands ---> command
# You ---> you
# can ---> can
# find ---> find
# out ---> out
# how ---> how
# here ---> here
# http ---> http
# You ---> you
# mean ---> mean
# that ---> that
# out ---> out
# of ---> of
# all ---> all
# your ---> your
# pinend ---> pinend
# apps ---> app
# it ---> it
# First ---> first
# We ---> we
# love ---> love
# how ---> how
# it ---> it
# brings ---> bring
# people ---> peopl
# together ---> togeth
# Say ---> say
# whattt ---> whattt
# The ---> the
# day ---> day
# not ---> not
# over ---> over
# yet ---> yet
# Now ---> now
# that ---> that
# sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# We ---> we
# sure ---> sure
# you ---> you
# love ---> love
# it ---> it
# Let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# Welcome ---> welcom
# back ---> back
# Michelle ---> michel
# It ---> it
# like ---> like
# riding ---> ride
# a ---> a
# bicycle ---> bicycl
# Made ---> made
# out ---> out
# of ---> of
# guns ---> gun
# Sounds ---> sound
# like ---> like
# a ---> a
# Monday ---> monday
# well ---> well
# spent ---> spent
# to ---> to
# us ---> us
# We ---> we
# applaud ---> applaud
# his ---> hi
# dedication ---> dedic
# Epic ---> epic
# clip ---> clip
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# Have ---> have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# through ---> through
# them ---> them
# Thanks ---> thank
# Jon ---> jon
# Will ---> will
# you ---> you
# be ---> be
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# soon ---> soon
# A ---> a
# great ---> great
# day ---> day
# indeed ---> inde
# Are ---> are
# you ---> you
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# right ---> right
# now ---> now
# Incredible ---> incred
# Your ---> your
# gamerscore ---> gamerscor
# must ---> must
# be ---> be
# crazy ---> crazi
# Awesome ---> awesom
# What ---> what
# game ---> game
# were ---> were
# you ---> you
# streaming ---> stream
# And ---> and
# then ---> then
# we ---> we
# responded ---> respond
# on ---> on
# yours ---> your
# Everyone ---> everyon
# can ---> can
# enjoy ---> enjoy
# Xbox ---> xbox
# But ---> but
# it ---> it
# great ---> great
# to ---> to
# hear ---> hear
# that ---> that
# we ---> we
# can ---> can
# bring ---> bring
# generations ---> gener
# together ---> togeth
# Someone ---> someon
# in ---> in
# for ---> for
# a ---> a
# very ---> veri
# bad ---> bad
# day ---> day
# She ---> she
# looks ---> look
# like ---> like
# a ---> a
# serious ---> seriou
# piece ---> piec
# of ---> of
# hardware ---> hardwar
# Mel ---> mel

# %% [markdown]
# ## Snowball Stemming

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language='english')

for token in tokens:
  print(token,"--->", snowball.stem(token))
# Out:
# Feeling ---> feel
# thankful ---> thank
# Tag ---> tag
# friends ---> friend
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# M ---> m
# digital ---> digit
# codes ---> code
# Rules ---> rule
# http ---> http
# Holiday ---> holiday
# parties ---> parti
# are ---> are
# the ---> the
# worst ---> worst
# M ---> m
# http ---> http
# Now ---> now
# through ---> through
# Monday ---> monday
# enjoy ---> enjoy
# free ---> free
# engraving ---> engrav
# on ---> on
# all ---> all
# XboxDesignLab ---> xboxdesignlab
# controllers ---> control
# Start ---> start
# building ---> build
# yours ---> your
# at ---> at
# http ---> http
# Make ---> make
# your ---> your
# own ---> own
# zombie ---> zombi
# musical ---> music
# number ---> number
# inspired ---> inspir
# by ---> by
# M ---> m
# http ---> http
# This ---> this
# Week ---> week
# on ---> on
# Xbox ---> xbox
# FFXV ---> ffxv
# T ---> t
# The ---> the
# Division ---> divis
# M ---> m
# Survival ---> surviv
# and ---> and
# Episode ---> episod
# of ---> of
# telltalegames ---> telltalegam
# Batman ---> batman
# M ---> m
# http ---> http
# Celebrate ---> celebr
# woodyinho ---> woodyinho
# jamesrodriguez ---> jamesrodriguez
# anthonymartial ---> anthonymarti
# in ---> in
# the ---> the
# E ---> e
# free ---> free
# trial ---> trial
# out ---> out
# now ---> now
# http ---> http
# Sounds ---> sound
# like ---> like
# Austin ---> austin
# is ---> is
# a ---> a
# pretty ---> pretti
# good ---> good
# player ---> player
# huh ---> huh
# We ---> we
# glad ---> glad
# you ---> you
# had ---> had
# a ---> a
# successful ---> success
# Black ---> black
# Friday ---> friday
# What ---> what
# games ---> game
# did ---> did
# you ---> you
# get ---> get
# Which ---> which
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# choosing ---> choos
# If ---> if
# that ---> that
# is ---> is
# true ---> true
# love ---> love
# then ---> then
# we ---> we
# do ---> do
# know ---> know
# what ---> what
# is ---> is
# Which ---> which
# bundle ---> bundl
# did ---> did
# you ---> you
# get ---> get
# him ---> him
# Awesome ---> awesom
# is ---> is
# right ---> right
# Did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# it ---> it
# Those ---> those
# are ---> are
# the ---> the
# best ---> best
# What ---> what
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# We ---> we
# say ---> say
# you ---> you
# were ---> were
# pretty ---> pretti
# successful ---> success
# We ---> we
# love ---> love
# that ---> that
# idea ---> idea
# What ---> what
# did ---> did
# you ---> you
# play ---> play
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> one
# family ---> famili
# What ---> what
# games ---> game
# did ---> did
# you ---> you
# get ---> get
# We ---> we
# glad ---> glad
# you ---> you
# could ---> could
# take ---> take
# advantage ---> advantag
# of ---> of
# this ---> this
# great ---> great
# deal ---> deal
# Which ---> which
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Which ---> which
# games ---> game
# did ---> did
# you ---> you
# pick ---> pick
# We ---> we
# love ---> love
# to ---> to
# hear ---> hear
# that ---> that
# Do ---> do
# you ---> you
# think ---> think
# you ---> you
# replay ---> replay
# it ---> it
# anytime ---> anytim
# soon ---> soon
# We ---> we
# know ---> know
# what ---> what
# that ---> that
# like ---> like
# You ---> you
# get ---> get
# home ---> home
# and ---> and
# game ---> game
# yet ---> yet
# We ---> we
# love ---> love
# the ---> the
# sound ---> sound
# of ---> of
# that ---> that
# Are ---> are
# you ---> you
# hoping ---> hope
# for ---> for
# any ---> ani
# specific ---> specif
# bundles ---> bundl
# We ---> we
# ca ---> ca
# wait ---> wait
# either ---> either
# When ---> when
# do ---> do
# you ---> you
# plan ---> plan
# on ---> on
# getting ---> get
# one ---> one
# Personalized ---> person
# just ---> just
# for ---> for
# you ---> you
# We ---> we
# loving ---> love
# this ---> this
# design ---> design
# Sounds ---> sound
# like ---> like
# the ---> the
# perfect ---> perfect
# birthday ---> birthday
# Which ---> which
# games ---> game
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# for ---> for
# Black ---> black
# Friday ---> friday
# Boom ---> boom
# That ---> that
# going ---> go
# to ---> to
# keep ---> keep
# you ---> you
# busy ---> busi
# Awesome ---> awesom
# Sounds ---> sound
# like ---> like
# a ---> a
# pretty ---> pretti
# good ---> good
# Black ---> black
# Friday ---> friday
# huh ---> huh
# Thanks ---> thank
# for ---> for
# the ---> the
# shoutout ---> shoutout
# Did ---> did
# you ---> you
# get ---> get
# any ---> ani
# other ---> other
# games ---> game
# along ---> along
# with ---> with
# Fifa ---> fifa
# Sometimes ---> sometim
# it ---> it
# good ---> good
# to ---> to
# upgrade ---> upgrad
# Is ---> is
# this ---> this
# all ---> all
# you ---> you
# got ---> got
# for ---> for
# your ---> your
# gaming ---> game
# set ---> set
# up ---> up
# Live ---> live
# now ---> now
# Tune ---> tune
# in ---> in
# to ---> to
# the ---> the
# Gears ---> gear
# Pro ---> pro
# Circuit ---> circuit
# Open ---> open
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# http ---> http
# GearsofWar ---> gearsofwar
# M ---> m
# Sounds ---> sound
# like ---> like
# a ---> a
# pretty ---> pretti
# great ---> great
# holiday ---> holiday
# Did ---> did
# you ---> you
# get ---> get
# a ---> a
# specific ---> specif
# bundle ---> bundl
# We ---> we
# loving ---> love
# the ---> the
# color ---> color
# scheme ---> scheme
# You ---> you
# take ---> take
# it ---> it
# for ---> for
# a ---> a
# spin ---> spin
# already ---> alreadi
# Sounds ---> sound
# like ---> like
# your ---> your
# Black ---> black
# Friday ---> friday
# was ---> was
# a ---> a
# huge ---> huge
# success ---> success
# That ---> that
# a ---> a
# very ---> veri
# good ---> good
# way ---> way
# to ---> to
# celebrate ---> celebr
# if ---> if
# you ---> you
# ask ---> ask
# us ---> us
# You ---> you
# better ---> better
# believe ---> believ
# it ---> it
# For ---> for
# some ---> some
# things ---> thing
# an ---> an
# exception ---> except
# must ---> must
# be ---> be
# made ---> made
# Looks ---> look
# like ---> like
# you ---> you
# made ---> made
# the ---> the
# most ---> most
# of ---> of
# Black ---> black
# Friday ---> friday
# this ---> this
# year ---> year
# At ---> at
# least ---> least
# you ---> you
# got ---> got
# the ---> the
# essentials ---> essenti
# Technically ---> technic
# we ---> we
# do ---> do
# play ---> play
# DVD ---> dvd
# and ---> and
# Blu ---> blu
# Rays ---> ray
# sounds ---> sound
# like ---> like
# a ---> a
# Looks ---> look
# like ---> like
# it ---> it
# was ---> was
# your ---> your
# Destiny ---> destini
# to ---> to
# get ---> get
# great ---> great
# deals ---> deal
# today ---> today
# Sounds ---> sound
# like ---> like
# a ---> a
# very ---> veri
# successful ---> success
# day ---> day
# Sounds ---> sound
# like ---> like
# it ---> it
# was ---> was
# a ---> a
# good ---> good
# day ---> day
# We ---> we
# loving ---> love
# the ---> the
# color ---> color
# Browse ---> brows
# BlackFriday ---> blackfriday
# deals ---> deal
# on ---> on
# top ---> top
# Xbox ---> xbox
# games ---> game
# like ---> like
# Skyrim ---> skyrim
# Special ---> special
# Edition ---> edit
# M ---> m
# DOOM ---> doom
# M ---> m
# and ---> and
# more ---> more
# http ---> http
# Awesome ---> awesom
# Trust ---> trust
# us ---> us
# the ---> the
# Horizon ---> horizon
# Festival ---> festiv
# just ---> just
# keeps ---> keep
# getting ---> get
# better ---> better
# Get ---> get
# the ---> the
# undead ---> undead
# party ---> parti
# started ---> start
# Check ---> check
# out ---> out
# the ---> the
# M ---> m
# lens ---> len
# now ---> now
# on ---> on
# Snapchat ---> snapchat
# Sounds ---> sound
# like ---> like
# it ---> it
# gon ---> gon
# na ---> na
# be ---> be
# a ---> a
# good ---> good
# day ---> day
# Feel ---> feel
# the ---> the
# difference ---> differ
# Pick ---> pick
# up ---> up
# the ---> the
# XboxElite ---> xboxelit
# at ---> at
# a ---> a
# MicrosoftStore ---> microsoftstor
# near ---> near
# you ---> you
# http ---> http
# Have ---> have
# fun ---> fun
# Holli ---> holli
# Epic ---> epic
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# fun ---> fun
# That ---> that
# makes ---> make
# you ---> you
# an ---> an
# awesome ---> awesom
# human ---> human
# being ---> be
# You ---> you
# know ---> know
# it ---> it
# What ---> what
# have ---> have
# you ---> you
# picked ---> pick
# up ---> up
# so ---> so
# far ---> far
# Woot ---> woot
# woot ---> woot
# Now ---> now
# that ---> that
# an ---> an
# awesome ---> awesom
# pick ---> pick
# up ---> up
# Grab ---> grab
# ahold ---> ahold
# of ---> of
# happiness ---> happi
# BlackFriday ---> blackfriday
# Get ---> get
# the ---> the
# XboxOneS ---> xboxon
# at ---> at
# our ---> our
# lowest ---> lowest
# price ---> price
# yet ---> yet
# Shop ---> shop
# the ---> the
# BlackFriday ---> blackfriday
# sale ---> sale
# at ---> at
# http ---> http
# Every ---> everi
# achievement ---> achiev
# is ---> is
# a ---> a
# tiny ---> tini
# parade ---> parad
# Celebrate ---> celebr
# yours ---> your
# this ---> this
# Thanksgiving ---> thanksgiv
# Our ---> our
# gear ---> gear
# Your ---> your
# design ---> design
# Start ---> start
# building ---> build
# your ---> your
# Xbox ---> xbox
# controller ---> control
# at ---> at
# http ---> http
# XboxDesignLab ---> xboxdesignlab
# It ---> it
# just ---> just
# that ---> that
# many ---> mani
# more ---> more
# achievements ---> achiev
# for ---> for
# you ---> you
# to ---> to
# hunt ---> hunt
# XboxOne ---> xboxon
# The ---> the
# best ---> best
# controller ---> control
# make ---> make
# no ---> no
# XboxOne ---> xboxon
# Tag ---> tag
# friends ---> friend
# you ---> you
# thankful ---> thank
# for ---> for
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# digital ---> digit
# codes ---> code
# of ---> of
# M ---> m
# Rules ---> rule
# http ---> http
# Ooh ---> ooh
# that ---> that
# a ---> a
# tough ---> tough
# one ---> one
# At ---> at
# least ---> least
# it ---> it
# a ---> a
# choice ---> choic
# No ---> no
# sweat ---> sweat
# Have ---> have
# a ---> a
# blast ---> blast
# Anthony ---> anthoni
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> have
# so ---> so
# much ---> much
# fun ---> fun
# streaming ---> stream
# There ---> there
# absolutely ---> absolut
# is ---> is
# just ---> just
# follow ---> follow
# this ---> this
# guide ---> guid
# UI ---> ui
# may ---> may
# differ ---> differ
# http ---> http
# It ---> it
# does ---> doe
# look ---> look
# amazing ---> amaz
# Good ---> good
# plan ---> plan
# Have ---> have
# fun ---> fun
# The ---> the
# only ---> onli
# people ---> peopl
# who ---> who
# should ---> should
# be ---> be
# alarmed ---> alarm
# are ---> are
# your ---> your
# opponents ---> oppon
# We ---> we
# sure ---> sure
# you ---> you
# can ---> can
# find ---> find
# time ---> time
# for ---> for
# both ---> both
# Cruise ---> cruis
# into ---> into
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# E ---> e
# now ---> now
# through ---> through
# November ---> novemb
# http ---> http
# Time ---> time
# to ---> to
# find ---> find
# some ---> some
# savings ---> save
# XboxOne ---> xboxon
# Join ---> join
# Clubs ---> club
# find ---> find
# players ---> player
# and ---> and
# download ---> download
# GamesWithGold ---> gameswithgold
# from ---> from
# your ---> your
# smartphone ---> smartphon
# with ---> with
# the ---> the
# Xbox ---> xbox
# app ---> app
# Download ---> download
# http ---> http
# Thanks ---> thank
# Brandon ---> brandon
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# The ---> the
# big ---> big
# question ---> question
# is ---> is
# which ---> which
# game ---> game
# will ---> will
# you ---> you
# be ---> be
# booting ---> boot
# up ---> up
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Looks ---> look
# like ---> like
# quite ---> quit
# the ---> the
# haul ---> haul
# We ---> we
# right ---> right
# there ---> there
# with ---> with
# you ---> you
# Save ---> save
# cash ---> cash
# Save ---> save
# Sera ---> sera
# M ---> m
# is ---> is
# on ---> on
# sale ---> sale
# now ---> now
# http ---> http
# BlackFriday ---> blackfriday
# How ---> how
# did ---> did
# it ---> it
# end ---> end
# up ---> up
# working ---> work
# out ---> out
# for ---> for
# you ---> you
# Emily ---> emili
# That ---> that
# the ---> the
# way ---> way
# to ---> to
# go ---> go
# Buy ---> buy
# digital ---> digit
# Play ---> play
# anywhere ---> anywher
# Learn ---> learn
# how ---> how
# at ---> at
# http ---> http
# XboxPlayAnywhere ---> xboxplayanywher
# Hard ---> hard
# weather ---> weather
# heads ---> head
# to ---> to
# New ---> new
# York ---> york
# with ---> with
# today ---> today
# release ---> releas
# of ---> of
# TheDivision ---> thedivis
# M ---> m
# Survival ---> surviv
# Get ---> get
# the ---> the
# new ---> new
# DLC ---> dlc
# at ---> at
# http ---> http
# Battlepacks ---> battlepack
# are ---> are
# now ---> now
# available ---> avail
# for ---> for
# purchase ---> purchas
# in ---> in
# Battlefield ---> battlefield
# M ---> m
# http ---> http
# Forge ---> forg
# an ---> an
# alliance ---> allianc
# with ---> with
# The ---> the
# Clown ---> clown
# Prince ---> princ
# of ---> of
# Crime ---> crime
# in ---> in
# BATMAN ---> batman
# The ---> the
# Telltale ---> telltal
# Series ---> seri
# M ---> m
# Episode ---> episod
# is ---> is
# out ---> out
# now ---> now
# http ---> http
# The ---> the
# only ---> onli
# question ---> question
# is ---> is
# which ---> which
# squad ---> squad
# member ---> member
# did ---> did
# you ---> you
# use ---> use
# for ---> for
# gaming ---> game
# today ---> today
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# be ---> be
# shouting ---> shout
# out ---> out
# a ---> a
# game ---> game
# that ---> that
# you ---> you
# worked ---> work
# on ---> on
# over ---> over
# our ---> our
# channels ---> channel
# Thanks ---> thank
# for ---> for
# awesome ---> awesom
# years ---> year
# Mason ---> mason
# Oh ---> oh
# no ---> no
# Guess ---> guess
# it ---> it
# the ---> the
# only ---> onli
# way ---> way
# to ---> to
# keep ---> keep
# both ---> both
# your ---> your
# mind ---> mind
# and ---> and
# your ---> your
# gaming ---> game
# skills ---> skill
# sharp ---> sharp
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# What ---> what
# game ---> game
# did ---> did
# you ---> you
# get ---> get
# it ---> it
# with ---> with
# Whoa ---> whoa
# Now ---> now
# those ---> those
# are ---> are
# some ---> some
# serious ---> serious
# classics ---> classic
# Gear ---> gear
# up ---> up
# on ---> on
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# M ---> m
# available ---> avail
# now ---> now
# at ---> at
# http ---> http
# We ---> we
# could ---> could
# think ---> think
# of ---> of
# a ---> a
# better ---> better
# XboxOne ---> xboxon
# It ---> it
# coming ---> come
# together ---> togeth
# nicely ---> nice
# Thanks ---> thank
# for ---> for
# sharing ---> share
# the ---> the
# pic ---> pic
# Have ---> have
# a ---> a
# great ---> great
# week ---> week
# We ---> we
# looking ---> look
# forward ---> forward
# Xbox ---> xbox
# heavy ---> heavi
# holidays ---> holiday
# as ---> as
# well ---> well
# No ---> no
# arguments ---> argument
# here ---> here
# You ---> you
# should ---> should
# pick ---> pick
# it ---> it
# up ---> up
# Devin ---> devin
# That ---> that
# awesome ---> awesom
# We ---> we
# sure ---> sure
# it ---> it
# will ---> will
# make ---> make
# an ---> an
# amazing ---> amaz
# early ---> earli
# present ---> present
# We ---> we
# got ---> got
# to ---> to
# agree ---> agre
# with ---> with
# you ---> you
# there ---> there
# Hopefully ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Hello ---> hello
# there ---> there
# Oh ---> oh
# nice ---> nice
# That ---> that
# pretty ---> pretti
# creative ---> creativ
# We ---> we
# were ---> were
# always ---> alway
# fans ---> fan
# of ---> of
# their ---> their
# logo ---> logo
# There ---> there
# always ---> alway
# tomorrow ---> tomorrow
# and ---> and
# there ---> there
# ca ---> ca
# be ---> be
# an ---> an
# essay ---> essay
# every ---> everi
# day ---> day
# D ---> d
# Good ---> good
# plan ---> plan
# JJ ---> jj
# Pick ---> pick
# up ---> up
# some ---> some
# snacks ---> snack
# while ---> while
# you ---> you
# there ---> there
# We ---> we
# have ---> have
# http ---> http
# What ---> what
# better ---> better
# way ---> way
# to ---> to
# weather ---> weather
# winter ---> winter
# than ---> than
# with ---> with
# new ---> new
# GamesWithGold ---> gameswithgold
# Learn ---> learn
# more ---> more
# about ---> about
# December ---> decemb
# picks ---> pick
# at ---> at
# http ---> http
# Awesome ---> awesom
# work ---> work
# You ---> you
# know ---> know
# it ---> it
# You ---> you
# kept ---> kept
# it ---> it
# all ---> all
# this ---> this
# time ---> time
# Now ---> now
# we ---> we
# blushing ---> blush
# There ---> there
# nothing ---> noth
# wrong ---> wrong
# with ---> with
# being ---> be
# an ---> an
# Xbox ---> xbox
# fan ---> fan
# Have ---> have
# fun ---> fun
# Awesome ---> awesom
# Have ---> have
# fun ---> fun
# with ---> with
# it ---> it
# when ---> when
# it ---> it
# arrives ---> arriv
# XboxOne ---> xboxon
# to ---> to
# Oculus ---> oculus
# streaming ---> stream
# arrives ---> arriv
# December ---> decemb
# with ---> with
# the ---> the
# XboxOne ---> xboxon
# Streaming ---> stream
# app ---> app
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# It ---> it
# definitely ---> definit
# worth ---> worth
# checking ---> check
# out ---> out
# Carlos ---> carlo
# Have ---> have
# fun ---> fun
# Thanks ---> thank
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chanc
# to ---> to
# play ---> play
# them ---> them
# all ---> all
# The ---> the
# best ---> best
# time ---> time
# of ---> of
# the ---> the
# day ---> day
# We ---> we
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Have ---> have
# fun ---> fun
# with ---> with
# them ---> them
# We ---> we
# wrapping ---> wrap
# up ---> up
# with ---> with
# a ---> a
# bang ---> bang
# D ---> d
# Burnout ---> burnout
# Paradise ---> paradis
# is ---> is
# now ---> now
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Get ---> get
# it ---> it
# free ---> free
# on ---> on
# GamesWithGold ---> gameswithgold
# http ---> http
# You ---> you
# did ---> did
# a ---> a
# good ---> good
# thing ---> thing
# It ---> it
# the ---> the
# little ---> littl
# things ---> thing
# right ---> right
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Dylan ---> dylan
# What ---> what
# an ---> an
# awesome ---> awesom
# gift ---> gift
# We ---> we
# sure ---> sure
# he ---> he
# love ---> love
# it ---> it
# We ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Josh ---> josh
# Sounds ---> sound
# like ---> like
# a ---> a
# relaxing ---> relax
# morning ---> morn
# to ---> to
# us ---> us
# It ---> it
# quite ---> quit
# beautiful ---> beauti
# is ---> is
# it ---> it
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# We ---> we
# appreciate ---> appreci
# it ---> it
# You ---> you
# sure ---> sure
# know ---> know
# how ---> how
# to ---> to
# spread ---> spread
# the ---> the
# love ---> love
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Ashley ---> ashley
# You ---> you
# got ---> got
# real ---> real
# good ---> good
# taste ---> tast
# in ---> in
# games ---> game
# That ---> that
# looks ---> look
# awesome ---> awesom
# How ---> how
# did ---> did
# you ---> you
# come ---> come
# up ---> up
# with ---> with
# red ---> red
# and ---> and
# blue ---> blue
# Timeless ---> timeless
# as ---> as
# always ---> alway
# We ---> we
# love ---> love
# it ---> it
# Thanks ---> thank
# for ---> for
# participating ---> particip
# Sylvia ---> sylvia
# Thanks ---> thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gamer
# Hunter ---> hunter
# You ---> you
# kept ---> kept
# the ---> the
# box ---> box
# How ---> how
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# celebrate ---> celebr
# BlackFriday ---> blackfriday
# is ---> is
# here ---> here
# Save ---> save
# up ---> up
# to ---> to
# on ---> on
# Xbox ---> xbox
# games ---> game
# and ---> and
# go ---> go
# Gold ---> gold
# to ---> to
# save ---> save
# up ---> up
# to ---> to
# more ---> more
# See ---> see
# the ---> the
# deals ---> deal
# http ---> http
# Thanks ---> thank
# We ---> we
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> game
# Thanks ---> thank
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# about ---> about
# to ---> to
# go ---> go
# down ---> down
# Woot ---> woot
# woot ---> woot
# Awesome ---> awesom
# deal ---> deal
# Oh ---> oh
# hey ---> hey
# Whaddup ---> whaddup
# Sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Which ---> which
# bundle ---> bundl
# do ---> do
# you ---> you
# have ---> have
# your ---> your
# eye ---> eye
# on ---> on
# Thanks ---> thank
# for ---> for
# the ---> the
# Dustin ---> dustin
# Glad ---> glad
# to ---> to
# see ---> see
# that ---> that
# we ---> we
# could ---> could
# help ---> help
# hook ---> hook
# you ---> you
# up ---> up
# Right ---> right
# What ---> what
# an ---> an
# awesome ---> awesom
# deal ---> deal
# Adam ---> adam
# speaks ---> speak
# the ---> the
# truth ---> truth
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# so ---> so
# hyped ---> hype
# that ---> that
# awesome ---> awesom
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> one
# family ---> famili
# Very ---> veri
# nice ---> nice
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# We ---> we
# be ---> be
# waiting ---> wait
# You ---> you
# got ---> got
# good ---> good
# taste ---> tast
# in ---> in
# games ---> game
# Be ---> be
# sure ---> sure
# to ---> to
# let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# The ---> the
# best ---> best
# kind ---> kind
# of ---> of
# break ---> break
# You ---> you
# know ---> know
# what ---> what
# up ---> up
# Matt ---> matt
# Sometimes ---> sometim
# it ---> it
# just ---> just
# takes ---> take
# a ---> a
# little ---> littl
# motivation ---> motiv
# It ---> it
# is ---> is
# not ---> not
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# managed ---> manag
# to ---> to
# make ---> make
# it ---> it
# Looking ---> look
# good ---> good
# It ---> it
# Gearing ---> gear
# up ---> up
# to ---> to
# be ---> be
# a ---> a
# great ---> great
# day ---> day
# Awesome ---> awesom
# The ---> the
# sign ---> sign
# of ---> of
# a ---> a
# great ---> great
# Pilot ---> pilot
# You ---> you
# doing ---> do
# great ---> great
# Angel ---> angel
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# No ---> no
# problem ---> problem
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Playing ---> play
# M ---> m
# Try ---> tri
# out ---> out
# these ---> these
# maps ---> map
# for ---> for
# your ---> your
# XboxElite ---> xboxelit
# http ---> http
# You ---> you
# got ---> got
# so ---> so
# much ---> much
# gaming ---> game
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# envious ---> envious
# Have ---> have
# another ---> anoth
# great ---> great
# stream ---> stream
# Peter ---> peter
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# it ---> it
# This ---> this
# is ---> is
# a ---> a
# great ---> great
# time ---> time
# to ---> to
# pick ---> pick
# both ---> both
# of ---> of
# them ---> them
# up ---> up
# http ---> http
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# loving ---> love
# it ---> it
# Alyssa ---> alyssa
# Pizza ---> pizza
# party ---> parti
# at ---> at
# your ---> your
# house ---> hous
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# liking ---> like
# it ---> it
# What ---> what
# clubs ---> club
# have ---> have
# you ---> you
# joined ---> join
# so ---> so
# far ---> far
# Do ---> do
# worry ---> worri
# we ---> we
# got ---> got
# your ---> your
# back ---> back
# We ---> we
# see ---> see
# you ---> you
# at ---> at
# the ---> the
# Horizon ---> horizon
# Festival ---> festiv
# Forza ---> forza
# Horizon ---> horizon
# is ---> is
# also ---> also
# available ---> avail
# for ---> for
# Windows ---> window
# Good ---> good
# luck ---> luck
# getting ---> get
# to ---> to
# the ---> the
# wave ---> wave
# We ---> we
# ca ---> ca
# argue ---> argu
# with ---> with
# that ---> that
# We ---> we
# loving ---> love
# it ---> it
# too ---> too
# Enter ---> enter
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# when ---> when
# you ---> you
# order ---> order
# a ---> a
# Triple ---> tripl
# Treat ---> treat
# Box ---> box
# from ---> from
# PizzaHut ---> pizzahut
# Offer ---> offer
# ends ---> end
# Rules ---> rule
# http ---> http
# Be ---> be
# sure ---> sure
# to ---> to
# report ---> report
# the ---> the
# account ---> account
# http ---> http
# Our ---> our
# condolences ---> condol
# But ---> but
# we ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# got ---> got
# some ---> some
# great ---> great
# memories ---> memori
# together ---> togeth
# on ---> on
# the ---> the
# Xbox ---> xbox
# Awesome ---> awesom
# article ---> articl
# Michael ---> michael
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# been ---> been
# with ---> with
# us ---> us
# since ---> sinc
# the ---> the
# very ---> veri
# beginning ---> begin
# From ---> from
# behind ---> behind
# Great ---> great
# clip ---> clip
# Awesome ---> awesom
# work ---> work
# We ---> we
# love ---> love
# chatting ---> chat
# with ---> with
# our ---> our
# awesome ---> awesom
# fans ---> fan
# Great ---> great
# choice ---> choic
# with ---> with
# Mafia ---> mafia
# III ---> iii
# Looking ---> look
# great ---> great
# so ---> so
# far ---> far
# What ---> what
# game ---> game
# have ---> have
# you ---> you
# played ---> play
# the ---> the
# most ---> most
# Smart ---> smart
# thinking ---> think
# Dessmond ---> dessmond
# Looking ---> look
# for ---> for
# a ---> a
# holiday ---> holiday
# escape ---> escap
# M ---> m
# today ---> today
# and ---> and
# play ---> play
# it ---> it
# December ---> decemb
# http ---> http
# Awesome ---> awesom
# Which ---> which
# game ---> game
# were ---> were
# you ---> you
# playing ---> play
# Watch ---> watch
# Lesnar ---> lesnar
# battle ---> battl
# Goldberg ---> goldberg
# live ---> live
# tonight ---> tonight
# at ---> at
# PM ---> pm
# PT ---> pt
# on ---> on
# the ---> the
# WWENetwork ---> wwenetwork
# app ---> app
# Learn ---> learn
# more ---> more
# http ---> http
# WWESurvivorSeries ---> wwesurvivorseri
# Catch ---> catch
# the ---> the
# final ---> final
# day ---> day
# of ---> of
# HCS ---> hcs
# Las ---> las
# Vegas ---> vega
# live ---> live
# on ---> on
# Twitch ---> twitch
# Halo ---> halo
# top ---> top
# players ---> player
# are ---> are
# competing ---> compet
# now ---> now
# http ---> http
# Now ---> now
# through ---> through
# November ---> novemb
# save ---> save
# when ---> when
# you ---> you
# buy ---> buy
# any ---> ani
# XboxOneS ---> xboxon
# console ---> consol
# or ---> or
# console ---> consol
# bundle ---> bundl
# http ---> http
# Halos ---> halo
# and ---> and
# Death ---> death
# Stars ---> star
# superweapons ---> superweapon
# are ---> are
# your ---> your
# specialty ---> specialti
# Stream ---> stream
# movies ---> movi
# and ---> and
# TV ---> tv
# with ---> with
# the ---> the
# new ---> new
# FandangoNOW ---> fandangonow
# app ---> app
# plus ---> plus
# get ---> get
# off ---> off
# your ---> your
# first ---> first
# transaction ---> transact
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Watch ---> watch
# UFC ---> ufc
# Fight ---> fight
# Night ---> night
# Mousasi ---> mousasi
# vs ---> vs
# Hall ---> hall
# today ---> today
# on ---> on
# the ---> the
# Xbox ---> xbox
# UFC ---> ufc
# app ---> app
# Learn ---> learn
# more ---> more
# http ---> http
# MLG ---> mlg
# and ---> and
# GearsofWar ---> gearsofwar
# M ---> m
# are ---> are
# back ---> back
# together ---> togeth
# for ---> for
# the ---> the
# first ---> first
# Pro ---> pro
# Circuit ---> circuit
# in ---> in
# years ---> year
# Be ---> be
# there ---> there
# November ---> novemb
# Passes ---> pass
# http ---> http
# Stand ---> stand
# by ---> by
# for ---> for
# savings ---> save
# M ---> m
# is ---> is
# now ---> now
# off ---> off
# http ---> http
# We ---> we
# down ---> down
# with ---> with
# this ---> this
# plan ---> plan
# Only ---> onli
# because ---> becaus
# of ---> of
# awesome ---> awesom
# fans ---> fan
# like ---> like
# you ---> you
# We ---> we
# love ---> love
# living ---> live
# in ---> in
# the ---> the
# future ---> futur
# Better ---> better
# catnip ---> catnip
# than ---> than
# something ---> someth
# like ---> like
# skooma ---> skooma
# Get ---> get
# days ---> day
# free ---> free
# of ---> of
# Sling ---> sling
# TV ---> tv
# exclusively ---> exclus
# on ---> on
# XboxOne ---> xboxon
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# You ---> you
# a ---> a
# five ---> five
# star ---> star
# fan ---> fan
# Sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Very ---> veri
# nice ---> nice
# Talk ---> talk
# about ---> about
# a ---> a
# classic ---> classic
# Play ---> play
# E ---> e
# free ---> free
# this ---> this
# weekend ---> weekend
# with ---> with
# XboxLive ---> xboxliv
# Gold ---> gold
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# You ---> you
# got ---> got
# this ---> this
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# That ---> that
# what ---> what
# up ---> up
# Looks ---> look
# like ---> like
# you ---> you
# got ---> got
# a ---> a
# ton ---> ton
# of ---> of
# awesome ---> awesom
# gaming ---> game
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Very ---> veri
# nice ---> nice
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# Thanks ---> thank
# so ---> so
# much ---> much
# Mark ---> mark
# Glad ---> glad
# we ---> we
# could ---> could
# hook ---> hook
# you ---> you
# up ---> up
# with ---> with
# so ---> so
# many ---> mani
# other ---> other
# awesome ---> awesom
# gamers ---> gamer
# This ---> this
# weekend ---> weekend
# play ---> play
# Overwatch ---> overwatch
# T ---> t
# for ---> for
# free ---> free
# Start ---> start
# playing ---> play
# today ---> today
# on ---> on
# XboxOne ---> xboxon
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Thanks ---> thank
# for ---> for
# picking ---> pick
# up ---> up
# so ---> so
# many ---> mani
# cool ---> cool
# games ---> game
# Are ---> are
# you ---> you
# all ---> all
# set ---> set
# for ---> for
# the ---> the
# winter ---> winter
# It ---> it
# so ---> so
# hard ---> hard
# to ---> to
# narrow ---> narrow
# down ---> down
# that ---> that
# wish ---> wish
# list ---> list
# Have ---> have
# fun ---> fun
# with ---> with
# whatever ---> whatev
# you ---> you
# decide ---> decid
# to ---> to
# pick ---> pick
# up ---> up
# Scott ---> scott
# This ---> this
# Week ---> week
# on ---> on
# Xbox ---> xbox
# join ---> join
# us ---> us
# for ---> for
# the ---> the
# release ---> releas
# of ---> of
# M ---> m
# and ---> and
# a ---> a
# look ---> look
# at ---> at
# BlackFriday ---> blackfriday
# http ---> http
# That ---> that
# what ---> what
# up ---> up
# What ---> what
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# your ---> your
# clips ---> clip
# That ---> that
# a ---> a
# good ---> good
# problem ---> problem
# to ---> to
# have ---> have
# in ---> in
# our ---> our
# opinions ---> opinion
# D ---> d
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# Here ---> here
# to ---> to
# many ---> mani
# more ---> more
# awesome ---> awesom
# gaming ---> game
# moments ---> moment
# in ---> in
# the ---> the
# future ---> futur
# This ---> this
# holiday ---> holiday
# make ---> make
# it ---> it
# theirs ---> their
# with ---> with
# an ---> an
# XboxDesignLab ---> xboxdesignlab
# Digital ---> digit
# Code ---> code
# Learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Cry ---> cri
# havoc ---> havoc
# and ---> and
# let ---> let
# slip ---> slip
# the ---> the
# huskies ---> huski
# of ---> of
# war ---> war
# Go ---> go
# Gold ---> gold
# for ---> for
# and ---> and
# enjoy ---> enjoy
# early ---> earli
# access ---> access
# to ---> to
# this ---> this
# year ---> year
# Xbox ---> xbox
# BlackFriday ---> blackfriday
# savings ---> save
# Learn ---> learn
# more ---> more
# http ---> http
# Looks ---> look
# like ---> like
# Player ---> player
# has ---> has
# entered ---> enter
# the ---> the
# game ---> game
# We ---> we
# got ---> got
# some ---> some
# extra ---> extra
# deals ---> deal
# coming ---> come
# up ---> up
# next ---> next
# weekend ---> weekend
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# that ---> that
# it ---> it
# such ---> such
# a ---> a
# vivid ---> vivid
# memory ---> memori
# No ---> no
# problem ---> problem
# Everyone ---> everyon
# getting ---> get
# excited ---> excit
# for ---> for
# it ---> it
# Design ---> design
# share ---> share
# and ---> and
# tag ---> tag
# a ---> a
# controller ---> control
# with ---> with
# XboxDesignLab ---> xboxdesignlab
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# Rules ---> rule
# http ---> http
# So ---> so
# fresh ---> fresh
# and ---> and
# so ---> so
# clean ---> clean
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Joe ---> joe
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# Hopefully ---> hope
# you ---> you
# get ---> get
# some ---> some
# epic ---> epic
# games ---> game
# with ---> with
# the ---> the
# club ---> club
# Got ---> got
# ta ---> ta
# rep ---> rep
# the ---> the
# Ravens ---> raven
# Flock ---> flock
# right ---> right
# Awesome ---> awesom
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# Lindsey ---> lindsey
# Wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Shawn ---> shawn
# Nice ---> nice
# What ---> what
# do ---> do
# you ---> you
# think ---> think
# of ---> of
# it ---> it
# so ---> so
# far ---> far
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Drew ---> drew
# It ---> it
# for ---> for
# project ---> project
# Scorpio ---> scorpio
# They ---> they
# tell ---> tell
# stories ---> stori
# of ---> of
# your ---> your
# time ---> time
# in ---> in
# Tamriel ---> tamriel
# We ---> we
# already ---> alreadi
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Thanks ---> thank
# so ---> so
# much ---> much
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# all ---> all
# the ---> the
# awesome ---> awesom
# stuff ---> stuff
# ahead ---> ahead
# Great ---> great
# work ---> work
# The ---> the
# gun ---> gun
# looks ---> look
# awesome ---> awesom
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# all ---> all
# set ---> set
# to ---> to
# go ---> go
# Have ---> have
# fun ---> fun
# We ---> we
# hope ---> hope
# to ---> to
# see ---> see
# you ---> you
# soon ---> soon
# Andrew ---> andrew
# We ---> we
# wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# You ---> you
# have ---> have
# great ---> great
# taste ---> tast
# in ---> in
# games ---> game
# RT ---> rt
# now ---> now
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# M ---> m
# bundle ---> bundl
# Sweepstakes ---> sweepstak
# Rules ---> rule
# http ---> http
# Let ---> let
# just ---> just
# assume ---> assum
# it ---> it
# all ---> all
# the ---> the
# clips ---> clip
# Awesome ---> awesom
# work ---> work
# Thanks ---> thank
# Joe ---> joe
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Sounds ---> sound
# like ---> like
# you ---> you
# on ---> on
# your ---> your
# way ---> way
# to ---> to
# your ---> your
# dream ---> dream
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# There ---> there
# no ---> no
# words ---> word
# that ---> that
# could ---> could
# describe ---> describ
# our ---> our
# love ---> love
# Good ---> good
# plan ---> plan
# Briana ---> briana
# What ---> what
# are ---> are
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# And ---> and
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Haden ---> haden
# Very ---> veri
# nice ---> nice
# Here ---> here
# to ---> to
# many ---> mani
# more ---> more
# rare ---> rare
# achievements ---> achiev
# in ---> in
# the ---> the
# future ---> futur
# Awesome ---> awesom
# Which ---> which
# achievement ---> achiev
# was ---> was
# it ---> it
# Sounds ---> sound
# like ---> like
# it ---> it
# about ---> about
# to ---> to
# be ---> be
# an ---> an
# awesome ---> awesom
# birthday ---> birthday
# We ---> we
# glad ---> glad
# you ---> you
# loving ---> love
# it ---> it
# Joey ---> joey
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# It ---> it
# still ---> still
# as ---> as
# beautiful ---> beauti
# as ---> as
# ever ---> ever
# Sounds ---> sound
# like ---> like
# a ---> a
# good ---> good
# day ---> day
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# We ---> we
# hear ---> hear
# that ---> that
# At ---> at
# least ---> least
# we ---> we
# on ---> on
# the ---> the
# home ---> home
# stretch ---> stretch
# You ---> you
# ca ---> ca
# help ---> help
# but ---> but
# be ---> be
# holly ---> holli
# and ---> and
# jolly ---> jolli
# Congrats ---> congrat
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# play ---> play
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> have
# so ---> so
# much ---> much
# fun ---> fun
# You ---> you
# still ---> still
# got ---> got
# great ---> great
# skills ---> skill
# Dylan ---> dylan
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# still ---> still
# finding ---> find
# some ---> some
# play ---> play
# time ---> time
# Emmarie ---> emmari
# We ---> we
# love ---> love
# that ---> that
# series ---> seri
# That ---> that
# sounds ---> sound
# like ---> like
# a ---> a
# great ---> great
# idea ---> idea
# to ---> to
# us ---> us
# Sometimes ---> sometim
# you ---> you
# just ---> just
# got ---> got
# to ---> to
# play ---> play
# You ---> you
# got ---> got
# this ---> this
# There ---> there
# plenty ---> plenti
# of ---> of
# great ---> great
# games ---> game
# ahead ---> ahead
# to ---> to
# help ---> help
# you ---> you
# out ---> out
# It ---> it
# sure ---> sure
# does ---> doe
# Fans ---> fan
# like ---> like
# you ---> you
# are ---> are
# why ---> whi
# we ---> we
# do ---> do
# what ---> what
# we ---> we
# do ---> do
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Nice ---> nice
# What ---> what
# was ---> was
# your ---> your
# favorite ---> favorit
# game ---> game
# to ---> to
# play ---> play
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# BlackFriday ---> blackfriday
# deals ---> deal
# are ---> are
# coming ---> come
# soon ---> soon
# Get ---> get
# early ---> earli
# access ---> access
# with ---> with
# XboxLive ---> xboxliv
# Gold ---> gold
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Good ---> good
# luck ---> luck
# with ---> with
# your ---> your
# new ---> new
# club ---> club
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# Have ---> have
# fun ---> fun
# with ---> with
# the ---> the
# new ---> new
# features ---> featur
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# Unlock ---> unlock
# the ---> the
# true ---> true
# colors ---> color
# of ---> of
# your ---> your
# games ---> game
# and ---> and
# entertainment ---> entertain
# with ---> with
# HDR ---> hdr
# http ---> http
# XboxOneS ---> xboxon
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# share ---> share
# the ---> the
# next ---> next
# years ---> year
# Great ---> great
# clip ---> clip
# Nice ---> nice
# shot ---> shot
# It ---> it
# definitely ---> definit
# worth ---> worth
# writing ---> write
# home ---> home
# about ---> about
# Now ---> now
# that ---> that
# one ---> one
# look ---> look
# you ---> you
# can ---> can
# never ---> never
# outgrow ---> outgrow
# Have ---> have
# fun ---> fun
# Commander ---> command
# That ---> that
# the ---> the
# plan ---> plan
# Ryan ---> ryan
# That ---> that
# must ---> must
# been ---> been
# a ---> a
# very ---> veri
# happy ---> happi
# Christmas ---> christma
# day ---> day
# Making ---> make
# great ---> great
# friends ---> friend
# online ---> onlin
# is ---> is
# definitely ---> definit
# our ---> our
# favorite ---> favorit
# feature ---> featur
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# Scorpio ---> scorpio
# either ---> either
# Thanks ---> thank
# for ---> for
# sharing ---> share
# your ---> your
# pride ---> pride
# Thanks ---> thank
# for ---> for
# the ---> the
# birthday ---> birthday
# wishes ---> wish
# Mark ---> mark
# We ---> we
# just ---> just
# getting ---> get
# started ---> start
# It ---> it
# never ---> never
# too ---> too
# late ---> late
# We ---> we
# glad ---> glad
# to ---> to
# have ---> have
# you ---> you
# with ---> with
# us ---> us
# Xbox ---> xbox
# fans ---> fan
# can ---> can
# be ---> be
# any ---> ani
# age ---> age
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# so ---> so
# long ---> long
# Thanks ---> thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# fan ---> fan
# We ---> we
# love ---> love
# you ---> you
# too ---> too
# Thanks ---> thank
# Eric ---> eric
# Game ---> game
# on ---> on
# Sounds ---> sound
# like ---> like
# an ---> an
# awesome ---> awesom
# club ---> club
# That ---> that
# was ---> was
# an ---> an
# epic ---> epic
# console ---> consol
# too ---> too
# Game ---> game
# on ---> on
# Welcome ---> welcom
# back ---> back
# Glad ---> glad
# that ---> that
# it ---> it
# held ---> held
# such ---> such
# an ---> an
# important ---> import
# place ---> place
# in ---> in
# your ---> your
# life ---> life
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Aww ---> aww
# thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# What ---> what
# an ---> an
# awesome ---> awesom
# family ---> famili
# portrait ---> portrait
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Blood ---> blood
# Dragon ---> dragon
# M ---> m
# and ---> and
# Murdered ---> murder
# Soul ---> soul
# Suspect ---> suspect
# M ---> m
# are ---> are
# now ---> now
# on ---> on
# GamesWithGold ---> gameswithgold
# Start ---> start
# playing ---> play
# today ---> today
# http ---> http
# Nice ---> nice
# to ---> to
# hear ---> hear
# Thanks ---> thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedic
# fan ---> fan
# That ---> that
# awesome ---> awesom
# Travis ---> travi
# Sounds ---> sound
# like ---> like
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# quite ---> quit
# some ---> some
# time ---> time
# Thanks ---> thank
# for ---> for
# all ---> all
# the ---> the
# awesome ---> awesom
# years ---> year
# of ---> of
# gaming ---> game
# with ---> with
# us ---> us
# And ---> and
# that ---> that
# you ---> you
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesom
# gamer ---> gamer
# and ---> and
# fan ---> fan
# Canvas ---> canva
# does ---> doe
# matter ---> matter
# without ---> without
# artists ---> artist
# like ---> like
# yourself ---> yourself
# Thanks ---> thank
# for ---> for
# all ---> all
# your ---> your
# awesome ---> awesom
# work ---> work
# You ---> you
# very ---> veri
# welcome ---> welcom
# Have ---> have
# you ---> you
# set ---> set
# up ---> up
# your ---> your
# own ---> own
# yet ---> yet
# Or ---> or
# have ---> have
# you ---> you
# found ---> found
# some ---> some
# fun ---> fun
# ones ---> one
# to ---> to
# join ---> join
# Thanks ---> thank
# much ---> much
# We ---> we
# so ---> so
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# Aditya ---> aditya
# It ---> it
# been ---> been
# a ---> a
# wild ---> wild
# ride ---> ride
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# The ---> the
# future ---> futur
# is ---> is
# bright ---> bright
# Ben ---> ben
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# this ---> this
# time ---> time
# Thanks ---> thank
# so ---> so
# much ---> much
# Jeff ---> jeff
# And ---> and
# thank ---> thank
# you ---> you
# Nathan ---> nathan
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesom
# gamer ---> gamer
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# it ---> it
# That ---> that
# alright ---> alright
# The ---> the
# party ---> parti
# still ---> still
# going ---> go
# Thank ---> thank
# you ---> you
# LFG ---> lfg
# on ---> on
# XBL ---> xbl
# Our ---> our
# newest ---> newest
# update ---> updat
# lets ---> let
# you ---> you
# search ---> search
# for ---> for
# teammates ---> teammat
# by ---> by
# objective ---> object
# playstyle ---> playstyl
# and ---> and
# more ---> more
# XboxLive ---> xboxliv
# http ---> http
# They ---> they
# be ---> be
# many ---> mani
# more ---> more
# for ---> for
# sure ---> sure
# Jay ---> jay
# Thanks ---> thank
# for ---> for
# the ---> the
# greeting ---> greet
# Got ---> got
# ta ---> ta
# agree ---> agre
# with ---> with
# you ---> you
# there ---> there
# Andrew ---> andrew
# Here ---> here
# to ---> to
# years ---> year
# of ---> of
# games ---> game
# achievements ---> achiev
# friendships ---> friendship
# and ---> and
# memories ---> memori
# Thank ---> thank
# you ---> you
# Hack ---> hack
# Everything ---> everyth
# M ---> m
# comes ---> come
# to ---> to
# XboxOne ---> xboxon
# today ---> today
# http ---> http
# And ---> and
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Totally ---> total
# radical ---> radic
# controller ---> control
# We ---> we
# so ---> so
# thankful ---> thank
# for ---> for
# fans ---> fan
# like ---> like
# you ---> you
# Anthony ---> anthoni
# What ---> what
# been ---> been
# your ---> your
# favorite ---> favorit
# gaming ---> game
# moment ---> moment
# It ---> it
# a ---> a
# deathmatch ---> deathmatch
# made ---> made
# in ---> in
# heaven ---> heaven
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# RT ---> rt
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# a ---> a
# Military ---> militari
# Green ---> green
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# bundle ---> bundl
# Rules ---> rule
# http ---> http
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# From ---> from
# the ---> the
# beginning ---> begin
# It ---> it
# great ---> great
# to ---> to
# have ---> have
# awesome ---> awesom
# fans ---> fan
# That ---> that
# awesome ---> awesom
# Thanks ---> thank
# for ---> for
# sharing ---> share
# your ---> your
# memory ---> memori
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# chance ---> chanc
# to ---> to
# pick ---> pick
# one ---> one
# up ---> up
# Thanks ---> thank
# Thanks ---> thank
# for ---> for
# years ---> year
# of ---> of
# awesomeness ---> awesom
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Talan ---> talan
# Stay ---> stay
# awesome ---> awesom
# And ---> and
# thank ---> thank
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gamer
# You ---> you
# know ---> know
# it ---> it
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# of ---> of
# Halo ---> halo
# awesomeness ---> awesom
# Which ---> which
# one ---> one
# did ---> did
# you ---> you
# grow ---> grow
# up ---> up
# with ---> with
# Thanks ---> thank
# Here ---> here
# to ---> to
# more ---> more
# That ---> that
# a ---> a
# great ---> great
# story ---> stori
# Mac ---> mac
# Thanks ---> thank
# for ---> for
# sharing ---> share
# The ---> the
# ride ---> ride
# not ---> not
# over ---> over
# yet ---> yet
# Christian ---> christian
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Why ---> whi
# thank ---> thank
# you ---> you
# Daniel ---> daniel
# Here ---> here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# If ---> if
# you ---> you
# like ---> like
# we ---> we
# highly ---> high
# recommend ---> recommend
# Super ---> super
# Dungeon ---> dungeon
# Bros ---> bros
# and ---> and
# Overcooked ---> overcook
# Cheers ---> cheer
# You ---> you
# have ---> have
# very ---> veri
# good ---> good
# taste ---> tast
# in ---> in
# birthdays ---> birthday
# We ---> we
# definitely ---> definit
# will ---> will
# You ---> you
# can ---> can
# celebrate ---> celebr
# by ---> by
# playing ---> play
# some ---> some
# Xbox ---> xbox
# tonight ---> tonight
# Today ---> today
# players ---> player
# get ---> get
# a ---> a
# Ford ---> ford
# Raptor ---> raptor
# with ---> with
# livery ---> liveri
# new ---> new
# Rivals ---> rival
# events ---> event
# and ---> and
# more ---> more
# http ---> http
# Thanks ---> thank
# Rodolfo ---> rodolfo
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# We ---> we
# forever ---> forev
# young ---> young
# Aiden ---> aiden
# Thanks ---> thank
# for ---> for
# being ---> be
# a ---> a
# great ---> great
# fan ---> fan
# Time ---> time
# flies ---> fli
# but ---> but
# the ---> the
# awesome ---> awesom
# memories ---> memori
# are ---> are
# here ---> here
# to ---> to
# stay ---> stay
# We ---> we
# loving ---> love
# the ---> the
# photo ---> photo
# Keep ---> keep
# on ---> on
# gaming ---> game
# and ---> and
# keep ---> keep
# on ---> on
# raging ---> rage
# Hunter ---> hunter
# It ---> it
# gamers ---> gamer
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# moving ---> move
# forward ---> forward
# Thanks ---> thank
# Zachary ---> zachari
# A ---> a
# very ---> veri
# happy ---> happi
# birthday ---> birthday
# to ---> to
# you ---> you
# Thank ---> thank
# you ---> you
# Shaun ---> shaun
# Thanks ---> thank
# for ---> for
# being ---> be
# part ---> part
# of ---> of
# the ---> the
# team ---> team
# We ---> we
# appreciate ---> appreci
# it ---> it
# With ---> with
# the ---> the
# best ---> best
# fans ---> fan
# of ---> of
# all ---> all
# time ---> time
# And ---> and
# thank ---> thank
# you ---> you
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# amazing ---> amaz
# fan ---> fan
# It ---> it
# our ---> our
# pleasure ---> pleasur
# We ---> we
# love ---> love
# to ---> to
# hear ---> hear
# you ---> you
# enjoying ---> enjoy
# ...
# CallofDuty ---> callofduti
# InfiniteWarfare ---> infinitewarfar
# M ---> m
# pack ---> pack
# XboxSweepstakes ---> xboxsweepstak
# rules ---> rule
# http ---> http
# In ---> in
# the ---> the
# last ---> last
# year ---> year
# we ---> we
# added ---> ad
# over ---> over
# games ---> game
# to ---> to
# BackwardCompatibility ---> backwardcompat
# Which ---> which
# were ---> were
# your ---> your
# favs ---> fav
# http ---> http
# Tune ---> tune
# in ---> in
# to ---> to
# see ---> see
# who ---> who
# qualifies ---> qualifi
# for ---> for
# the ---> the
# SMITE ---> smite
# T ---> t
# Console ---> consol
# World ---> world
# Championship ---> championship
# http ---> http
# SmitePro ---> smitepro
# Take ---> take
# back ---> back
# what ---> what
# yours ---> your
# M ---> m
# is ---> is
# available ---> avail
# now ---> now
# http ---> http
# This ---> this
# Week ---> week
# on ---> on
# Xbox ---> xbox
# BackwardCompatibility ---> backwardcompat
# turns ---> turn
# one ---> one
# M ---> m
# comes ---> come
# to ---> to
# Xbox ---> xbox
# and ---> and
# more ---> more
# http ---> http
# We ---> we
# most ---> most
# certainly ---> certain
# okay ---> okay
# with ---> with
# this ---> this
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# December ---> decemb
# We ---> we
# see ---> see
# if ---> if
# the ---> the
# other ---> other
# Koopa ---> koopa
# keep ---> keep
# up ---> up
# XboxOne ---> xboxon
# EASPORTSUFC ---> easportsufc
# T ---> t
# is ---> is
# now ---> now
# in ---> in
# the ---> the
# EAAccess ---> eaaccess
# Vault ---> vault
# Get ---> get
# a ---> a
# round ---> round
# in ---> in
# http ---> http
# Time ---> time
# to ---> to
# start ---> start
# marathoning ---> marathon
# in ---> in
# your ---> your
# Batcave ---> batcav
# XboxOne ---> xboxon
# Catch ---> catch
# today ---> today
# T ---> t
# Twitch ---> twitch
# stream ---> stream
# at ---> at
# PM ---> pm
# PT ---> pt
# PM ---> pm
# ET ---> et
# Tune ---> tune
# in ---> in
# at ---> at
# http ---> http
# That ---> that
# always ---> alway
# a ---> a
# great ---> great
# feeling ---> feel
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# playing ---> play
# You ---> you
# never ---> never
# gon ---> gon
# na ---> na
# have ---> have
# a ---> a
# good ---> good
# sauce ---> sauc
# again ---> again
# M ---> m
# http ---> http
# Follow ---> follow
# RT ---> rt
# for ---> for
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# an ---> an
# EAAccess ---> eaaccess
# code ---> code
# MassEffect ---> masseffect
# M ---> m
# M ---> m
# and ---> and
# M ---> m
# are ---> are
# waiting ---> wait
# http ---> http
# Sweepstakes ---> sweepstak
# Dishonored ---> dishonor
# M ---> m
# is ---> is
# live ---> live
# on ---> on
# Twitch ---> twitch
# Join ---> join
# the ---> the
# stream ---> stream
# for ---> for
# gameplay ---> gameplay
# chat ---> chat
# and ---> and
# a ---> a
# chance ---> chanc
# to ---> to
# win ---> win
# a ---> a
# prize ---> prize
# http ---> http
# STEEP ---> steep
# T ---> t
# Early ---> earli
# Access ---> access
# beta ---> beta
# is ---> is
# live ---> live
# Watch ---> watch
# the ---> the
# trailer ---> trailer
# and ---> and
# start ---> start
# your ---> your
# descent ---> descent
# at ---> at
# http ---> http
# The ---> the
# feeling ---> feel
# is ---> is
# mutual ---> mutual
# You ---> you
# welcome ---> welcom
# so ---> so
# much ---> much
# Jennifer ---> jennif
# Grab ---> grab
# your ---> your
# running ---> run
# gear ---> gear
# MirrorsEdge ---> mirrorsedg
# T ---> t
# and ---> and
# MirrorsEdgeCatalyst ---> mirrorsedgecatalyst
# T ---> t
# are ---> are
# now ---> now
# part ---> part
# of ---> of
# EAAccess ---> eaaccess
# http ---> http
# That ---> that
# great ---> great
# to ---> to
# hear ---> hear
# Will ---> will
# you ---> you
# be ---> be
# streaming ---> stream
# the ---> the
# game ---> game
# It ---> it
# a ---> a
# very ---> veri
# important ---> import
# aspect ---> aspect
# of ---> of
# his ---> his
# character ---> charact
# that ---> that
# people ---> peopl
# must ---> must
# know ---> know
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# Got ---> got
# your ---> your
# copy ---> copi
# preordered ---> preorder
# yet ---> yet
# Talk ---> talk
# about ---> about
# a ---> a
# blast ---> blast
# from ---> from
# the ---> the
# past ---> past
# Stay ---> stay
# awesome ---> awesom
# birthday ---> birthday
# buddy ---> buddi
# As ---> as
# a ---> a
# journalist ---> journalist
# Frank ---> frank
# is ---> is
# naturally ---> natur
# witty ---> witti
# He ---> he
# covered ---> cover
# wars ---> war
# you ---> you
# know ---> know
# Glad ---> glad
# that ---> that
# you ---> you
# liking ---> like
# what ---> what
# you ---> you
# seeing ---> see
# What ---> what
# part ---> part
# are ---> are
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# not ---> not
# too ---> too
# terrible ---> terribl
# of ---> of
# a ---> a
# problem ---> problem
# to ---> to
# have ---> have
# That ---> that
# because ---> becaus
# you ---> you
# are ---> are
# Glad ---> glad
# you ---> you
# think ---> think
# so ---> so
# We ---> we
# guess ---> guess
# you ---> you
# still ---> still
# got ---> got
# the ---> the
# flick ---> flick
# then ---> then
# That ---> that
# awesome ---> awesom
# to ---> to
# hear ---> hear
# You ---> you
# going ---> go
# to ---> to
# have ---> have
# an ---> an
# amazing ---> amaz
# holiday ---> holiday
# season ---> season
# Looking ---> look
# good ---> good
# Aaron ---> aaron
# What ---> what
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# break ---> break
# it ---> it
# in ---> in
# with ---> with
# Xbox ---> xbox
# is ---> is
# love ---> love
# It ---> it
# been ---> been
# a ---> a
# great ---> great
# day ---> day
# for ---> for
# Backwards ---> backward
# Compatibility ---> compat
# D ---> d
# Shoutouts ---> shoutout
# to ---> to
# your ---> your
# son ---> son
# Thanks ---> thank
# for ---> for
# sharing ---> share
# The ---> the
# anticipation ---> anticip
# is ---> is
# already ---> alreadi
# getting ---> get
# hard ---> hard
# to ---> to
# handle ---> handl
# We ---> we
# guessing ---> guess
# someone ---> someon
# excited ---> excit
# The ---> the
# first ---> first
# of ---> of
# many ---> mani
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# the ---> the
# feature ---> featur
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Woot ---> woot
# woot ---> woot
# Have ---> have
# fun ---> fun
# T ---> t
# is ---> is
# now ---> now
# playable ---> playabl
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Buy ---> buy
# it ---> it
# today ---> today
# and ---> and
# save ---> save
# http ---> http
# Happy ---> happi
# birthday ---> birthday
# in ---> in
# advance ---> advanc
# Dear ---> dear
# Chris ---> chris
# Thank ---> thank
# you ---> you
# for ---> for
# taking ---> take
# the ---> the
# time ---> time
# to ---> to
# slay ---> slay
# bosses ---> boss
# with ---> with
# us ---> us
# It ---> it
# has ---> has
# been ---> been
# too ---> too
# long ---> long
# and ---> and
# we ---> we
# missed ---> miss
# you ---> you
# Love ---> love
# Xbox ---> xbox
# We ---> we
# glad ---> glad
# you ---> you
# like ---> like
# it ---> it
# You ---> you
# better ---> better
# believe ---> believ
# it ---> it
# Here ---> here
# to ---> to
# that ---> that
# birthday ---> birthday
# twin ---> twin
# We ---> we
# hope ---> hope
# you ---> you
# had ---> had
# a ---> a
# great ---> great
# night ---> night
# Great ---> great
# work ---> work
# Meet ---> meet
# XboxLive ---> xboxliv
# newest ---> newest
# features ---> featur
# Looking ---> look
# for ---> for
# Group ---> group
# and ---> and
# Clubs ---> club
# http ---> http
# FUS ---> fus
# RO ---> ro
# MOD ---> mod
# Skyrim ---> skyrim
# Special ---> special
# Edition ---> edit
# M ---> m
# is ---> is
# now ---> now
# available ---> avail
# and ---> and
# moddable ---> moddabl
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Have ---> have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Playing ---> play
# games ---> game
# is ---> is
# a ---> a
# great ---> great
# way ---> way
# to ---> to
# unwind ---> unwind
# We ---> we
# hope ---> hope
# you ---> you
# feel ---> feel
# better ---> better
# afterward ---> afterward
# Sounds ---> sound
# like ---> like
# the ---> the
# perfect ---> perfect
# way ---> way
# to ---> to
# unwind ---> unwind
# Fight ---> fight
# like ---> like
# hell ---> hell
# Intense ---> intens
# Thanks ---> thank
# for ---> for
# sharing ---> share
# the ---> the
# clip ---> clip
# That ---> that
# probably ---> probabl
# because ---> becaus
# it ---> it
# is ---> is
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# well ---> well
# We ---> we
# got ---> got
# your ---> your
# back ---> back
# Very ---> veri
# nice ---> nice
# choice ---> choic
# So ---> so
# much ---> much
# replay ---> replay
# value ---> valu
# Great ---> great
# work ---> work
# Shane ---> shane
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# What ---> what
# game ---> game
# is ---> is
# up ---> up
# next ---> next
# Good ---> good
# call ---> call
# We ---> we
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chanc
# to ---> to
# pick ---> pick
# it ---> it
# up ---> up
# soon ---> soon
# You ---> you
# welcome ---> welcom
# Are ---> are
# you ---> you
# going ---> go
# Paragon ---> paragon
# or ---> or
# Renegade ---> renegad
# Very ---> veri
# nice ---> nice
# Standby ---> standbi
# for ---> for
# awesomeness ---> awesom
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# Absolutely ---> absolut
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# working ---> work
# on ---> on
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# enjoying ---> enjoy
# the ---> the
# game ---> game
# Nice ---> nice
# Have ---> have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# all ---> all
# of ---> of
# them ---> them
# You ---> you
# know ---> know
# it ---> it
# Have ---> have
# fun ---> fun
# and ---> and
# good ---> good
# luck ---> luck
# on ---> on
# your ---> your
# test ---> test
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# call ---> call
# an ---> an
# army ---> armi
# of ---> of
# two ---> two
# XboxOne ---> xboxon
# It ---> it
# fans ---> fan
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# going ---> go
# It ---> it
# great ---> great
# seeing ---> see
# those ---> those
# enemies ---> enemi
# just ---> just
# hanging ---> hang
# up ---> up
# there ---> there
# We ---> we
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# No ---> no
# problem ---> problem
# But ---> but
# with ---> with
# your ---> your
# skill ---> skill
# we ---> we
# think ---> think
# you ---> you
# got ---> got
# this ---> this
# Game ---> game
# on ---> on
# Nathan ---> nathan
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# videos ---> video
# Awesome ---> awesom
# Have ---> have
# you ---> you
# been ---> been
# playing ---> play
# Infinite ---> infinit
# Warfare ---> warfar
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# Family ---> famili
# What ---> what
# games ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# be ---> be
# playing ---> play
# You ---> you
# have ---> have
# great ---> great
# taste ---> tast
# in ---> in
# games ---> game
# Leah ---> leah
# Good ---> good
# luck ---> luck
# against ---> against
# the ---> the
# hordes ---> hord
# Alex ---> alex
# Massive ---> massiv
# You ---> you
# welcome ---> welcom
# Korie ---> kori
# A ---> a
# good ---> good
# night ---> night
# indeed ---> inde
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# blast ---> blast
# There ---> there
# a ---> a
# lot ---> lot
# of ---> of
# stuff ---> stuff
# to ---> to
# take ---> take
# care ---> care
# of ---> of
# in ---> in
# Gotham ---> gotham
# Good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# love ---> love
# it ---> it
# so ---> so
# much ---> much
# What ---> what
# your ---> your
# favorite ---> favorit
# game ---> game
# to ---> to
# play ---> play
# on ---> on
# it ---> it
# This ---> this
# week ---> week
# XboxCharityChallenge ---> xboxcharitychalleng
# throws ---> throw
# back ---> back
# to ---> to
# with ---> with
# Watch ---> watch
# live ---> live
# now ---> now
# http ---> http
# It ---> it
# nothing ---> noth
# but ---> but
# love ---> love
# here ---> here
# Clifton ---> clifton
# Stay ---> stay
# awesome ---> awesom
# Well ---> well
# the ---> the
# colors ---> color
# do ---> do
# match ---> match
# your ---> your
# avatar ---> avatar
# so ---> so
# we ---> we
# think ---> think
# they ---> they
# cool ---> cool
# Have ---> have
# a ---> a
# great ---> great
# stream ---> stream
# Nyree ---> nyre
# Glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# How ---> how
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# so ---> so
# far ---> far
# It ---> it
# really ---> realli
# is ---> is
# worth ---> worth
# it ---> it
# Keith ---> keith
# Terminal ---> termin
# was ---> was
# easily ---> easili
# one ---> one
# of ---> of
# our ---> our
# favorite ---> favorit
# maps ---> map
# You ---> you
# have ---> have
# good ---> good
# taste ---> tast
# If ---> if
# not ---> not
# you ---> you
# can ---> can
# always ---> alway
# grab ---> grab
# an ---> an
# external ---> extern
# hard ---> hard
# drive ---> drive
# How ---> how
# are ---> are
# you ---> you
# liking ---> like
# it ---> it
# so ---> so
# far ---> far
# Nice ---> nice
# plan ---> plan
# Which ---> which
# squad ---> squad
# mate ---> mate
# are ---> are
# you ---> you
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# again ---> again
# the ---> the
# most ---> most
# What ---> what
# up ---> up
# Troy ---> troy
# That ---> that
# an ---> an
# excellent ---> excel
# option ---> option
# Good ---> good
# luck ---> luck
# Breaks ---> break
# your ---> your
# heart ---> heart
# and ---> and
# forces ---> forc
# a ---> a
# restart ---> restart
# from ---> from
# the ---> the
# beginning ---> begin
# We ---> we
# also ---> also
# make ---> make
# sure ---> sure
# that ---> that
# it ---> it
# a ---> a
# Suicide ---> suicid
# Mission ---> mission
# in ---> in
# name ---> name
# only ---> onli
# Mass ---> mass
# Effect ---> effect
# and ---> and
# are ---> are
# available ---> avail
# digitally ---> digit
# through ---> through
# EA ---> ea
# Access ---> access
# here ---> here
# Thank ---> thank
# goodness ---> good
# Whatcha ---> whatcha
# playing ---> play
# We ---> we
# love ---> love
# Jack ---> jack
# Though ---> though
# we ---> we
# ca ---> ca
# really ---> realli
# repeat ---> repeat
# any ---> ani
# of ---> of
# our ---> our
# favorite ---> favorit
# quotes ---> quot
# though ---> though
# There ---> there
# is ---> is
# an ---> an
# option ---> option
# to ---> to
# go ---> go
# back ---> back
# to ---> to
# Xbox ---> xbox
# commands ---> command
# You ---> you
# can ---> can
# find ---> find
# out ---> out
# how ---> how
# here ---> here
# http ---> http
# You ---> you
# mean ---> mean
# that ---> that
# out ---> out
# of ---> of
# all ---> all
# your ---> your
# pinend ---> pinend
# apps ---> app
# it ---> it
# First ---> first
# We ---> we
# love ---> love
# how ---> how
# it ---> it
# brings ---> bring
# people ---> peopl
# together ---> togeth
# Say ---> say
# whattt ---> whattt
# The ---> the
# day ---> day
# not ---> not
# over ---> over
# yet ---> yet
# Now ---> now
# that ---> that
# sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# We ---> we
# sure ---> sure
# you ---> you
# love ---> love
# it ---> it
# Let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# Welcome ---> welcom
# back ---> back
# Michelle ---> michell
# It ---> it
# like ---> like
# riding ---> ride
# a ---> a
# bicycle ---> bicycl
# Made ---> made
# out ---> out
# of ---> of
# guns ---> gun
# Sounds ---> sound
# like ---> like
# a ---> a
# Monday ---> monday
# well ---> well
# spent ---> spent
# to ---> to
# us ---> us
# We ---> we
# applaud ---> applaud
# his ---> his
# dedication ---> dedic
# Epic ---> epic
# clip ---> clip
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# Have ---> have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# through ---> through
# them ---> them
# Thanks ---> thank
# Jon ---> jon
# Will ---> will
# you ---> you
# be ---> be
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# soon ---> soon
# A ---> a
# great ---> great
# day ---> day
# indeed ---> inde
# Are ---> are
# you ---> you
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# right ---> right
# now ---> now
# Incredible ---> incred
# Your ---> your
# gamerscore ---> gamerscor
# must ---> must
# be ---> be
# crazy ---> crazi
# Awesome ---> awesom
# What ---> what
# game ---> game
# were ---> were
# you ---> you
# streaming ---> stream
# And ---> and
# then ---> then
# we ---> we
# responded ---> respond
# on ---> on
# yours ---> your
# Everyone ---> everyon
# can ---> can
# enjoy ---> enjoy
# Xbox ---> xbox
# But ---> but
# it ---> it
# great ---> great
# to ---> to
# hear ---> hear
# that ---> that
# we ---> we
# can ---> can
# bring ---> bring
# generations ---> generat
# together ---> togeth
# Someone ---> someon
# in ---> in
# for ---> for
# a ---> a
# very ---> veri
# bad ---> bad
# day ---> day
# She ---> she
# looks ---> look
# like ---> like
# a ---> a
# serious ---> serious
# piece ---> piec
# of ---> of
# hardware ---> hardwar
# Mel ---> mel

# %% [markdown]
# ## Lancaster Stemming

# %%
from nltk.stem import LancasterStemmer
lancaster = LancasterStemmer()

for token in tokens:
  print(token,"--->", lancaster.stem(token))
# Out:
# Feeling ---> feel
# thankful ---> thank
# Tag ---> tag
# friends ---> friend
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# M ---> m
# digital ---> digit
# codes ---> cod
# Rules ---> rul
# http ---> http
# Holiday ---> holiday
# parties ---> party
# are ---> ar
# the ---> the
# worst ---> worst
# M ---> m
# http ---> http
# Now ---> now
# through ---> through
# Monday ---> monday
# enjoy ---> enjoy
# free ---> fre
# engraving ---> engrav
# on ---> on
# all ---> al
# XboxDesignLab ---> xboxdesignlab
# controllers ---> control
# Start ---> start
# building ---> build
# yours ---> yo
# at ---> at
# http ---> http
# Make ---> mak
# your ---> yo
# own ---> own
# zombie ---> zomby
# musical ---> mus
# number ---> numb
# inspired ---> inspir
# by ---> by
# M ---> m
# http ---> http
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# FFXV ---> ffxv
# T ---> t
# The ---> the
# Division ---> divid
# M ---> m
# Survival ---> surv
# and ---> and
# Episode ---> episod
# of ---> of
# telltalegames ---> telltalegam
# Batman ---> batm
# M ---> m
# http ---> http
# Celebrate ---> celebr
# woodyinho ---> woodyinho
# jamesrodriguez ---> jamesrodriguez
# anthonymartial ---> anthonymart
# in ---> in
# the ---> the
# E ---> e
# free ---> fre
# trial ---> tri
# out ---> out
# now ---> now
# http ---> http
# Sounds ---> sound
# like ---> lik
# Austin ---> austin
# is ---> is
# a ---> a
# pretty ---> pretty
# good ---> good
# player ---> play
# huh ---> huh
# We ---> we
# glad ---> glad
# you ---> you
# had ---> had
# a ---> a
# successful ---> success
# Black ---> black
# Friday ---> friday
# What ---> what
# games ---> gam
# did ---> did
# you ---> you
# get ---> get
# Which ---> which
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# choosing ---> choos
# If ---> if
# that ---> that
# is ---> is
# true ---> tru
# love ---> lov
# then ---> then
# we ---> we
# do ---> do
# know ---> know
# what ---> what
# is ---> is
# Which ---> which
# bundle ---> bundl
# did ---> did
# you ---> you
# get ---> get
# him ---> him
# Awesome ---> awesom
# is ---> is
# right ---> right
# Did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# it ---> it
# Those ---> thos
# are ---> ar
# the ---> the
# best ---> best
# What ---> what
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# We ---> we
# say ---> say
# you ---> you
# were ---> wer
# pretty ---> pretty
# successful ---> success
# We ---> we
# love ---> lov
# that ---> that
# idea ---> ide
# What ---> what
# did ---> did
# you ---> you
# play ---> play
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> on
# family ---> famy
# What ---> what
# games ---> gam
# did ---> did
# you ---> you
# get ---> get
# We ---> we
# glad ---> glad
# you ---> you
# could ---> could
# take ---> tak
# advantage ---> adv
# of ---> of
# this ---> thi
# great ---> gre
# deal ---> deal
# Which ---> which
# will ---> wil
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# like ---> lik
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Which ---> which
# games ---> gam
# did ---> did
# you ---> you
# pick ---> pick
# We ---> we
# love ---> lov
# to ---> to
# hear ---> hear
# that ---> that
# Do ---> do
# you ---> you
# think ---> think
# you ---> you
# replay ---> replay
# it ---> it
# anytime ---> anytim
# soon ---> soon
# We ---> we
# know ---> know
# what ---> what
# that ---> that
# like ---> lik
# You ---> you
# get ---> get
# home ---> hom
# and ---> and
# game ---> gam
# yet ---> yet
# We ---> we
# love ---> lov
# the ---> the
# sound ---> sound
# of ---> of
# that ---> that
# Are ---> ar
# you ---> you
# hoping ---> hop
# for ---> for
# any ---> any
# specific ---> spec
# bundles ---> bundl
# We ---> we
# ca ---> ca
# wait ---> wait
# either ---> eith
# When ---> when
# do ---> do
# you ---> you
# plan ---> plan
# on ---> on
# getting ---> get
# one ---> on
# Personalized ---> person
# just ---> just
# for ---> for
# you ---> you
# We ---> we
# loving ---> lov
# this ---> thi
# design ---> design
# Sounds ---> sound
# like ---> lik
# the ---> the
# perfect ---> perfect
# birthday ---> birthday
# Which ---> which
# games ---> gam
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> get
# for ---> for
# Black ---> black
# Friday ---> friday
# Boom ---> boom
# That ---> that
# going ---> going
# to ---> to
# keep ---> keep
# you ---> you
# busy ---> busy
# Awesome ---> awesom
# Sounds ---> sound
# like ---> lik
# a ---> a
# pretty ---> pretty
# good ---> good
# Black ---> black
# Friday ---> friday
# huh ---> huh
# Thanks ---> thank
# for ---> for
# the ---> the
# shoutout ---> shoutout
# Did ---> did
# you ---> you
# get ---> get
# any ---> any
# other ---> oth
# games ---> gam
# along ---> along
# with ---> with
# Fifa ---> fif
# Sometimes ---> sometim
# it ---> it
# good ---> good
# to ---> to
# upgrade ---> upgrad
# Is ---> is
# this ---> thi
# all ---> al
# you ---> you
# got ---> got
# for ---> for
# your ---> yo
# gaming ---> gam
# set ---> set
# up ---> up
# Live ---> liv
# now ---> now
# Tune ---> tun
# in ---> in
# to ---> to
# the ---> the
# Gears ---> gear
# Pro ---> pro
# Circuit ---> circuit
# Open ---> op
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# http ---> http
# GearsofWar ---> gearsofw
# M ---> m
# Sounds ---> sound
# like ---> lik
# a ---> a
# pretty ---> pretty
# great ---> gre
# holiday ---> holiday
# Did ---> did
# you ---> you
# get ---> get
# a ---> a
# specific ---> spec
# bundle ---> bundl
# We ---> we
# loving ---> lov
# the ---> the
# color ---> col
# scheme ---> scheme
# You ---> you
# take ---> tak
# it ---> it
# for ---> for
# a ---> a
# spin ---> spin
# already ---> already
# Sounds ---> sound
# like ---> lik
# your ---> yo
# Black ---> black
# Friday ---> friday
# was ---> was
# a ---> a
# huge ---> hug
# success ---> success
# That ---> that
# a ---> a
# very ---> very
# good ---> good
# way ---> way
# to ---> to
# celebrate ---> celebr
# if ---> if
# you ---> you
# ask ---> ask
# us ---> us
# You ---> you
# better ---> bet
# believe ---> believ
# it ---> it
# For ---> for
# some ---> som
# things ---> thing
# an ---> an
# exception ---> exceiv
# must ---> must
# be ---> be
# made ---> mad
# Looks ---> look
# like ---> lik
# you ---> you
# made ---> mad
# the ---> the
# most ---> most
# of ---> of
# Black ---> black
# Friday ---> friday
# this ---> thi
# year ---> year
# At ---> at
# least ---> least
# you ---> you
# got ---> got
# the ---> the
# essentials ---> ess
# Technically ---> techn
# we ---> we
# do ---> do
# play ---> play
# DVD ---> dvd
# and ---> and
# Blu ---> blu
# Rays ---> ray
# sounds ---> sound
# like ---> lik
# a ---> a
# Looks ---> look
# like ---> lik
# it ---> it
# was ---> was
# your ---> yo
# Destiny ---> destiny
# to ---> to
# get ---> get
# great ---> gre
# deals ---> deal
# today ---> today
# Sounds ---> sound
# like ---> lik
# a ---> a
# very ---> very
# successful ---> success
# day ---> day
# Sounds ---> sound
# like ---> lik
# it ---> it
# was ---> was
# a ---> a
# good ---> good
# day ---> day
# We ---> we
# loving ---> lov
# the ---> the
# color ---> col
# Browse ---> brows
# BlackFriday ---> blackfriday
# deals ---> deal
# on ---> on
# top ---> top
# Xbox ---> xbox
# games ---> gam
# like ---> lik
# Skyrim ---> skyrim
# Special ---> spec
# Edition ---> edit
# M ---> m
# DOOM ---> doom
# M ---> m
# and ---> and
# more ---> mor
# http ---> http
# Awesome ---> awesom
# Trust ---> trust
# us ---> us
# the ---> the
# Horizon ---> horizon
# Festival ---> fest
# just ---> just
# keeps ---> keep
# getting ---> get
# better ---> bet
# Get ---> get
# the ---> the
# undead ---> undead
# party ---> party
# started ---> start
# Check ---> check
# out ---> out
# the ---> the
# M ---> m
# lens ---> len
# now ---> now
# on ---> on
# Snapchat ---> snapch
# Sounds ---> sound
# like ---> lik
# it ---> it
# gon ---> gon
# na ---> na
# be ---> be
# a ---> a
# good ---> good
# day ---> day
# Feel ---> feel
# the ---> the
# difference ---> diff
# Pick ---> pick
# up ---> up
# the ---> the
# XboxElite ---> xboxelit
# at ---> at
# a ---> a
# MicrosoftStore ---> microsoftst
# near ---> near
# you ---> you
# http ---> http
# Have ---> hav
# fun ---> fun
# Holli ---> holl
# Epic ---> ep
# We ---> we
# hope ---> hop
# you ---> you
# have ---> hav
# fun ---> fun
# That ---> that
# makes ---> mak
# you ---> you
# an ---> an
# awesome ---> awesom
# human ---> hum
# being ---> being
# You ---> you
# know ---> know
# it ---> it
# What ---> what
# have ---> hav
# you ---> you
# picked ---> pick
# up ---> up
# so ---> so
# far ---> far
# Woot ---> woot
# woot ---> woot
# Now ---> now
# that ---> that
# an ---> an
# awesome ---> awesom
# pick ---> pick
# up ---> up
# Grab ---> grab
# ahold ---> ahold
# of ---> of
# happiness ---> happy
# BlackFriday ---> blackfriday
# Get ---> get
# the ---> the
# XboxOneS ---> xboxon
# at ---> at
# our ---> our
# lowest ---> lowest
# price ---> pric
# yet ---> yet
# Shop ---> shop
# the ---> the
# BlackFriday ---> blackfriday
# sale ---> sal
# at ---> at
# http ---> http
# Every ---> every
# achievement ---> achiev
# is ---> is
# a ---> a
# tiny ---> tiny
# parade ---> parad
# Celebrate ---> celebr
# yours ---> yo
# this ---> thi
# Thanksgiving ---> thanksg
# Our ---> our
# gear ---> gear
# Your ---> yo
# design ---> design
# Start ---> start
# building ---> build
# your ---> yo
# Xbox ---> xbox
# controller ---> control
# at ---> at
# http ---> http
# XboxDesignLab ---> xboxdesignlab
# It ---> it
# just ---> just
# that ---> that
# many ---> many
# more ---> mor
# achievements ---> achiev
# for ---> for
# you ---> you
# to ---> to
# hunt ---> hunt
# XboxOne ---> xboxon
# The ---> the
# best ---> best
# controller ---> control
# make ---> mak
# no ---> no
# XboxOne ---> xboxon
# Tag ---> tag
# friends ---> friend
# you ---> you
# thankful ---> thank
# for ---> for
# XboxSweepstakes ---> xboxsweepstak
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# digital ---> digit
# codes ---> cod
# of ---> of
# M ---> m
# Rules ---> rul
# http ---> http
# Ooh ---> ooh
# that ---> that
# a ---> a
# tough ---> tough
# one ---> on
# At ---> at
# least ---> least
# it ---> it
# a ---> a
# choice ---> cho
# No ---> no
# sweat ---> swe
# Have ---> hav
# a ---> a
# blast ---> blast
# Anthony ---> anthony
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> hav
# so ---> so
# much ---> much
# fun ---> fun
# streaming ---> streaming
# There ---> ther
# absolutely ---> absolv
# is ---> is
# just ---> just
# follow ---> follow
# this ---> thi
# guide ---> guid
# UI ---> ui
# may ---> may
# differ ---> diff
# http ---> http
# It ---> it
# does ---> doe
# look ---> look
# amazing ---> amaz
# Good ---> good
# plan ---> plan
# Have ---> hav
# fun ---> fun
# The ---> the
# only ---> on
# people ---> peopl
# who ---> who
# should ---> should
# be ---> be
# alarmed ---> alarm
# are ---> ar
# your ---> yo
# opponents ---> oppon
# We ---> we
# sure ---> sur
# you ---> you
# can ---> can
# find ---> find
# time ---> tim
# for ---> for
# both ---> both
# Cruise ---> cru
# into ---> into
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# E ---> e
# now ---> now
# through ---> through
# November ---> novemb
# http ---> http
# Time ---> tim
# to ---> to
# find ---> find
# some ---> som
# savings ---> sav
# XboxOne ---> xboxon
# Join ---> join
# Clubs ---> club
# find ---> find
# players ---> play
# and ---> and
# download ---> download
# GamesWithGold ---> gameswithgold
# from ---> from
# your ---> yo
# smartphone ---> smartphon
# with ---> with
# the ---> the
# Xbox ---> xbox
# app ---> ap
# Download ---> download
# http ---> http
# Thanks ---> thank
# Brandon ---> brandon
# That ---> that
# great ---> gre
# to ---> to
# hear ---> hear
# The ---> the
# big ---> big
# question ---> quest
# is ---> is
# which ---> which
# game ---> gam
# will ---> wil
# you ---> you
# be ---> be
# booting ---> boot
# up ---> up
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Looks ---> look
# like ---> lik
# quite ---> quit
# the ---> the
# haul ---> haul
# We ---> we
# right ---> right
# there ---> ther
# with ---> with
# you ---> you
# Save ---> sav
# cash ---> cash
# Save ---> sav
# Sera ---> ser
# M ---> m
# is ---> is
# on ---> on
# sale ---> sal
# now ---> now
# http ---> http
# BlackFriday ---> blackfriday
# How ---> how
# did ---> did
# it ---> it
# end ---> end
# up ---> up
# working ---> work
# out ---> out
# for ---> for
# you ---> you
# Emily ---> emy
# That ---> that
# the ---> the
# way ---> way
# to ---> to
# go ---> go
# Buy ---> buy
# digital ---> digit
# Play ---> play
# anywhere ---> anywh
# Learn ---> learn
# how ---> how
# at ---> at
# http ---> http
# XboxPlayAnywhere ---> xboxplayanywh
# Hard ---> hard
# weather ---> weath
# heads ---> head
# to ---> to
# New ---> new
# York ---> york
# with ---> with
# today ---> today
# release ---> releas
# of ---> of
# TheDivision ---> thedivid
# M ---> m
# Survival ---> surv
# Get ---> get
# the ---> the
# new ---> new
# DLC ---> dlc
# at ---> at
# http ---> http
# Battlepacks ---> battlepack
# are ---> ar
# now ---> now
# available ---> avail
# for ---> for
# purchase ---> purchas
# in ---> in
# Battlefield ---> battlefield
# M ---> m
# http ---> http
# Forge ---> forg
# an ---> an
# alliance ---> al
# with ---> with
# The ---> the
# Clown ---> clown
# Prince ---> print
# of ---> of
# Crime ---> crim
# in ---> in
# BATMAN ---> batm
# The ---> the
# Telltale ---> tellt
# Series ---> sery
# M ---> m
# Episode ---> episod
# is ---> is
# out ---> out
# now ---> now
# http ---> http
# The ---> the
# only ---> on
# question ---> quest
# is ---> is
# which ---> which
# squad ---> squad
# member ---> memb
# did ---> did
# you ---> you
# use ---> us
# for ---> for
# gaming ---> gam
# today ---> today
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# be ---> be
# shouting ---> shout
# out ---> out
# a ---> a
# game ---> gam
# that ---> that
# you ---> you
# worked ---> work
# on ---> on
# over ---> ov
# our ---> our
# channels ---> channel
# Thanks ---> thank
# for ---> for
# awesome ---> awesom
# years ---> year
# Mason ---> mason
# Oh ---> oh
# no ---> no
# Guess ---> guess
# it ---> it
# the ---> the
# only ---> on
# way ---> way
# to ---> to
# keep ---> keep
# both ---> both
# your ---> yo
# mind ---> mind
# and ---> and
# your ---> yo
# gaming ---> gam
# skills ---> skil
# sharp ---> sharp
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> tim
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gam
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# What ---> what
# game ---> gam
# did ---> did
# you ---> you
# get ---> get
# it ---> it
# with ---> with
# Whoa ---> who
# Now ---> now
# those ---> thos
# are ---> ar
# some ---> som
# serious ---> sery
# classics ---> class
# Gear ---> gear
# up ---> up
# on ---> on
# BlackFriday ---> blackfriday
# with ---> with
# off ---> off
# M ---> m
# available ---> avail
# now ---> now
# at ---> at
# http ---> http
# We ---> we
# could ---> could
# think ---> think
# of ---> of
# a ---> a
# better ---> bet
# XboxOne ---> xboxon
# It ---> it
# coming ---> com
# together ---> togeth
# nicely ---> nic
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# the ---> the
# pic ---> pic
# Have ---> hav
# a ---> a
# great ---> gre
# week ---> week
# We ---> we
# looking ---> look
# forward ---> forward
# Xbox ---> xbox
# heavy ---> heavy
# holidays ---> holiday
# as ---> as
# well ---> wel
# No ---> no
# arguments ---> argu
# here ---> her
# You ---> you
# should ---> should
# pick ---> pick
# it ---> it
# up ---> up
# Devin ---> devin
# That ---> that
# awesome ---> awesom
# We ---> we
# sure ---> sur
# it ---> it
# will ---> wil
# make ---> mak
# an ---> an
# amazing ---> amaz
# early ---> ear
# present ---> pres
# We ---> we
# got ---> got
# to ---> to
# agree ---> agr
# with ---> with
# you ---> you
# there ---> ther
# Hopefully ---> hop
# you ---> you
# enjoy ---> enjoy
# all ---> al
# the ---> the
# games ---> gam
# Hello ---> hello
# there ---> ther
# Oh ---> oh
# nice ---> nic
# That ---> that
# pretty ---> pretty
# creative ---> cre
# We ---> we
# were ---> wer
# always ---> alway
# fans ---> fan
# of ---> of
# their ---> their
# logo ---> logo
# There ---> ther
# always ---> alway
# tomorrow ---> tomorrow
# and ---> and
# there ---> ther
# ca ---> ca
# be ---> be
# an ---> an
# essay ---> essay
# every ---> every
# day ---> day
# D ---> d
# Good ---> good
# plan ---> plan
# JJ ---> jj
# Pick ---> pick
# up ---> up
# some ---> som
# snacks ---> snack
# while ---> whil
# you ---> you
# there ---> ther
# We ---> we
# have ---> hav
# http ---> http
# What ---> what
# better ---> bet
# way ---> way
# to ---> to
# weather ---> weath
# winter ---> wint
# than ---> than
# with ---> with
# new ---> new
# GamesWithGold ---> gameswithgold
# Learn ---> learn
# more ---> mor
# about ---> about
# December ---> decemb
# picks ---> pick
# at ---> at
# http ---> http
# Awesome ---> awesom
# work ---> work
# You ---> you
# know ---> know
# it ---> it
# You ---> you
# kept ---> kept
# it ---> it
# all ---> al
# this ---> thi
# time ---> tim
# Now ---> now
# we ---> we
# blushing ---> blush
# There ---> ther
# nothing ---> noth
# wrong ---> wrong
# with ---> with
# being ---> being
# an ---> an
# Xbox ---> xbox
# fan ---> fan
# Have ---> hav
# fun ---> fun
# Awesome ---> awesom
# Have ---> hav
# fun ---> fun
# with ---> with
# it ---> it
# when ---> when
# it ---> it
# arrives ---> ar
# XboxOne ---> xboxon
# to ---> to
# Oculus ---> ocul
# streaming ---> streaming
# arrives ---> ar
# December ---> decemb
# with ---> with
# the ---> the
# XboxOne ---> xboxon
# Streaming ---> streaming
# app ---> ap
# Learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# It ---> it
# definitely ---> definit
# worth ---> wor
# checking ---> check
# out ---> out
# Carlos ---> carlo
# Have ---> hav
# fun ---> fun
# Thanks ---> thank
# We ---> we
# hope ---> hop
# you ---> you
# have ---> hav
# a ---> a
# chance ---> chant
# to ---> to
# play ---> play
# them ---> them
# all ---> al
# The ---> the
# best ---> best
# time ---> tim
# of ---> of
# the ---> the
# day ---> day
# We ---> we
# hope ---> hop
# you ---> you
# enjoy ---> enjoy
# all ---> al
# the ---> the
# games ---> gam
# Have ---> hav
# fun ---> fun
# with ---> with
# them ---> them
# We ---> we
# wrapping ---> wrap
# up ---> up
# with ---> with
# a ---> a
# bang ---> bang
# D ---> d
# Burnout ---> burnout
# Paradise ---> parad
# is ---> is
# now ---> now
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Get ---> get
# it ---> it
# free ---> fre
# on ---> on
# GamesWithGold ---> gameswithgold
# http ---> http
# You ---> you
# did ---> did
# a ---> a
# good ---> good
# thing ---> thing
# It ---> it
# the ---> the
# little ---> littl
# things ---> thing
# right ---> right
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> lov
# Dylan ---> dyl
# What ---> what
# an ---> an
# awesome ---> awesom
# gift ---> gift
# We ---> we
# sure ---> sur
# he ---> he
# love ---> lov
# it ---> it
# We ---> we
# love ---> lov
# you ---> you
# right ---> right
# back ---> back
# A ---> a
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Josh ---> josh
# Sounds ---> sound
# like ---> lik
# a ---> a
# relaxing ---> relax
# morning ---> morn
# to ---> to
# us ---> us
# It ---> it
# quite ---> quit
# beautiful ---> beauty
# is ---> is
# it ---> it
# How ---> how
# far ---> far
# have ---> hav
# you ---> you
# gotten ---> got
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# We ---> we
# appreciate ---> apprecy
# it ---> it
# You ---> you
# sure ---> sur
# know ---> know
# how ---> how
# to ---> to
# spread ---> spread
# the ---> the
# love ---> lov
# We ---> we
# like ---> lik
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# We ---> we
# like ---> lik
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Ashley ---> ashley
# You ---> you
# got ---> got
# real ---> real
# good ---> good
# taste ---> tast
# in ---> in
# games ---> gam
# That ---> that
# looks ---> look
# awesome ---> awesom
# How ---> how
# did ---> did
# you ---> you
# come ---> com
# up ---> up
# with ---> with
# red ---> red
# and ---> and
# blue ---> blu
# Timeless ---> timeless
# as ---> as
# always ---> alway
# We ---> we
# love ---> lov
# it ---> it
# Thanks ---> thank
# for ---> for
# participating ---> particip
# Sylvia ---> sylv
# Thanks ---> thank
# for ---> for
# being ---> being
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gam
# Hunter ---> hunt
# You ---> you
# kept ---> kept
# the ---> the
# box ---> box
# How ---> how
# are ---> ar
# you ---> you
# going ---> going
# to ---> to
# celebrate ---> celebr
# BlackFriday ---> blackfriday
# is ---> is
# here ---> her
# Save ---> sav
# up ---> up
# to ---> to
# on ---> on
# Xbox ---> xbox
# games ---> gam
# and ---> and
# go ---> go
# Gold ---> gold
# to ---> to
# save ---> sav
# up ---> up
# to ---> to
# more ---> mor
# See ---> see
# the ---> the
# deals ---> deal
# http ---> http
# Thanks ---> thank
# We ---> we
# hope ---> hop
# you ---> you
# enjoy ---> enjoy
# all ---> al
# the ---> the
# games ---> gam
# Thanks ---> thank
# What ---> what
# game ---> gam
# are ---> ar
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# about ---> about
# to ---> to
# go ---> go
# down ---> down
# Woot ---> woot
# woot ---> woot
# Awesome ---> awesom
# deal ---> deal
# Oh ---> oh
# hey ---> hey
# Whaddup ---> whaddup
# Sounds ---> sound
# like ---> lik
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Which ---> which
# bundle ---> bundl
# do ---> do
# you ---> you
# have ---> hav
# your ---> yo
# eye ---> ey
# on ---> on
# Thanks ---> thank
# for ---> for
# the ---> the
# Dustin ---> dustin
# Glad ---> glad
# to ---> to
# see ---> see
# that ---> that
# we ---> we
# could ---> could
# help ---> help
# hook ---> hook
# you ---> you
# up ---> up
# Right ---> right
# What ---> what
# an ---> an
# awesome ---> awesom
# deal ---> deal
# Adam ---> adam
# speaks ---> speak
# the ---> the
# truth ---> tru
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# so ---> so
# hyped ---> hyp
# that ---> that
# awesome ---> awesom
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# One ---> on
# family ---> famy
# Very ---> very
# nice ---> nic
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# We ---> we
# be ---> be
# waiting ---> wait
# You ---> you
# got ---> got
# good ---> good
# taste ---> tast
# in ---> in
# games ---> gam
# Be ---> be
# sure ---> sur
# to ---> to
# let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# The ---> the
# best ---> best
# kind ---> kind
# of ---> of
# break ---> break
# You ---> you
# know ---> know
# what ---> what
# up ---> up
# Matt ---> mat
# Sometimes ---> sometim
# it ---> it
# just ---> just
# takes ---> tak
# a ---> a
# little ---> littl
# motivation ---> mot
# It ---> it
# is ---> is
# not ---> not
# How ---> how
# far ---> far
# have ---> hav
# you ---> you
# managed ---> man
# to ---> to
# make ---> mak
# it ---> it
# Looking ---> look
# good ---> good
# It ---> it
# Gearing ---> gear
# up ---> up
# to ---> to
# be ---> be
# a ---> a
# great ---> gre
# day ---> day
# Awesome ---> awesom
# The ---> the
# sign ---> sign
# of ---> of
# a ---> a
# great ---> gre
# Pilot ---> pilot
# You ---> you
# doing ---> doing
# great ---> gre
# Angel ---> angel
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# No ---> no
# problem ---> problem
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Playing ---> play
# M ---> m
# Try ---> try
# out ---> out
# these ---> thes
# maps ---> map
# for ---> for
# your ---> yo
# XboxElite ---> xboxelit
# http ---> http
# You ---> you
# got ---> got
# so ---> so
# much ---> much
# gaming ---> gam
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# envious ---> envy
# Have ---> hav
# another ---> anoth
# great ---> gre
# stream ---> stream
# Peter ---> pet
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# it ---> it
# This ---> thi
# is ---> is
# a ---> a
# great ---> gre
# time ---> tim
# to ---> to
# pick ---> pick
# both ---> both
# of ---> of
# them ---> them
# up ---> up
# http ---> http
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# loving ---> lov
# it ---> it
# Alyssa ---> alyss
# Pizza ---> pizz
# party ---> party
# at ---> at
# your ---> yo
# house ---> hous
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# liking ---> lik
# it ---> it
# What ---> what
# clubs ---> club
# have ---> hav
# you ---> you
# joined ---> join
# so ---> so
# far ---> far
# Do ---> do
# worry ---> worry
# we ---> we
# got ---> got
# your ---> yo
# back ---> back
# We ---> we
# see ---> see
# you ---> you
# at ---> at
# the ---> the
# Horizon ---> horizon
# Festival ---> fest
# Forza ---> forz
# Horizon ---> horizon
# is ---> is
# also ---> also
# available ---> avail
# for ---> for
# Windows ---> window
# Good ---> good
# luck ---> luck
# getting ---> get
# to ---> to
# the ---> the
# wave ---> wav
# We ---> we
# ca ---> ca
# argue ---> argu
# with ---> with
# that ---> that
# We ---> we
# loving ---> lov
# it ---> it
# too ---> too
# Enter ---> ent
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# when ---> when
# you ---> you
# order ---> ord
# a ---> a
# Triple ---> tripl
# Treat ---> tre
# Box ---> box
# from ---> from
# PizzaHut ---> pizzahut
# Offer ---> off
# ends ---> end
# Rules ---> rul
# http ---> http
# Be ---> be
# sure ---> sur
# to ---> to
# report ---> report
# the ---> the
# account ---> account
# http ---> http
# Our ---> our
# condolences ---> condol
# But ---> but
# we ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# got ---> got
# some ---> som
# great ---> gre
# memories ---> mem
# together ---> togeth
# on ---> on
# the ---> the
# Xbox ---> xbox
# Awesome ---> awesom
# article ---> artic
# Michael ---> michael
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# been ---> been
# with ---> with
# us ---> us
# since ---> sint
# the ---> the
# very ---> very
# beginning ---> begin
# From ---> from
# behind ---> behind
# Great ---> gre
# clip ---> clip
# Awesome ---> awesom
# work ---> work
# We ---> we
# love ---> lov
# chatting ---> chat
# with ---> with
# our ---> our
# awesome ---> awesom
# fans ---> fan
# Great ---> gre
# choice ---> cho
# with ---> with
# Mafia ---> maf
# III ---> ii
# Looking ---> look
# great ---> gre
# so ---> so
# far ---> far
# What ---> what
# game ---> gam
# have ---> hav
# you ---> you
# played ---> play
# the ---> the
# most ---> most
# Smart ---> smart
# thinking ---> think
# Dessmond ---> dessmond
# Looking ---> look
# for ---> for
# a ---> a
# holiday ---> holiday
# escape ---> escap
# M ---> m
# today ---> today
# and ---> and
# play ---> play
# it ---> it
# December ---> decemb
# http ---> http
# Awesome ---> awesom
# Which ---> which
# game ---> gam
# were ---> wer
# you ---> you
# playing ---> play
# Watch ---> watch
# Lesnar ---> lesn
# battle ---> battl
# Goldberg ---> goldberg
# live ---> liv
# tonight ---> tonight
# at ---> at
# PM ---> pm
# PT ---> pt
# on ---> on
# the ---> the
# WWENetwork ---> wwenetwork
# app ---> ap
# Learn ---> learn
# more ---> mor
# http ---> http
# WWESurvivorSeries ---> wwesurvivorsery
# Catch ---> catch
# the ---> the
# final ---> fin
# day ---> day
# of ---> of
# HCS ---> hcs
# Las ---> las
# Vegas ---> vega
# live ---> liv
# on ---> on
# Twitch ---> twitch
# Halo ---> halo
# top ---> top
# players ---> play
# are ---> ar
# competing ---> compet
# now ---> now
# http ---> http
# Now ---> now
# through ---> through
# November ---> novemb
# save ---> sav
# when ---> when
# you ---> you
# buy ---> buy
# any ---> any
# XboxOneS ---> xboxon
# console ---> consol
# or ---> or
# console ---> consol
# bundle ---> bundl
# http ---> http
# Halos ---> halo
# and ---> and
# Death ---> dea
# Stars ---> star
# superweapons ---> superweapon
# are ---> ar
# your ---> yo
# specialty ---> special
# Stream ---> stream
# movies ---> movy
# and ---> and
# TV ---> tv
# with ---> with
# the ---> the
# new ---> new
# FandangoNOW ---> fandangonow
# app ---> ap
# plus ---> plu
# get ---> get
# off ---> off
# your ---> yo
# first ---> first
# transaction ---> transact
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Watch ---> watch
# UFC ---> ufc
# Fight ---> fight
# Night ---> night
# Mousasi ---> mousas
# vs ---> vs
# Hall ---> hal
# today ---> today
# on ---> on
# the ---> the
# Xbox ---> xbox
# UFC ---> ufc
# app ---> ap
# Learn ---> learn
# more ---> mor
# http ---> http
# MLG ---> mlg
# and ---> and
# GearsofWar ---> gearsofw
# M ---> m
# are ---> ar
# back ---> back
# together ---> togeth
# for ---> for
# the ---> the
# first ---> first
# Pro ---> pro
# Circuit ---> circuit
# in ---> in
# years ---> year
# Be ---> be
# there ---> ther
# November ---> novemb
# Passes ---> pass
# http ---> http
# Stand ---> stand
# by ---> by
# for ---> for
# savings ---> sav
# M ---> m
# is ---> is
# now ---> now
# off ---> off
# http ---> http
# We ---> we
# down ---> down
# with ---> with
# this ---> thi
# plan ---> plan
# Only ---> on
# because ---> becaus
# of ---> of
# awesome ---> awesom
# fans ---> fan
# like ---> lik
# you ---> you
# We ---> we
# love ---> lov
# living ---> liv
# in ---> in
# the ---> the
# future ---> fut
# Better ---> bet
# catnip ---> catnip
# than ---> than
# something ---> someth
# like ---> lik
# skooma ---> skoom
# Get ---> get
# days ---> day
# free ---> fre
# of ---> of
# Sling ---> sling
# TV ---> tv
# exclusively ---> exclud
# on ---> on
# XboxOne ---> xboxon
# Learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# You ---> you
# a ---> a
# five ---> fiv
# star ---> star
# fan ---> fan
# Sounds ---> sound
# like ---> lik
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Very ---> very
# nice ---> nic
# Talk ---> talk
# about ---> about
# a ---> a
# classic ---> class
# Play ---> play
# E ---> e
# free ---> fre
# this ---> thi
# weekend ---> weekend
# with ---> with
# XboxLive ---> xboxl
# Gold ---> gold
# Learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# You ---> you
# got ---> got
# this ---> thi
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# That ---> that
# what ---> what
# up ---> up
# Looks ---> look
# like ---> lik
# you ---> you
# got ---> got
# a ---> a
# ton ---> ton
# of ---> of
# awesome ---> awesom
# gaming ---> gam
# ahead ---> ahead
# of ---> of
# you ---> you
# We ---> we
# love ---> lov
# you ---> you
# right ---> right
# back ---> back
# Very ---> very
# nice ---> nic
# Thanks ---> thank
# for ---> for
# being ---> being
# such ---> such
# a ---> a
# dedicated ---> ded
# fan ---> fan
# Thanks ---> thank
# so ---> so
# much ---> much
# Mark ---> mark
# Glad ---> glad
# we ---> we
# could ---> could
# hook ---> hook
# you ---> you
# up ---> up
# with ---> with
# so ---> so
# many ---> many
# other ---> oth
# awesome ---> awesom
# gamers ---> gam
# This ---> thi
# weekend ---> weekend
# play ---> play
# Overwatch ---> overwatch
# T ---> t
# for ---> for
# free ---> fre
# Start ---> start
# playing ---> play
# today ---> today
# on ---> on
# XboxOne ---> xboxon
# and ---> and
# learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# Thanks ---> thank
# for ---> for
# picking ---> pick
# up ---> up
# so ---> so
# many ---> many
# cool ---> cool
# games ---> gam
# Are ---> ar
# you ---> you
# all ---> al
# set ---> set
# for ---> for
# the ---> the
# winter ---> wint
# It ---> it
# so ---> so
# hard ---> hard
# to ---> to
# narrow ---> narrow
# down ---> down
# that ---> that
# wish ---> wish
# list ---> list
# Have ---> hav
# fun ---> fun
# with ---> with
# whatever ---> whatev
# you ---> you
# decide ---> decid
# to ---> to
# pick ---> pick
# up ---> up
# Scott ---> scot
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# join ---> join
# us ---> us
# for ---> for
# the ---> the
# release ---> releas
# of ---> of
# M ---> m
# and ---> and
# a ---> a
# look ---> look
# at ---> at
# BlackFriday ---> blackfriday
# http ---> http
# That ---> that
# what ---> what
# up ---> up
# What ---> what
# will ---> wil
# you ---> you
# play ---> play
# first ---> first
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# your ---> yo
# clips ---> clip
# That ---> that
# a ---> a
# good ---> good
# problem ---> problem
# to ---> to
# have ---> hav
# in ---> in
# our ---> our
# opinions ---> opin
# D ---> d
# Thanks ---> thank
# for ---> for
# being ---> being
# such ---> such
# a ---> a
# dedicated ---> ded
# fan ---> fan
# Here ---> her
# to ---> to
# many ---> many
# more ---> mor
# awesome ---> awesom
# gaming ---> gam
# moments ---> mom
# in ---> in
# the ---> the
# future ---> fut
# This ---> thi
# holiday ---> holiday
# make ---> mak
# it ---> it
# theirs ---> their
# with ---> with
# an ---> an
# XboxDesignLab ---> xboxdesignlab
# Digital ---> digit
# Code ---> cod
# Learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# Cry ---> cry
# havoc ---> havoc
# and ---> and
# let ---> let
# slip ---> slip
# the ---> the
# huskies ---> husky
# of ---> of
# war ---> war
# Go ---> go
# Gold ---> gold
# for ---> for
# and ---> and
# enjoy ---> enjoy
# early ---> ear
# access ---> access
# to ---> to
# this ---> thi
# year ---> year
# Xbox ---> xbox
# BlackFriday ---> blackfriday
# savings ---> sav
# Learn ---> learn
# more ---> mor
# http ---> http
# Looks ---> look
# like ---> lik
# Player ---> play
# has ---> has
# entered ---> ent
# the ---> the
# game ---> gam
# We ---> we
# got ---> got
# some ---> som
# extra ---> extr
# deals ---> deal
# coming ---> com
# up ---> up
# next ---> next
# weekend ---> weekend
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# that ---> that
# it ---> it
# such ---> such
# a ---> a
# vivid ---> vivid
# memory ---> mem
# No ---> no
# problem ---> problem
# Everyone ---> everyon
# getting ---> get
# excited ---> excit
# for ---> for
# it ---> it
# Design ---> design
# share ---> shar
# and ---> and
# tag ---> tag
# a ---> a
# controller ---> control
# with ---> with
# XboxDesignLab ---> xboxdesignlab
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# Rules ---> rul
# http ---> http
# So ---> so
# fresh ---> fresh
# and ---> and
# so ---> so
# clean ---> cle
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> lov
# Joe ---> joe
# That ---> that
# great ---> gre
# to ---> to
# hear ---> hear
# Hopefully ---> hop
# you ---> you
# get ---> get
# some ---> som
# epic ---> ep
# games ---> gam
# with ---> with
# the ---> the
# club ---> club
# Got ---> got
# ta ---> ta
# rep ---> rep
# the ---> the
# Ravens ---> rav
# Flock ---> flock
# right ---> right
# Awesome ---> awesom
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# Lindsey ---> lindsey
# Wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Shawn ---> shawn
# Nice ---> nic
# What ---> what
# do ---> do
# you ---> you
# think ---> think
# of ---> of
# it ---> it
# so ---> so
# far ---> far
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Drew ---> drew
# It ---> it
# for ---> for
# project ---> project
# Scorpio ---> scorpio
# They ---> they
# tell ---> tel
# stories ---> story
# of ---> of
# your ---> yo
# time ---> tim
# in ---> in
# Tamriel ---> tamriel
# We ---> we
# already ---> already
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Thanks ---> thank
# so ---> so
# much ---> much
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# all ---> al
# the ---> the
# awesome ---> awesom
# stuff ---> stuff
# ahead ---> ahead
# Great ---> gre
# work ---> work
# The ---> the
# gun ---> gun
# looks ---> look
# awesome ---> awesom
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# all ---> al
# set ---> set
# to ---> to
# go ---> go
# Have ---> hav
# fun ---> fun
# We ---> we
# hope ---> hop
# to ---> to
# see ---> see
# you ---> you
# soon ---> soon
# Andrew ---> andrew
# We ---> we
# wishing ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# You ---> you
# have ---> hav
# great ---> gre
# taste ---> tast
# in ---> in
# games ---> gam
# RT ---> rt
# now ---> now
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# M ---> m
# bundle ---> bundl
# Sweepstakes ---> sweepstak
# Rules ---> rul
# http ---> http
# Let ---> let
# just ---> just
# assume ---> assum
# it ---> it
# all ---> al
# the ---> the
# clips ---> clip
# Awesome ---> awesom
# work ---> work
# Thanks ---> thank
# Joe ---> joe
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Sounds ---> sound
# like ---> lik
# you ---> you
# on ---> on
# your ---> yo
# way ---> way
# to ---> to
# your ---> yo
# dream ---> dream
# We ---> we
# believe ---> believ
# in ---> in
# you ---> you
# There ---> ther
# no ---> no
# words ---> word
# that ---> that
# could ---> could
# describe ---> describ
# our ---> our
# love ---> lov
# Good ---> good
# plan ---> plan
# Briana ---> brian
# What ---> what
# are ---> ar
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# And ---> and
# we ---> we
# love ---> lov
# you ---> you
# right ---> right
# back ---> back
# Haden ---> had
# Very ---> very
# nice ---> nic
# Here ---> her
# to ---> to
# many ---> many
# more ---> mor
# rare ---> rar
# achievements ---> achiev
# in ---> in
# the ---> the
# future ---> fut
# Awesome ---> awesom
# Which ---> which
# achievement ---> achiev
# was ---> was
# it ---> it
# Sounds ---> sound
# like ---> lik
# it ---> it
# about ---> about
# to ---> to
# be ---> be
# an ---> an
# awesome ---> awesom
# birthday ---> birthday
# We ---> we
# glad ---> glad
# you ---> you
# loving ---> lov
# it ---> it
# Joey ---> joey
# How ---> how
# far ---> far
# have ---> hav
# you ---> you
# gotten ---> got
# It ---> it
# still ---> stil
# as ---> as
# beautiful ---> beauty
# as ---> as
# ever ---> ev
# Sounds ---> sound
# like ---> lik
# a ---> a
# good ---> good
# day ---> day
# It ---> it
# definitely ---> definit
# a ---> a
# good ---> good
# time ---> tim
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gam
# We ---> we
# hear ---> hear
# that ---> that
# At ---> at
# least ---> least
# we ---> we
# on ---> on
# the ---> the
# home ---> hom
# stretch ---> stretch
# You ---> you
# ca ---> ca
# help ---> help
# but ---> but
# be ---> be
# holly ---> hol
# and ---> and
# jolly ---> jol
# Congrats ---> congr
# What ---> what
# game ---> gam
# are ---> ar
# you ---> you
# going ---> going
# to ---> to
# play ---> play
# first ---> first
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# having ---> hav
# so ---> so
# much ---> much
# fun ---> fun
# You ---> you
# still ---> stil
# got ---> got
# great ---> gre
# skills ---> skil
# Dylan ---> dyl
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# still ---> stil
# finding ---> find
# some ---> som
# play ---> play
# time ---> tim
# Emmarie ---> em
# We ---> we
# love ---> lov
# that ---> that
# series ---> sery
# That ---> that
# sounds ---> sound
# like ---> lik
# a ---> a
# great ---> gre
# idea ---> ide
# to ---> to
# us ---> us
# Sometimes ---> sometim
# you ---> you
# just ---> just
# got ---> got
# to ---> to
# play ---> play
# You ---> you
# got ---> got
# this ---> thi
# There ---> ther
# plenty ---> plenty
# of ---> of
# great ---> gre
# games ---> gam
# ahead ---> ahead
# to ---> to
# help ---> help
# you ---> you
# out ---> out
# It ---> it
# sure ---> sur
# does ---> doe
# Fans ---> fan
# like ---> lik
# you ---> you
# are ---> ar
# why ---> why
# we ---> we
# do ---> do
# what ---> what
# we ---> we
# do ---> do
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Nice ---> nic
# What ---> what
# was ---> was
# your ---> yo
# favorite ---> favorit
# game ---> gam
# to ---> to
# play ---> play
# Good ---> good
# luck ---> luck
# to ---> to
# you ---> you
# BlackFriday ---> blackfriday
# deals ---> deal
# are ---> ar
# coming ---> com
# soon ---> soon
# Get ---> get
# early ---> ear
# access ---> access
# with ---> with
# XboxLive ---> xboxl
# Gold ---> gold
# and ---> and
# learn ---> learn
# more ---> mor
# at ---> at
# http ---> http
# Good ---> good
# luck ---> luck
# with ---> with
# your ---> yo
# new ---> new
# club ---> club
# Thanks ---> thank
# for ---> for
# the ---> the
# feedback ---> feedback
# Have ---> hav
# fun ---> fun
# with ---> with
# the ---> the
# new ---> new
# features ---> feat
# Have ---> hav
# fun ---> fun
# playing ---> play
# it ---> it
# Unlock ---> unlock
# the ---> the
# true ---> tru
# colors ---> col
# of ---> of
# your ---> yo
# games ---> gam
# and ---> and
# entertainment ---> entertain
# with ---> with
# HDR ---> hdr
# http ---> http
# XboxOneS ---> xboxon
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# share ---> shar
# the ---> the
# next ---> next
# years ---> year
# Great ---> gre
# clip ---> clip
# Nice ---> nic
# shot ---> shot
# It ---> it
# definitely ---> definit
# worth ---> wor
# writing ---> writ
# home ---> hom
# about ---> about
# Now ---> now
# that ---> that
# one ---> on
# look ---> look
# you ---> you
# can ---> can
# never ---> nev
# outgrow ---> outgrow
# Have ---> hav
# fun ---> fun
# Commander ---> command
# That ---> that
# the ---> the
# plan ---> plan
# Ryan ---> ryan
# That ---> that
# must ---> must
# been ---> been
# a ---> a
# very ---> very
# happy ---> happy
# Christmas ---> christmas
# day ---> day
# Making ---> mak
# great ---> gre
# friends ---> friend
# online ---> onlin
# is ---> is
# definitely ---> definit
# our ---> our
# favorite ---> favorit
# feature ---> feat
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# Scorpio ---> scorpio
# either ---> eith
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# your ---> yo
# pride ---> prid
# Thanks ---> thank
# for ---> for
# the ---> the
# birthday ---> birthday
# wishes ---> wish
# Mark ---> mark
# We ---> we
# just ---> just
# getting ---> get
# started ---> start
# It ---> it
# never ---> nev
# too ---> too
# late ---> lat
# We ---> we
# glad ---> glad
# to ---> to
# have ---> hav
# you ---> you
# with ---> with
# us ---> us
# Xbox ---> xbox
# fans ---> fan
# can ---> can
# be ---> be
# any ---> any
# age ---> ag
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# so ---> so
# long ---> long
# Thanks ---> thank
# for ---> for
# being ---> being
# an ---> an
# awesome ---> awesom
# fan ---> fan
# We ---> we
# love ---> lov
# you ---> you
# too ---> too
# Thanks ---> thank
# Eric ---> er
# Game ---> gam
# on ---> on
# Sounds ---> sound
# like ---> lik
# an ---> an
# awesome ---> awesom
# club ---> club
# That ---> that
# was ---> was
# an ---> an
# epic ---> ep
# console ---> consol
# too ---> too
# Game ---> gam
# on ---> on
# Welcome ---> welcom
# back ---> back
# Glad ---> glad
# that ---> that
# it ---> it
# held ---> held
# such ---> such
# an ---> an
# important ---> import
# place ---> plac
# in ---> in
# your ---> yo
# life ---> lif
# Here ---> her
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Aww ---> aww
# thanks ---> thank
# for ---> for
# the ---> the
# love ---> lov
# What ---> what
# an ---> an
# awesome ---> awesom
# family ---> famy
# portrait ---> portrait
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# Have ---> hav
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Blood ---> blood
# Dragon ---> dragon
# M ---> m
# and ---> and
# Murdered ---> murd
# Soul ---> soul
# Suspect ---> suspect
# M ---> m
# are ---> ar
# now ---> now
# on ---> on
# GamesWithGold ---> gameswithgold
# Start ---> start
# playing ---> play
# today ---> today
# http ---> http
# Nice ---> nic
# to ---> to
# hear ---> hear
# Thanks ---> thank
# for ---> for
# being ---> being
# such ---> such
# a ---> a
# dedicated ---> ded
# fan ---> fan
# That ---> that
# awesome ---> awesom
# Travis ---> trav
# Sounds ---> sound
# like ---> lik
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# quite ---> quit
# some ---> som
# time ---> tim
# Thanks ---> thank
# for ---> for
# all ---> al
# the ---> the
# awesome ---> awesom
# years ---> year
# of ---> of
# gaming ---> gam
# with ---> with
# us ---> us
# And ---> and
# that ---> that
# you ---> you
# for ---> for
# being ---> being
# such ---> such
# an ---> an
# awesome ---> awesom
# gamer ---> gam
# and ---> and
# fan ---> fan
# Canvas ---> canva
# does ---> doe
# matter ---> mat
# without ---> without
# artists ---> art
# like ---> lik
# yourself ---> yourself
# Thanks ---> thank
# for ---> for
# all ---> al
# your ---> yo
# awesome ---> awesom
# work ---> work
# You ---> you
# very ---> very
# welcome ---> welcom
# Have ---> hav
# you ---> you
# set ---> set
# up ---> up
# your ---> yo
# own ---> own
# yet ---> yet
# Or ---> or
# have ---> hav
# you ---> you
# found ---> found
# some ---> som
# fun ---> fun
# ones ---> on
# to ---> to
# join ---> join
# Thanks ---> thank
# much ---> much
# We ---> we
# so ---> so
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> al
# these ---> thes
# years ---> year
# Thanks ---> thank
# for ---> for
# the ---> the
# love ---> lov
# Aditya ---> adity
# It ---> it
# been ---> been
# a ---> a
# wild ---> wild
# ride ---> rid
# Good ---> good
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# The ---> the
# future ---> fut
# is ---> is
# bright ---> bright
# Ben ---> ben
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> al
# this ---> thi
# time ---> tim
# Thanks ---> thank
# so ---> so
# much ---> much
# Jeff ---> jeff
# And ---> and
# thank ---> thank
# you ---> you
# Nathan ---> nath
# for ---> for
# being ---> being
# an ---> an
# awesome ---> awesom
# gamer ---> gam
# We ---> we
# wish ---> wish
# you ---> you
# good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# you ---> you
# like ---> lik
# it ---> it
# That ---> that
# alright ---> alright
# The ---> the
# party ---> party
# still ---> stil
# going ---> going
# Thank ---> thank
# you ---> you
# LFG ---> lfg
# on ---> on
# XBL ---> xbl
# Our ---> our
# newest ---> newest
# update ---> upd
# lets ---> let
# you ---> you
# search ---> search
# for ---> for
# teammates ---> team
# by ---> by
# objective ---> object
# playstyle ---> playstyl
# and ---> and
# more ---> mor
# XboxLive ---> xboxl
# http ---> http
# They ---> they
# be ---> be
# many ---> many
# more ---> mor
# for ---> for
# sure ---> sur
# Jay ---> jay
# Thanks ---> thank
# for ---> for
# the ---> the
# greeting ---> greet
# Got ---> got
# ta ---> ta
# agree ---> agr
# with ---> with
# you ---> you
# there ---> ther
# Andrew ---> andrew
# Here ---> her
# to ---> to
# years ---> year
# of ---> of
# games ---> gam
# achievements ---> achiev
# friendships ---> friend
# and ---> and
# memories ---> mem
# Thank ---> thank
# you ---> you
# Hack ---> hack
# Everything ---> everyth
# M ---> m
# comes ---> com
# to ---> to
# XboxOne ---> xboxon
# today ---> today
# http ---> http
# And ---> and
# we ---> we
# love ---> lov
# you ---> you
# right ---> right
# back ---> back
# Totally ---> tot
# radical ---> rad
# controller ---> control
# We ---> we
# so ---> so
# thankful ---> thank
# for ---> for
# fans ---> fan
# like ---> lik
# you ---> you
# Anthony ---> anthony
# What ---> what
# been ---> been
# your ---> yo
# favorite ---> favorit
# gaming ---> gam
# moment ---> mom
# It ---> it
# a ---> a
# deathmatch ---> deathmatch
# made ---> mad
# in ---> in
# heaven ---> heav
# Here ---> her
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# RT ---> rt
# and ---> and
# Sweepstakes ---> sweepstak
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# a ---> a
# Military ---> milit
# Green ---> green
# XboxOneS ---> xboxon
# Battlefield ---> battlefield
# bundle ---> bundl
# Rules ---> rul
# http ---> http
# We ---> we
# looking ---> look
# forward ---> forward
# to ---> to
# the ---> the
# next ---> next
# From ---> from
# the ---> the
# beginning ---> begin
# It ---> it
# great ---> gre
# to ---> to
# have ---> hav
# awesome ---> awesom
# fans ---> fan
# That ---> that
# awesome ---> awesom
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# your ---> yo
# memory ---> mem
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# chance ---> chant
# to ---> to
# pick ---> pick
# one ---> on
# up ---> up
# Thanks ---> thank
# Thanks ---> thank
# for ---> for
# years ---> year
# of ---> of
# awesomeness ---> awesom
# Right ---> right
# back ---> back
# at ---> at
# you ---> you
# Talan ---> tal
# Stay ---> stay
# awesome ---> awesom
# And ---> and
# thank ---> thank
# for ---> for
# being ---> being
# such ---> such
# an ---> an
# awesome ---> awesom
# fan ---> fan
# and ---> and
# gamer ---> gam
# You ---> you
# know ---> know
# it ---> it
# Here ---> her
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# of ---> of
# Halo ---> halo
# awesomeness ---> awesom
# Which ---> which
# one ---> on
# did ---> did
# you ---> you
# grow ---> grow
# up ---> up
# with ---> with
# Thanks ---> thank
# Here ---> her
# to ---> to
# more ---> mor
# That ---> that
# a ---> a
# great ---> gre
# story ---> story
# Mac ---> mac
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# The ---> the
# ride ---> rid
# not ---> not
# over ---> ov
# yet ---> yet
# Christian ---> christian
# A ---> a
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Why ---> why
# thank ---> thank
# you ---> you
# Daniel ---> daniel
# Here ---> her
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# If ---> if
# you ---> you
# like ---> lik
# we ---> we
# highly ---> high
# recommend ---> recommend
# Super ---> sup
# Dungeon ---> dungeon
# Bros ---> bro
# and ---> and
# Overcooked ---> overcook
# Cheers ---> che
# You ---> you
# have ---> hav
# very ---> very
# good ---> good
# taste ---> tast
# in ---> in
# birthdays ---> birthday
# We ---> we
# definitely ---> definit
# will ---> wil
# You ---> you
# can ---> can
# celebrate ---> celebr
# by ---> by
# playing ---> play
# some ---> som
# Xbox ---> xbox
# tonight ---> tonight
# Today ---> today
# players ---> play
# get ---> get
# a ---> a
# Ford ---> ford
# Raptor ---> rapt
# with ---> with
# livery ---> livery
# new ---> new
# Rivals ---> riv
# events ---> ev
# and ---> and
# more ---> mor
# http ---> http
# Thanks ---> thank
# Rodolfo ---> rodolfo
# We ---> we
# glad ---> glad
# you ---> you
# kept ---> kept
# it ---> it
# all ---> al
# these ---> thes
# years ---> year
# We ---> we
# forever ---> forev
# young ---> young
# Aiden ---> aid
# Thanks ---> thank
# for ---> for
# being ---> being
# a ---> a
# great ---> gre
# fan ---> fan
# Time ---> tim
# flies ---> fli
# but ---> but
# the ---> the
# awesome ---> awesom
# memories ---> mem
# are ---> ar
# here ---> her
# to ---> to
# stay ---> stay
# We ---> we
# loving ---> lov
# the ---> the
# photo ---> photo
# Keep ---> keep
# on ---> on
# gaming ---> gam
# and ---> and
# keep ---> keep
# on ---> on
# raging ---> rag
# Hunter ---> hunt
# It ---> it
# gamers ---> gam
# like ---> lik
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# moving ---> mov
# forward ---> forward
# Thanks ---> thank
# Zachary ---> zach
# A ---> a
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Thank ---> thank
# you ---> you
# Shaun ---> shaun
# Thanks ---> thank
# for ---> for
# being ---> being
# part ---> part
# of ---> of
# the ---> the
# team ---> team
# We ---> we
# appreciate ---> apprecy
# it ---> it
# With ---> with
# the ---> the
# best ---> best
# fans ---> fan
# of ---> of
# all ---> al
# time ---> tim
# And ---> and
# thank ---> thank
# you ---> you
# for ---> for
# being ---> being
# such ---> such
# an ---> an
# amazing ---> amaz
# fan ---> fan
# It ---> it
# our ---> our
# pleasure ---> pleas
# We ---> we
# love ---> lov
# to ---> to
# hear ---> hear
# you ---> you
# enjoying ---> enjoy
# it ---> it
# so ---> so
# much ---> much
# Thank ---> thank
# you ---> you
# Here ---> her
# to ---> to
# more ---> mor
# great ---> gre
# memories ---> mem
# From ---> from
# Duke ---> duk
# till ---> til
# Dawn ---> dawn
# Thanks ---> thank
# for ---> for
# the ---> the
# greeting ---> greet
# Adam ---> adam
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# Game ---> gam
# on ---> on
# Tony ---> tony
# It ---> it
# all ---> al
# done ---> don
# for ---> for
# the ---> the
# awesome ---> awesom
# fans ---> fan
# like ---> lik
# you ---> you
# Game ---> gam
# on ---> on
# We ---> we
# glad ---> glad
# to ---> to
# have ---> hav
# you ---> you
# in ---> in
# the ---> the
# Xbox ---> xbox
# family ---> famy
# Here ---> her
# to ---> to
# many ---> many
# more ---> mor
# years ---> year
# of ---> of
# awesome ---> awesom
# gaming ---> gam
# The ---> the
# future ---> fut
# is ---> is
# ...
# tonight ---> tonight
# on ---> on
# the ---> the
# Xbox ---> xbox
# UFC ---> ufc
# app ---> ap
# Learn ---> learn
# more ---> mor
# http ---> http
# UFCNYC ---> ufcnyc
# One ---> on
# day ---> day
# left ---> left
# RT ---> rt
# now ---> now
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# an ---> an
# Elite ---> elit
# CallofDuty ---> callofduty
# InfiniteWarfare ---> infinitewarf
# M ---> m
# pack ---> pack
# XboxSweepstakes ---> xboxsweepstak
# rules ---> rul
# http ---> http
# In ---> in
# the ---> the
# last ---> last
# year ---> year
# we ---> we
# added ---> ad
# over ---> ov
# games ---> gam
# to ---> to
# BackwardCompatibility ---> backwardcompat
# Which ---> which
# were ---> wer
# your ---> yo
# favs ---> fav
# http ---> http
# Tune ---> tun
# in ---> in
# to ---> to
# see ---> see
# who ---> who
# qualifies ---> qual
# for ---> for
# the ---> the
# SMITE ---> smit
# T ---> t
# Console ---> consol
# World ---> world
# Championship ---> champ
# http ---> http
# SmitePro ---> smitepro
# Take ---> tak
# back ---> back
# what ---> what
# yours ---> yo
# M ---> m
# is ---> is
# available ---> avail
# now ---> now
# http ---> http
# This ---> thi
# Week ---> week
# on ---> on
# Xbox ---> xbox
# BackwardCompatibility ---> backwardcompat
# turns ---> turn
# one ---> on
# M ---> m
# comes ---> com
# to ---> to
# Xbox ---> xbox
# and ---> and
# more ---> mor
# http ---> http
# We ---> we
# most ---> most
# certainly ---> certain
# okay ---> okay
# with ---> with
# this ---> thi
# We ---> we
# ca ---> ca
# wait ---> wait
# for ---> for
# December ---> decemb
# We ---> we
# see ---> see
# if ---> if
# the ---> the
# other ---> oth
# Koopa ---> koop
# keep ---> keep
# up ---> up
# XboxOne ---> xboxon
# EASPORTSUFC ---> easportsufc
# T ---> t
# is ---> is
# now ---> now
# in ---> in
# the ---> the
# EAAccess ---> eaaccess
# Vault ---> vault
# Get ---> get
# a ---> a
# round ---> round
# in ---> in
# http ---> http
# Time ---> tim
# to ---> to
# start ---> start
# marathoning ---> marathon
# in ---> in
# your ---> yo
# Batcave ---> batcav
# XboxOne ---> xboxon
# Catch ---> catch
# today ---> today
# T ---> t
# Twitch ---> twitch
# stream ---> stream
# at ---> at
# PM ---> pm
# PT ---> pt
# PM ---> pm
# ET ---> et
# Tune ---> tun
# in ---> in
# at ---> at
# http ---> http
# That ---> that
# always ---> alway
# a ---> a
# great ---> gre
# feeling ---> feel
# What ---> what
# games ---> gam
# are ---> ar
# you ---> you
# playing ---> play
# You ---> you
# never ---> nev
# gon ---> gon
# na ---> na
# have ---> hav
# a ---> a
# good ---> good
# sauce ---> sauc
# again ---> again
# M ---> m
# http ---> http
# Follow ---> follow
# RT ---> rt
# for ---> for
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# an ---> an
# EAAccess ---> eaaccess
# code ---> cod
# MassEffect ---> masseffect
# M ---> m
# M ---> m
# and ---> and
# M ---> m
# are ---> ar
# waiting ---> wait
# http ---> http
# Sweepstakes ---> sweepstak
# Dishonored ---> dishon
# M ---> m
# is ---> is
# live ---> liv
# on ---> on
# Twitch ---> twitch
# Join ---> join
# the ---> the
# stream ---> stream
# for ---> for
# gameplay ---> gameplay
# chat ---> chat
# and ---> and
# a ---> a
# chance ---> chant
# to ---> to
# win ---> win
# a ---> a
# prize ---> priz
# http ---> http
# STEEP ---> steep
# T ---> t
# Early ---> ear
# Access ---> access
# beta ---> bet
# is ---> is
# live ---> liv
# Watch ---> watch
# the ---> the
# trailer ---> trail
# and ---> and
# start ---> start
# your ---> yo
# descent ---> desc
# at ---> at
# http ---> http
# The ---> the
# feeling ---> feel
# is ---> is
# mutual ---> mut
# You ---> you
# welcome ---> welcom
# so ---> so
# much ---> much
# Jennifer ---> jen
# Grab ---> grab
# your ---> yo
# running ---> run
# gear ---> gear
# MirrorsEdge ---> mirrorsedg
# T ---> t
# and ---> and
# MirrorsEdgeCatalyst ---> mirrorsedgecatalyst
# T ---> t
# are ---> ar
# now ---> now
# part ---> part
# of ---> of
# EAAccess ---> eaaccess
# http ---> http
# That ---> that
# great ---> gre
# to ---> to
# hear ---> hear
# Will ---> wil
# you ---> you
# be ---> be
# streaming ---> streaming
# the ---> the
# game ---> gam
# It ---> it
# a ---> a
# very ---> very
# important ---> import
# aspect ---> aspect
# of ---> of
# his ---> his
# character ---> charact
# that ---> that
# people ---> peopl
# must ---> must
# know ---> know
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# Got ---> got
# your ---> yo
# copy ---> cop
# preordered ---> preord
# yet ---> yet
# Talk ---> talk
# about ---> about
# a ---> a
# blast ---> blast
# from ---> from
# the ---> the
# past ---> past
# Stay ---> stay
# awesome ---> awesom
# birthday ---> birthday
# buddy ---> buddy
# As ---> as
# a ---> a
# journalist ---> journ
# Frank ---> frank
# is ---> is
# naturally ---> nat
# witty ---> witty
# He ---> he
# covered ---> cov
# wars ---> war
# you ---> you
# know ---> know
# Glad ---> glad
# that ---> that
# you ---> you
# liking ---> lik
# what ---> what
# you ---> you
# seeing ---> see
# What ---> what
# part ---> part
# are ---> ar
# you ---> you
# most ---> most
# excited ---> excit
# for ---> for
# It ---> it
# not ---> not
# too ---> too
# terrible ---> terr
# of ---> of
# a ---> a
# problem ---> problem
# to ---> to
# have ---> hav
# That ---> that
# because ---> becaus
# you ---> you
# are ---> ar
# Glad ---> glad
# you ---> you
# think ---> think
# so ---> so
# We ---> we
# guess ---> guess
# you ---> you
# still ---> stil
# got ---> got
# the ---> the
# flick ---> flick
# then ---> then
# That ---> that
# awesome ---> awesom
# to ---> to
# hear ---> hear
# You ---> you
# going ---> going
# to ---> to
# have ---> hav
# an ---> an
# amazing ---> amaz
# holiday ---> holiday
# season ---> season
# Looking ---> look
# good ---> good
# Aaron ---> aaron
# What ---> what
# game ---> gam
# are ---> ar
# you ---> you
# going ---> going
# to ---> to
# break ---> break
# it ---> it
# in ---> in
# with ---> with
# Xbox ---> xbox
# is ---> is
# love ---> lov
# It ---> it
# been ---> been
# a ---> a
# great ---> gre
# day ---> day
# for ---> for
# Backwards ---> backward
# Compatibility ---> compat
# D ---> d
# Shoutouts ---> shoutout
# to ---> to
# your ---> yo
# son ---> son
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# The ---> the
# anticipation ---> anticip
# is ---> is
# already ---> already
# getting ---> get
# hard ---> hard
# to ---> to
# handle ---> handl
# We ---> we
# guessing ---> guess
# someone ---> someon
# excited ---> excit
# The ---> the
# first ---> first
# of ---> of
# many ---> many
# We ---> we
# glad ---> glad
# you ---> you
# like ---> lik
# the ---> the
# feature ---> feat
# Thanks ---> thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Woot ---> woot
# woot ---> woot
# Have ---> hav
# fun ---> fun
# T ---> t
# is ---> is
# now ---> now
# playable ---> play
# on ---> on
# XboxOne ---> xboxon
# via ---> via
# BackwardCompatibility ---> backwardcompat
# Buy ---> buy
# it ---> it
# today ---> today
# and ---> and
# save ---> sav
# http ---> http
# Happy ---> happy
# birthday ---> birthday
# in ---> in
# advance ---> adv
# Dear ---> dear
# Chris ---> chris
# Thank ---> thank
# you ---> you
# for ---> for
# taking ---> tak
# the ---> the
# time ---> tim
# to ---> to
# slay ---> slay
# bosses ---> boss
# with ---> with
# us ---> us
# It ---> it
# has ---> has
# been ---> been
# too ---> too
# long ---> long
# and ---> and
# we ---> we
# missed ---> miss
# you ---> you
# Love ---> lov
# Xbox ---> xbox
# We ---> we
# glad ---> glad
# you ---> you
# like ---> lik
# it ---> it
# You ---> you
# better ---> bet
# believe ---> believ
# it ---> it
# Here ---> her
# to ---> to
# that ---> that
# birthday ---> birthday
# twin ---> twin
# We ---> we
# hope ---> hop
# you ---> you
# had ---> had
# a ---> a
# great ---> gre
# night ---> night
# Great ---> gre
# work ---> work
# Meet ---> meet
# XboxLive ---> xboxl
# newest ---> newest
# features ---> feat
# Looking ---> look
# for ---> for
# Group ---> group
# and ---> and
# Clubs ---> club
# http ---> http
# FUS ---> fus
# RO ---> ro
# MOD ---> mod
# Skyrim ---> skyrim
# Special ---> spec
# Edition ---> edit
# M ---> m
# is ---> is
# now ---> now
# available ---> avail
# and ---> and
# moddable ---> mod
# on ---> on
# XboxOne ---> xboxon
# http ---> http
# Have ---> hav
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Playing ---> play
# games ---> gam
# is ---> is
# a ---> a
# great ---> gre
# way ---> way
# to ---> to
# unwind ---> unwind
# We ---> we
# hope ---> hop
# you ---> you
# feel ---> feel
# better ---> bet
# afterward ---> afterward
# Sounds ---> sound
# like ---> lik
# the ---> the
# perfect ---> perfect
# way ---> way
# to ---> to
# unwind ---> unwind
# Fight ---> fight
# like ---> lik
# hell ---> hel
# Intense ---> intens
# Thanks ---> thank
# for ---> for
# sharing ---> shar
# the ---> the
# clip ---> clip
# That ---> that
# probably ---> prob
# because ---> becaus
# it ---> it
# is ---> is
# We ---> we
# know ---> know
# that ---> that
# feeling ---> feel
# well ---> wel
# We ---> we
# got ---> got
# your ---> yo
# back ---> back
# Very ---> very
# nice ---> nic
# choice ---> cho
# So ---> so
# much ---> much
# replay ---> replay
# value ---> valu
# Great ---> gre
# work ---> work
# Shane ---> shan
# Keep ---> keep
# up ---> up
# the ---> the
# good ---> good
# work ---> work
# What ---> what
# game ---> gam
# is ---> is
# up ---> up
# next ---> next
# Good ---> good
# call ---> cal
# We ---> we
# hope ---> hop
# you ---> you
# have ---> hav
# a ---> a
# chance ---> chant
# to ---> to
# pick ---> pick
# it ---> it
# up ---> up
# soon ---> soon
# You ---> you
# welcome ---> welcom
# Are ---> ar
# you ---> you
# going ---> going
# Paragon ---> paragon
# or ---> or
# Renegade ---> renegad
# Very ---> very
# nice ---> nic
# Standby ---> standby
# for ---> for
# awesomeness ---> awesom
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# Absolutely ---> absolv
# What ---> what
# games ---> gam
# are ---> ar
# you ---> you
# working ---> work
# on ---> on
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# enjoying ---> enjoy
# the ---> the
# game ---> gam
# Nice ---> nic
# Have ---> hav
# a ---> a
# great ---> gre
# time ---> tim
# playing ---> play
# all ---> al
# of ---> of
# them ---> them
# You ---> you
# know ---> know
# it ---> it
# Have ---> hav
# fun ---> fun
# and ---> and
# good ---> good
# luck ---> luck
# on ---> on
# your ---> yo
# test ---> test
# Now ---> now
# that ---> that
# what ---> what
# we ---> we
# call ---> cal
# an ---> an
# army ---> army
# of ---> of
# two ---> two
# XboxOne ---> xboxon
# It ---> it
# fans ---> fan
# like ---> lik
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# going ---> going
# It ---> it
# great ---> gre
# seeing ---> see
# those ---> thos
# enemies ---> enemy
# just ---> just
# hanging ---> hang
# up ---> up
# there ---> ther
# We ---> we
# like ---> lik
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# No ---> no
# problem ---> problem
# But ---> but
# with ---> with
# your ---> yo
# skill ---> skil
# we ---> we
# think ---> think
# you ---> you
# got ---> got
# this ---> thi
# Game ---> gam
# on ---> on
# Nathan ---> nath
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> mor
# videos ---> video
# Awesome ---> awesom
# Have ---> hav
# you ---> you
# been ---> been
# playing ---> play
# Infinite ---> infinit
# Warfare ---> warf
# Welcome ---> welcom
# to ---> to
# the ---> the
# Xbox ---> xbox
# Family ---> famy
# What ---> what
# games ---> gam
# are ---> ar
# you ---> you
# going ---> going
# to ---> to
# be ---> be
# playing ---> play
# You ---> you
# have ---> hav
# great ---> gre
# taste ---> tast
# in ---> in
# games ---> gam
# Leah ---> leah
# Good ---> good
# luck ---> luck
# against ---> against
# the ---> the
# hordes ---> hord
# Alex ---> alex
# Massive ---> mass
# You ---> you
# welcome ---> welcom
# Korie ---> kory
# A ---> a
# good ---> good
# night ---> night
# indeed ---> indee
# We ---> we
# glad ---> glad
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# blast ---> blast
# There ---> ther
# a ---> a
# lot ---> lot
# of ---> of
# stuff ---> stuff
# to ---> to
# take ---> tak
# care ---> car
# of ---> of
# in ---> in
# Gotham ---> gotham
# Good ---> good
# luck ---> luck
# We ---> we
# glad ---> glad
# that ---> that
# you ---> you
# love ---> lov
# it ---> it
# so ---> so
# much ---> much
# What ---> what
# your ---> yo
# favorite ---> favorit
# game ---> gam
# to ---> to
# play ---> play
# on ---> on
# it ---> it
# This ---> thi
# week ---> week
# XboxCharityChallenge ---> xboxcharitychalleng
# throws ---> throws
# back ---> back
# to ---> to
# with ---> with
# Watch ---> watch
# live ---> liv
# now ---> now
# http ---> http
# It ---> it
# nothing ---> noth
# but ---> but
# love ---> lov
# here ---> her
# Clifton ---> clifton
# Stay ---> stay
# awesome ---> awesom
# Well ---> wel
# the ---> the
# colors ---> col
# do ---> do
# match ---> match
# your ---> yo
# avatar ---> avat
# so ---> so
# we ---> we
# think ---> think
# they ---> they
# cool ---> cool
# Have ---> hav
# a ---> a
# great ---> gre
# stream ---> stream
# Nyree ---> nyr
# Glad ---> glad
# to ---> to
# hear ---> hear
# it ---> it
# How ---> how
# far ---> far
# have ---> hav
# you ---> you
# gotten ---> got
# so ---> so
# far ---> far
# It ---> it
# really ---> real
# is ---> is
# worth ---> wor
# it ---> it
# Keith ---> kei
# Terminal ---> termin
# was ---> was
# easily ---> easy
# one ---> on
# of ---> of
# our ---> our
# favorite ---> favorit
# maps ---> map
# You ---> you
# have ---> hav
# good ---> good
# taste ---> tast
# If ---> if
# not ---> not
# you ---> you
# can ---> can
# always ---> alway
# grab ---> grab
# an ---> an
# external ---> extern
# hard ---> hard
# drive ---> driv
# How ---> how
# are ---> ar
# you ---> you
# liking ---> lik
# it ---> it
# so ---> so
# far ---> far
# Nice ---> nic
# plan ---> plan
# Which ---> which
# squad ---> squad
# mate ---> mat
# are ---> ar
# you ---> you
# looking ---> look
# forward ---> forward
# to ---> to
# seeing ---> see
# again ---> again
# the ---> the
# most ---> most
# What ---> what
# up ---> up
# Troy ---> troy
# That ---> that
# an ---> an
# excellent ---> excel
# option ---> opt
# Good ---> good
# luck ---> luck
# Breaks ---> break
# your ---> yo
# heart ---> heart
# and ---> and
# forces ---> forc
# a ---> a
# restart ---> restart
# from ---> from
# the ---> the
# beginning ---> begin
# We ---> we
# also ---> also
# make ---> mak
# sure ---> sur
# that ---> that
# it ---> it
# a ---> a
# Suicide ---> suicid
# Mission ---> miss
# in ---> in
# name ---> nam
# only ---> on
# Mass ---> mass
# Effect ---> effect
# and ---> and
# are ---> ar
# available ---> avail
# digitally ---> digit
# through ---> through
# EA ---> ea
# Access ---> access
# here ---> her
# Thank ---> thank
# goodness ---> good
# Whatcha ---> whatch
# playing ---> play
# We ---> we
# love ---> lov
# Jack ---> jack
# Though ---> though
# we ---> we
# ca ---> ca
# really ---> real
# repeat ---> rep
# any ---> any
# of ---> of
# our ---> our
# favorite ---> favorit
# quotes ---> quot
# though ---> though
# There ---> ther
# is ---> is
# an ---> an
# option ---> opt
# to ---> to
# go ---> go
# back ---> back
# to ---> to
# Xbox ---> xbox
# commands ---> command
# You ---> you
# can ---> can
# find ---> find
# out ---> out
# how ---> how
# here ---> her
# http ---> http
# You ---> you
# mean ---> mean
# that ---> that
# out ---> out
# of ---> of
# all ---> al
# your ---> yo
# pinend ---> pinend
# apps ---> ap
# it ---> it
# First ---> first
# We ---> we
# love ---> lov
# how ---> how
# it ---> it
# brings ---> bring
# people ---> peopl
# together ---> togeth
# Say ---> say
# whattt ---> whatt
# The ---> the
# day ---> day
# not ---> not
# over ---> ov
# yet ---> yet
# Now ---> now
# that ---> that
# sounds ---> sound
# like ---> lik
# a ---> a
# plan ---> plan
# We ---> we
# sure ---> sur
# you ---> you
# love ---> lov
# it ---> it
# Let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# Welcome ---> welcom
# back ---> back
# Michelle ---> michel
# It ---> it
# like ---> lik
# riding ---> rid
# a ---> a
# bicycle ---> bicyc
# Made ---> mad
# out ---> out
# of ---> of
# guns ---> gun
# Sounds ---> sound
# like ---> lik
# a ---> a
# Monday ---> monday
# well ---> wel
# spent ---> spent
# to ---> to
# us ---> us
# We ---> we
# applaud ---> applaud
# his ---> his
# dedication ---> ded
# Epic ---> ep
# clip ---> clip
# We ---> we
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> mor
# Have ---> hav
# a ---> a
# great ---> gre
# time ---> tim
# playing ---> play
# through ---> through
# them ---> them
# Thanks ---> thank
# Jon ---> jon
# Will ---> wil
# you ---> you
# be ---> be
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# soon ---> soon
# A ---> a
# great ---> gre
# day ---> day
# indeed ---> indee
# Are ---> ar
# you ---> you
# playing ---> play
# Mass ---> mass
# Effect ---> effect
# right ---> right
# now ---> now
# Incredible ---> incred
# Your ---> yo
# gamerscore ---> gamersc
# must ---> must
# be ---> be
# crazy ---> crazy
# Awesome ---> awesom
# What ---> what
# game ---> gam
# were ---> wer
# you ---> you
# streaming ---> streaming
# And ---> and
# then ---> then
# we ---> we
# responded ---> respond
# on ---> on
# yours ---> yo
# Everyone ---> everyon
# can ---> can
# enjoy ---> enjoy
# Xbox ---> xbox
# But ---> but
# it ---> it
# great ---> gre
# to ---> to
# hear ---> hear
# that ---> that
# we ---> we
# can ---> can
# bring ---> bring
# generations ---> gen
# together ---> togeth
# Someone ---> someon
# in ---> in
# for ---> for
# a ---> a
# very ---> very
# bad ---> bad
# day ---> day
# She ---> she
# looks ---> look
# like ---> lik
# a ---> a
# serious ---> sery
# piece ---> piec
# of ---> of
# hardware ---> hardw
# Mel ---> mel

# %% [markdown]
# ## Regexp Stemming

# %%
from nltk.stem import RegexpStemmer
regexp = RegexpStemmer('es$|d$|ing$|s$|able$', min=4)

for token in tokens:
  print(token,"--->", regexp.stem(token))
# Out:
# Feeling ---> Feel
# thankful ---> thankful
# Tag ---> Tag
# friends ---> friend
# XboxSweepstakes ---> XboxSweepstak
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# M ---> M
# digital ---> digital
# codes ---> cod
# Rules ---> Rul
# http ---> http
# Holiday ---> Holiday
# parties ---> parti
# are ---> are
# the ---> the
# worst ---> worst
# M ---> M
# http ---> http
# Now ---> Now
# through ---> through
# Monday ---> Monday
# enjoy ---> enjoy
# free ---> free
# engraving ---> engrav
# on ---> on
# all ---> all
# XboxDesignLab ---> XboxDesignLab
# controllers ---> controller
# Start ---> Start
# building ---> build
# yours ---> your
# at ---> at
# http ---> http
# Make ---> Make
# your ---> your
# own ---> own
# zombie ---> zombie
# musical ---> musical
# number ---> number
# inspired ---> inspire
# by ---> by
# M ---> M
# http ---> http
# This ---> Thi
# Week ---> Week
# on ---> on
# Xbox ---> Xbox
# FFXV ---> FFXV
# T ---> T
# The ---> The
# Division ---> Division
# M ---> M
# Survival ---> Survival
# and ---> and
# Episode ---> Episode
# of ---> of
# telltalegames ---> telltalegam
# Batman ---> Batman
# M ---> M
# http ---> http
# Celebrate ---> Celebrate
# woodyinho ---> woodyinho
# jamesrodriguez ---> jamesrodriguez
# anthonymartial ---> anthonymartial
# in ---> in
# the ---> the
# E ---> E
# free ---> free
# trial ---> trial
# out ---> out
# now ---> now
# http ---> http
# Sounds ---> Sound
# like ---> like
# Austin ---> Austin
# is ---> is
# a ---> a
# pretty ---> pretty
# good ---> goo
# player ---> player
# huh ---> huh
# We ---> We
# glad ---> gla
# you ---> you
# had ---> had
# a ---> a
# successful ---> successful
# Black ---> Black
# Friday ---> Friday
# What ---> What
# games ---> gam
# did ---> did
# you ---> you
# get ---> get
# Which ---> Which
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# choosing ---> choos
# If ---> If
# that ---> that
# is ---> is
# true ---> true
# love ---> love
# then ---> then
# we ---> we
# do ---> do
# know ---> know
# what ---> what
# is ---> is
# Which ---> Which
# bundle ---> bundle
# did ---> did
# you ---> you
# get ---> get
# him ---> him
# Awesome ---> Awesome
# is ---> is
# right ---> right
# Did ---> Did
# you ---> you
# end ---> end
# up ---> up
# getting ---> gett
# it ---> it
# Those ---> Those
# are ---> are
# the ---> the
# best ---> best
# What ---> What
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# We ---> We
# say ---> say
# you ---> you
# were ---> were
# pretty ---> pretty
# successful ---> successful
# We ---> We
# love ---> love
# that ---> that
# idea ---> idea
# What ---> What
# did ---> did
# you ---> you
# play ---> play
# Welcome ---> Welcome
# to ---> to
# the ---> the
# Xbox ---> Xbox
# One ---> One
# family ---> family
# What ---> What
# games ---> gam
# did ---> did
# you ---> you
# get ---> get
# We ---> We
# glad ---> gla
# you ---> you
# could ---> coul
# take ---> take
# advantage ---> advantage
# of ---> of
# this ---> thi
# great ---> great
# deal ---> deal
# Which ---> Which
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> We
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Which ---> Which
# games ---> gam
# did ---> did
# you ---> you
# pick ---> pick
# We ---> We
# love ---> love
# to ---> to
# hear ---> hear
# that ---> that
# Do ---> Do
# you ---> you
# think ---> think
# you ---> you
# replay ---> replay
# it ---> it
# anytime ---> anytime
# soon ---> soon
# We ---> We
# know ---> know
# what ---> what
# that ---> that
# like ---> like
# You ---> You
# get ---> get
# home ---> home
# and ---> and
# game ---> game
# yet ---> yet
# We ---> We
# love ---> love
# the ---> the
# sound ---> soun
# of ---> of
# that ---> that
# Are ---> Are
# you ---> you
# hoping ---> hop
# for ---> for
# any ---> any
# specific ---> specific
# bundles ---> bundl
# We ---> We
# ca ---> ca
# wait ---> wait
# either ---> either
# When ---> When
# do ---> do
# you ---> you
# plan ---> plan
# on ---> on
# getting ---> gett
# one ---> one
# Personalized ---> Personalize
# just ---> just
# for ---> for
# you ---> you
# We ---> We
# loving ---> lov
# this ---> thi
# design ---> design
# Sounds ---> Sound
# like ---> like
# the ---> the
# perfect ---> perfect
# birthday ---> birthday
# Which ---> Which
# games ---> gam
# did ---> did
# you ---> you
# end ---> end
# up ---> up
# getting ---> gett
# for ---> for
# Black ---> Black
# Friday ---> Friday
# Boom ---> Boom
# That ---> That
# going ---> go
# to ---> to
# keep ---> keep
# you ---> you
# busy ---> busy
# Awesome ---> Awesome
# Sounds ---> Sound
# like ---> like
# a ---> a
# pretty ---> pretty
# good ---> goo
# Black ---> Black
# Friday ---> Friday
# huh ---> huh
# Thanks ---> Thank
# for ---> for
# the ---> the
# shoutout ---> shoutout
# Did ---> Did
# you ---> you
# get ---> get
# any ---> any
# other ---> other
# games ---> gam
# along ---> along
# with ---> with
# Fifa ---> Fifa
# Sometimes ---> Sometim
# it ---> it
# good ---> goo
# to ---> to
# upgrade ---> upgrade
# Is ---> Is
# this ---> thi
# all ---> all
# you ---> you
# got ---> got
# for ---> for
# your ---> your
# gaming ---> gam
# set ---> set
# up ---> up
# Live ---> Live
# now ---> now
# Tune ---> Tune
# in ---> in
# to ---> to
# the ---> the
# Gears ---> Gear
# Pro ---> Pro
# Circuit ---> Circuit
# Open ---> Open
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> XboxOneS
# http ---> http
# GearsofWar ---> GearsofWar
# M ---> M
# Sounds ---> Sound
# like ---> like
# a ---> a
# pretty ---> pretty
# great ---> great
# holiday ---> holiday
# Did ---> Did
# you ---> you
# get ---> get
# a ---> a
# specific ---> specific
# bundle ---> bundle
# We ---> We
# loving ---> lov
# the ---> the
# color ---> color
# scheme ---> scheme
# You ---> You
# take ---> take
# it ---> it
# for ---> for
# a ---> a
# spin ---> spin
# already ---> already
# Sounds ---> Sound
# like ---> like
# your ---> your
# Black ---> Black
# Friday ---> Friday
# was ---> was
# a ---> a
# huge ---> huge
# success ---> succes
# That ---> That
# a ---> a
# very ---> very
# good ---> goo
# way ---> way
# to ---> to
# celebrate ---> celebrate
# if ---> if
# you ---> you
# ask ---> ask
# us ---> us
# You ---> You
# better ---> better
# believe ---> believe
# it ---> it
# For ---> For
# some ---> some
# things ---> thing
# an ---> an
# exception ---> exception
# must ---> must
# be ---> be
# made ---> made
# Looks ---> Look
# like ---> like
# you ---> you
# made ---> made
# the ---> the
# most ---> most
# of ---> of
# Black ---> Black
# Friday ---> Friday
# this ---> thi
# year ---> year
# At ---> At
# least ---> least
# you ---> you
# got ---> got
# the ---> the
# essentials ---> essential
# Technically ---> Technically
# we ---> we
# do ---> do
# play ---> play
# DVD ---> DVD
# and ---> and
# Blu ---> Blu
# Rays ---> Ray
# sounds ---> sound
# like ---> like
# a ---> a
# Looks ---> Look
# like ---> like
# it ---> it
# was ---> was
# your ---> your
# Destiny ---> Destiny
# to ---> to
# get ---> get
# great ---> great
# deals ---> deal
# today ---> today
# Sounds ---> Sound
# like ---> like
# a ---> a
# very ---> very
# successful ---> successful
# day ---> day
# Sounds ---> Sound
# like ---> like
# it ---> it
# was ---> was
# a ---> a
# good ---> goo
# day ---> day
# We ---> We
# loving ---> lov
# the ---> the
# color ---> color
# Browse ---> Browse
# BlackFriday ---> BlackFriday
# deals ---> deal
# on ---> on
# top ---> top
# Xbox ---> Xbox
# games ---> gam
# like ---> like
# Skyrim ---> Skyrim
# Special ---> Special
# Edition ---> Edition
# M ---> M
# DOOM ---> DOOM
# M ---> M
# and ---> and
# more ---> more
# http ---> http
# Awesome ---> Awesome
# Trust ---> Trust
# us ---> us
# the ---> the
# Horizon ---> Horizon
# Festival ---> Festival
# just ---> just
# keeps ---> keep
# getting ---> gett
# better ---> better
# Get ---> Get
# the ---> the
# undead ---> undea
# party ---> party
# started ---> starte
# Check ---> Check
# out ---> out
# the ---> the
# M ---> M
# lens ---> len
# now ---> now
# on ---> on
# Snapchat ---> Snapchat
# Sounds ---> Sound
# like ---> like
# it ---> it
# gon ---> gon
# na ---> na
# be ---> be
# a ---> a
# good ---> goo
# day ---> day
# Feel ---> Feel
# the ---> the
# difference ---> difference
# Pick ---> Pick
# up ---> up
# the ---> the
# XboxElite ---> XboxElite
# at ---> at
# a ---> a
# MicrosoftStore ---> MicrosoftStore
# near ---> near
# you ---> you
# http ---> http
# Have ---> Have
# fun ---> fun
# Holli ---> Holli
# Epic ---> Epic
# We ---> We
# hope ---> hope
# you ---> you
# have ---> have
# fun ---> fun
# That ---> That
# makes ---> mak
# you ---> you
# an ---> an
# awesome ---> awesome
# human ---> human
# being ---> be
# You ---> You
# know ---> know
# it ---> it
# What ---> What
# have ---> have
# you ---> you
# picked ---> picke
# up ---> up
# so ---> so
# far ---> far
# Woot ---> Woot
# woot ---> woot
# Now ---> Now
# that ---> that
# an ---> an
# awesome ---> awesome
# pick ---> pick
# up ---> up
# Grab ---> Grab
# ahold ---> ahol
# of ---> of
# happiness ---> happines
# BlackFriday ---> BlackFriday
# Get ---> Get
# the ---> the
# XboxOneS ---> XboxOneS
# at ---> at
# our ---> our
# lowest ---> lowest
# price ---> price
# yet ---> yet
# Shop ---> Shop
# the ---> the
# BlackFriday ---> BlackFriday
# sale ---> sale
# at ---> at
# http ---> http
# Every ---> Every
# achievement ---> achievement
# is ---> is
# a ---> a
# tiny ---> tiny
# parade ---> parade
# Celebrate ---> Celebrate
# yours ---> your
# this ---> thi
# Thanksgiving ---> Thanksgiv
# Our ---> Our
# gear ---> gear
# Your ---> Your
# design ---> design
# Start ---> Start
# building ---> build
# your ---> your
# Xbox ---> Xbox
# controller ---> controller
# at ---> at
# http ---> http
# XboxDesignLab ---> XboxDesignLab
# It ---> It
# just ---> just
# that ---> that
# many ---> many
# more ---> more
# achievements ---> achievement
# for ---> for
# you ---> you
# to ---> to
# hunt ---> hunt
# XboxOne ---> XboxOne
# The ---> The
# best ---> best
# controller ---> controller
# make ---> make
# no ---> no
# XboxOne ---> XboxOne
# Tag ---> Tag
# friends ---> friend
# you ---> you
# thankful ---> thankful
# for ---> for
# XboxSweepstakes ---> XboxSweepstak
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# digital ---> digital
# codes ---> cod
# of ---> of
# M ---> M
# Rules ---> Rul
# http ---> http
# Ooh ---> Ooh
# that ---> that
# a ---> a
# tough ---> tough
# one ---> one
# At ---> At
# least ---> least
# it ---> it
# a ---> a
# choice ---> choice
# No ---> No
# sweat ---> sweat
# Have ---> Have
# a ---> a
# blast ---> blast
# Anthony ---> Anthony
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# having ---> hav
# so ---> so
# much ---> much
# fun ---> fun
# streaming ---> stream
# There ---> There
# absolutely ---> absolutely
# is ---> is
# just ---> just
# follow ---> follow
# this ---> thi
# guide ---> guide
# UI ---> UI
# may ---> may
# differ ---> differ
# http ---> http
# It ---> It
# does ---> do
# look ---> look
# amazing ---> amaz
# Good ---> Goo
# plan ---> plan
# Have ---> Have
# fun ---> fun
# The ---> The
# only ---> only
# people ---> people
# who ---> who
# should ---> shoul
# be ---> be
# alarmed ---> alarme
# are ---> are
# your ---> your
# opponents ---> opponent
# We ---> We
# sure ---> sure
# you ---> you
# can ---> can
# find ---> fin
# time ---> time
# for ---> for
# both ---> both
# Cruise ---> Cruise
# into ---> into
# BlackFriday ---> BlackFriday
# with ---> with
# off ---> off
# E ---> E
# now ---> now
# through ---> through
# November ---> November
# http ---> http
# Time ---> Time
# to ---> to
# find ---> fin
# some ---> some
# savings ---> saving
# XboxOne ---> XboxOne
# Join ---> Join
# Clubs ---> Club
# find ---> fin
# players ---> player
# and ---> and
# download ---> downloa
# GamesWithGold ---> GamesWithGol
# from ---> from
# your ---> your
# smartphone ---> smartphone
# with ---> with
# the ---> the
# Xbox ---> Xbox
# app ---> app
# Download ---> Downloa
# http ---> http
# Thanks ---> Thank
# Brandon ---> Brandon
# That ---> That
# great ---> great
# to ---> to
# hear ---> hear
# The ---> The
# big ---> big
# question ---> question
# is ---> is
# which ---> which
# game ---> game
# will ---> will
# you ---> you
# be ---> be
# booting ---> boot
# up ---> up
# first ---> first
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# it ---> it
# Thanks ---> Thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Looks ---> Look
# like ---> like
# quite ---> quite
# the ---> the
# haul ---> haul
# We ---> We
# right ---> right
# there ---> there
# with ---> with
# you ---> you
# Save ---> Save
# cash ---> cash
# Save ---> Save
# Sera ---> Sera
# M ---> M
# is ---> is
# on ---> on
# sale ---> sale
# now ---> now
# http ---> http
# BlackFriday ---> BlackFriday
# How ---> How
# did ---> did
# it ---> it
# end ---> end
# up ---> up
# working ---> work
# out ---> out
# for ---> for
# you ---> you
# Emily ---> Emily
# That ---> That
# the ---> the
# way ---> way
# to ---> to
# go ---> go
# Buy ---> Buy
# digital ---> digital
# Play ---> Play
# anywhere ---> anywhere
# Learn ---> Learn
# how ---> how
# at ---> at
# http ---> http
# XboxPlayAnywhere ---> XboxPlayAnywhere
# Hard ---> Har
# weather ---> weather
# heads ---> head
# to ---> to
# New ---> New
# York ---> York
# with ---> with
# today ---> today
# release ---> release
# of ---> of
# TheDivision ---> TheDivision
# M ---> M
# Survival ---> Survival
# Get ---> Get
# the ---> the
# new ---> new
# DLC ---> DLC
# at ---> at
# http ---> http
# Battlepacks ---> Battlepack
# are ---> are
# now ---> now
# available ---> avail
# for ---> for
# purchase ---> purchase
# in ---> in
# Battlefield ---> Battlefiel
# M ---> M
# http ---> http
# Forge ---> Forge
# an ---> an
# alliance ---> alliance
# with ---> with
# The ---> The
# Clown ---> Clown
# Prince ---> Prince
# of ---> of
# Crime ---> Crime
# in ---> in
# BATMAN ---> BATMAN
# The ---> The
# Telltale ---> Telltale
# Series ---> Seri
# M ---> M
# Episode ---> Episode
# is ---> is
# out ---> out
# now ---> now
# http ---> http
# The ---> The
# only ---> only
# question ---> question
# is ---> is
# which ---> which
# squad ---> squa
# member ---> member
# did ---> did
# you ---> you
# use ---> use
# for ---> for
# gaming ---> gam
# today ---> today
# We ---> We
# ca ---> ca
# wait ---> wait
# to ---> to
# be ---> be
# shouting ---> shout
# out ---> out
# a ---> a
# game ---> game
# that ---> that
# you ---> you
# worked ---> worke
# on ---> on
# over ---> over
# our ---> our
# channels ---> channel
# Thanks ---> Thank
# for ---> for
# awesome ---> awesome
# years ---> year
# Mason ---> Mason
# Oh ---> Oh
# no ---> no
# Guess ---> Gues
# it ---> it
# the ---> the
# only ---> only
# way ---> way
# to ---> to
# keep ---> keep
# both ---> both
# your ---> your
# mind ---> min
# and ---> and
# your ---> your
# gaming ---> gam
# skills ---> skill
# sharp ---> sharp
# It ---> It
# definitely ---> definitely
# a ---> a
# good ---> goo
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# Now ---> Now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# What ---> What
# game ---> game
# did ---> did
# you ---> you
# get ---> get
# it ---> it
# with ---> with
# Whoa ---> Whoa
# Now ---> Now
# those ---> those
# are ---> are
# some ---> some
# serious ---> seriou
# classics ---> classic
# Gear ---> Gear
# up ---> up
# on ---> on
# BlackFriday ---> BlackFriday
# with ---> with
# off ---> off
# M ---> M
# available ---> avail
# now ---> now
# at ---> at
# http ---> http
# We ---> We
# could ---> coul
# think ---> think
# of ---> of
# a ---> a
# better ---> better
# XboxOne ---> XboxOne
# It ---> It
# coming ---> com
# together ---> together
# nicely ---> nicely
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# the ---> the
# pic ---> pic
# Have ---> Have
# a ---> a
# great ---> great
# week ---> week
# We ---> We
# looking ---> look
# forward ---> forwar
# Xbox ---> Xbox
# heavy ---> heavy
# holidays ---> holiday
# as ---> as
# well ---> well
# No ---> No
# arguments ---> argument
# here ---> here
# You ---> You
# should ---> shoul
# pick ---> pick
# it ---> it
# up ---> up
# Devin ---> Devin
# That ---> That
# awesome ---> awesome
# We ---> We
# sure ---> sure
# it ---> it
# will ---> will
# make ---> make
# an ---> an
# amazing ---> amaz
# early ---> early
# present ---> present
# We ---> We
# got ---> got
# to ---> to
# agree ---> agree
# with ---> with
# you ---> you
# there ---> there
# Hopefully ---> Hopefully
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> gam
# Hello ---> Hello
# there ---> there
# Oh ---> Oh
# nice ---> nice
# That ---> That
# pretty ---> pretty
# creative ---> creative
# We ---> We
# were ---> were
# always ---> alway
# fans ---> fan
# of ---> of
# their ---> their
# logo ---> logo
# There ---> There
# always ---> alway
# tomorrow ---> tomorrow
# and ---> and
# there ---> there
# ca ---> ca
# be ---> be
# an ---> an
# essay ---> essay
# every ---> every
# day ---> day
# D ---> D
# Good ---> Goo
# plan ---> plan
# JJ ---> JJ
# Pick ---> Pick
# up ---> up
# some ---> some
# snacks ---> snack
# while ---> while
# you ---> you
# there ---> there
# We ---> We
# have ---> have
# http ---> http
# What ---> What
# better ---> better
# way ---> way
# to ---> to
# weather ---> weather
# winter ---> winter
# than ---> than
# with ---> with
# new ---> new
# GamesWithGold ---> GamesWithGol
# Learn ---> Learn
# more ---> more
# about ---> about
# December ---> December
# picks ---> pick
# at ---> at
# http ---> http
# Awesome ---> Awesome
# work ---> work
# You ---> You
# know ---> know
# it ---> it
# You ---> You
# kept ---> kept
# it ---> it
# all ---> all
# this ---> thi
# time ---> time
# Now ---> Now
# we ---> we
# blushing ---> blush
# There ---> There
# nothing ---> noth
# wrong ---> wrong
# with ---> with
# being ---> be
# an ---> an
# Xbox ---> Xbox
# fan ---> fan
# Have ---> Have
# fun ---> fun
# Awesome ---> Awesome
# Have ---> Have
# fun ---> fun
# with ---> with
# it ---> it
# when ---> when
# it ---> it
# arrives ---> arriv
# XboxOne ---> XboxOne
# to ---> to
# Oculus ---> Oculu
# streaming ---> stream
# arrives ---> arriv
# December ---> December
# with ---> with
# the ---> the
# XboxOne ---> XboxOne
# Streaming ---> Stream
# app ---> app
# Learn ---> Learn
# more ---> more
# at ---> at
# http ---> http
# It ---> It
# definitely ---> definitely
# worth ---> worth
# checking ---> check
# out ---> out
# Carlos ---> Carlo
# Have ---> Have
# fun ---> fun
# Thanks ---> Thank
# We ---> We
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chance
# to ---> to
# play ---> play
# them ---> them
# all ---> all
# The ---> The
# best ---> best
# time ---> time
# of ---> of
# the ---> the
# day ---> day
# We ---> We
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> gam
# Have ---> Have
# fun ---> fun
# with ---> with
# them ---> them
# We ---> We
# wrapping ---> wrapp
# up ---> up
# with ---> with
# a ---> a
# bang ---> bang
# D ---> D
# Burnout ---> Burnout
# Paradise ---> Paradise
# is ---> is
# now ---> now
# on ---> on
# XboxOne ---> XboxOne
# via ---> via
# BackwardCompatibility ---> BackwardCompatibility
# Get ---> Get
# it ---> it
# free ---> free
# on ---> on
# GamesWithGold ---> GamesWithGol
# http ---> http
# You ---> You
# did ---> did
# a ---> a
# good ---> goo
# thing ---> th
# It ---> It
# the ---> the
# little ---> little
# things ---> thing
# right ---> right
# Thanks ---> Thank
# for ---> for
# the ---> the
# love ---> love
# Dylan ---> Dylan
# What ---> What
# an ---> an
# awesome ---> awesome
# gift ---> gift
# We ---> We
# sure ---> sure
# he ---> he
# love ---> love
# it ---> it
# We ---> We
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# A ---> A
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Josh ---> Josh
# Sounds ---> Sound
# like ---> like
# a ---> a
# relaxing ---> relax
# morning ---> morn
# to ---> to
# us ---> us
# It ---> It
# quite ---> quite
# beautiful ---> beautiful
# is ---> is
# it ---> it
# How ---> How
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# Thanks ---> Thank
# for ---> for
# the ---> the
# feedback ---> feedback
# We ---> We
# appreciate ---> appreciate
# it ---> it
# You ---> You
# sure ---> sure
# know ---> know
# how ---> how
# to ---> to
# spread ---> sprea
# the ---> the
# love ---> love
# We ---> We
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# We ---> We
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# Ashley ---> Ashley
# You ---> You
# got ---> got
# real ---> real
# good ---> goo
# taste ---> taste
# in ---> in
# games ---> gam
# That ---> That
# looks ---> look
# awesome ---> awesome
# How ---> How
# did ---> did
# you ---> you
# come ---> come
# up ---> up
# with ---> with
# red ---> red
# and ---> and
# blue ---> blue
# Timeless ---> Timeles
# as ---> as
# always ---> alway
# We ---> We
# love ---> love
# it ---> it
# Thanks ---> Thank
# for ---> for
# participating ---> participat
# Sylvia ---> Sylvia
# Thanks ---> Thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesome
# fan ---> fan
# and ---> and
# gamer ---> gamer
# Hunter ---> Hunter
# You ---> You
# kept ---> kept
# the ---> the
# box ---> box
# How ---> How
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# celebrate ---> celebrate
# BlackFriday ---> BlackFriday
# is ---> is
# here ---> here
# Save ---> Save
# up ---> up
# to ---> to
# on ---> on
# Xbox ---> Xbox
# games ---> gam
# and ---> and
# go ---> go
# Gold ---> Gol
# to ---> to
# save ---> save
# up ---> up
# to ---> to
# more ---> more
# See ---> See
# the ---> the
# deals ---> deal
# http ---> http
# Thanks ---> Thank
# We ---> We
# hope ---> hope
# you ---> you
# enjoy ---> enjoy
# all ---> all
# the ---> the
# games ---> gam
# Thanks ---> Thank
# What ---> What
# game ---> game
# are ---> are
# you ---> you
# most ---> most
# excited ---> excite
# for ---> for
# It ---> It
# about ---> about
# to ---> to
# go ---> go
# down ---> down
# Woot ---> Woot
# woot ---> woot
# Awesome ---> Awesome
# deal ---> deal
# Oh ---> Oh
# hey ---> hey
# Whaddup ---> Whaddup
# Sounds ---> Sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Which ---> Which
# bundle ---> bundle
# do ---> do
# you ---> you
# have ---> have
# your ---> your
# eye ---> eye
# on ---> on
# Thanks ---> Thank
# for ---> for
# the ---> the
# Dustin ---> Dustin
# Glad ---> Gla
# to ---> to
# see ---> see
# that ---> that
# we ---> we
# could ---> coul
# help ---> help
# hook ---> hook
# you ---> you
# up ---> up
# Right ---> Right
# What ---> What
# an ---> an
# awesome ---> awesome
# deal ---> deal
# Adam ---> Adam
# speaks ---> speak
# the ---> the
# truth ---> truth
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# so ---> so
# hyped ---> hype
# that ---> that
# awesome ---> awesome
# Welcome ---> Welcome
# to ---> to
# the ---> the
# Xbox ---> Xbox
# One ---> One
# family ---> family
# Very ---> Very
# nice ---> nice
# Keep ---> Keep
# up ---> up
# the ---> the
# good ---> goo
# work ---> work
# We ---> We
# be ---> be
# waiting ---> wait
# You ---> You
# got ---> got
# good ---> goo
# taste ---> taste
# in ---> in
# games ---> gam
# Be ---> Be
# sure ---> sure
# to ---> to
# let ---> let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# The ---> The
# best ---> best
# kind ---> kin
# of ---> of
# break ---> break
# You ---> You
# know ---> know
# what ---> what
# up ---> up
# Matt ---> Matt
# Sometimes ---> Sometim
# it ---> it
# just ---> just
# takes ---> tak
# a ---> a
# little ---> little
# motivation ---> motivation
# It ---> It
# is ---> is
# not ---> not
# How ---> How
# far ---> far
# have ---> have
# you ---> you
# managed ---> manage
# to ---> to
# make ---> make
# it ---> it
# Looking ---> Look
# good ---> goo
# It ---> It
# Gearing ---> Gear
# up ---> up
# to ---> to
# be ---> be
# a ---> a
# great ---> great
# day ---> day
# Awesome ---> Awesome
# The ---> The
# sign ---> sign
# of ---> of
# a ---> a
# great ---> great
# Pilot ---> Pilot
# You ---> You
# doing ---> do
# great ---> great
# Angel ---> Angel
# Keep ---> Keep
# up ---> up
# the ---> the
# good ---> goo
# work ---> work
# No ---> No
# problem ---> problem
# Good ---> Goo
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Playing ---> Play
# M ---> M
# Try ---> Try
# out ---> out
# these ---> these
# maps ---> map
# for ---> for
# your ---> your
# XboxElite ---> XboxElite
# http ---> http
# You ---> You
# got ---> got
# so ---> so
# much ---> much
# gaming ---> gam
# ahead ---> ahea
# of ---> of
# you ---> you
# We ---> We
# envious ---> enviou
# Have ---> Have
# another ---> another
# great ---> great
# stream ---> stream
# Peter ---> Peter
# We ---> We
# looking ---> look
# forward ---> forwar
# to ---> to
# seeing ---> see
# it ---> it
# This ---> Thi
# is ---> is
# a ---> a
# great ---> great
# time ---> time
# to ---> to
# pick ---> pick
# both ---> both
# of ---> of
# them ---> them
# up ---> up
# http ---> http
# We ---> We
# glad ---> gla
# that ---> that
# you ---> you
# loving ---> lov
# it ---> it
# Alyssa ---> Alyssa
# Pizza ---> Pizza
# party ---> party
# at ---> at
# your ---> your
# house ---> house
# We ---> We
# glad ---> gla
# that ---> that
# you ---> you
# liking ---> lik
# it ---> it
# What ---> What
# clubs ---> club
# have ---> have
# you ---> you
# joined ---> joine
# so ---> so
# far ---> far
# Do ---> Do
# worry ---> worry
# we ---> we
# got ---> got
# your ---> your
# back ---> back
# We ---> We
# see ---> see
# you ---> you
# at ---> at
# the ---> the
# Horizon ---> Horizon
# Festival ---> Festival
# Forza ---> Forza
# Horizon ---> Horizon
# is ---> is
# also ---> also
# available ---> avail
# for ---> for
# Windows ---> Window
# Good ---> Goo
# luck ---> luck
# getting ---> gett
# to ---> to
# the ---> the
# wave ---> wave
# We ---> We
# ca ---> ca
# argue ---> argue
# with ---> with
# that ---> that
# We ---> We
# loving ---> lov
# it ---> it
# too ---> too
# Enter ---> Enter
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> XboxOneS
# when ---> when
# you ---> you
# order ---> order
# a ---> a
# Triple ---> Triple
# Treat ---> Treat
# Box ---> Box
# from ---> from
# PizzaHut ---> PizzaHut
# Offer ---> Offer
# ends ---> end
# Rules ---> Rul
# http ---> http
# Be ---> Be
# sure ---> sure
# to ---> to
# report ---> report
# the ---> the
# account ---> account
# http ---> http
# Our ---> Our
# condolences ---> condolenc
# But ---> But
# we ---> we
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# got ---> got
# some ---> some
# great ---> great
# memories ---> memori
# together ---> together
# on ---> on
# the ---> the
# Xbox ---> Xbox
# Awesome ---> Awesome
# article ---> article
# Michael ---> Michael
# We ---> We
# glad ---> gla
# that ---> that
# you ---> you
# been ---> been
# with ---> with
# us ---> us
# since ---> since
# the ---> the
# very ---> very
# beginning ---> beginn
# From ---> From
# behind ---> behin
# Great ---> Great
# clip ---> clip
# Awesome ---> Awesome
# work ---> work
# We ---> We
# love ---> love
# chatting ---> chatt
# with ---> with
# our ---> our
# awesome ---> awesome
# fans ---> fan
# Great ---> Great
# choice ---> choice
# with ---> with
# Mafia ---> Mafia
# III ---> III
# Looking ---> Look
# great ---> great
# so ---> so
# far ---> far
# What ---> What
# game ---> game
# have ---> have
# you ---> you
# played ---> playe
# the ---> the
# most ---> most
# Smart ---> Smart
# thinking ---> think
# Dessmond ---> Dessmon
# Looking ---> Look
# for ---> for
# a ---> a
# holiday ---> holiday
# escape ---> escape
# M ---> M
# today ---> today
# and ---> and
# play ---> play
# it ---> it
# December ---> December
# http ---> http
# Awesome ---> Awesome
# Which ---> Which
# game ---> game
# were ---> were
# you ---> you
# playing ---> play
# Watch ---> Watch
# Lesnar ---> Lesnar
# battle ---> battle
# Goldberg ---> Goldberg
# live ---> live
# tonight ---> tonight
# at ---> at
# PM ---> PM
# PT ---> PT
# on ---> on
# the ---> the
# WWENetwork ---> WWENetwork
# app ---> app
# Learn ---> Learn
# more ---> more
# http ---> http
# WWESurvivorSeries ---> WWESurvivorSeri
# Catch ---> Catch
# the ---> the
# final ---> final
# day ---> day
# of ---> of
# HCS ---> HCS
# Las ---> Las
# Vegas ---> Vega
# live ---> live
# on ---> on
# Twitch ---> Twitch
# Halo ---> Halo
# top ---> top
# players ---> player
# are ---> are
# competing ---> compet
# now ---> now
# http ---> http
# Now ---> Now
# through ---> through
# November ---> November
# save ---> save
# when ---> when
# you ---> you
# buy ---> buy
# any ---> any
# XboxOneS ---> XboxOneS
# console ---> console
# or ---> or
# console ---> console
# bundle ---> bundle
# http ---> http
# Halos ---> Halo
# and ---> and
# Death ---> Death
# Stars ---> Star
# superweapons ---> superweapon
# are ---> are
# your ---> your
# specialty ---> specialty
# Stream ---> Stream
# movies ---> movi
# and ---> and
# TV ---> TV
# with ---> with
# the ---> the
# new ---> new
# FandangoNOW ---> FandangoNOW
# app ---> app
# plus ---> plu
# get ---> get
# off ---> off
# your ---> your
# first ---> first
# transaction ---> transaction
# on ---> on
# XboxOne ---> XboxOne
# http ---> http
# Watch ---> Watch
# UFC ---> UFC
# Fight ---> Fight
# Night ---> Night
# Mousasi ---> Mousasi
# vs ---> vs
# Hall ---> Hall
# today ---> today
# on ---> on
# the ---> the
# Xbox ---> Xbox
# UFC ---> UFC
# app ---> app
# Learn ---> Learn
# more ---> more
# http ---> http
# MLG ---> MLG
# and ---> and
# GearsofWar ---> GearsofWar
# M ---> M
# are ---> are
# back ---> back
# together ---> together
# for ---> for
# the ---> the
# first ---> first
# Pro ---> Pro
# Circuit ---> Circuit
# in ---> in
# years ---> year
# Be ---> Be
# there ---> there
# November ---> November
# Passes ---> Pass
# http ---> http
# Stand ---> Stan
# by ---> by
# for ---> for
# savings ---> saving
# M ---> M
# is ---> is
# now ---> now
# off ---> off
# http ---> http
# We ---> We
# down ---> down
# with ---> with
# this ---> thi
# plan ---> plan
# Only ---> Only
# because ---> because
# of ---> of
# awesome ---> awesome
# fans ---> fan
# like ---> like
# you ---> you
# We ---> We
# love ---> love
# living ---> liv
# in ---> in
# the ---> the
# future ---> future
# Better ---> Better
# catnip ---> catnip
# than ---> than
# something ---> someth
# like ---> like
# skooma ---> skooma
# Get ---> Get
# days ---> day
# free ---> free
# of ---> of
# Sling ---> Sl
# TV ---> TV
# exclusively ---> exclusively
# on ---> on
# XboxOne ---> XboxOne
# Learn ---> Learn
# more ---> more
# at ---> at
# http ---> http
# You ---> You
# a ---> a
# five ---> five
# star ---> star
# fan ---> fan
# Sounds ---> Sound
# like ---> like
# a ---> a
# plan ---> plan
# to ---> to
# us ---> us
# Very ---> Very
# nice ---> nice
# Talk ---> Talk
# about ---> about
# a ---> a
# classic ---> classic
# Play ---> Play
# E ---> E
# free ---> free
# this ---> thi
# weekend ---> weeken
# with ---> with
# XboxLive ---> XboxLive
# Gold ---> Gol
# Learn ---> Learn
# more ---> more
# at ---> at
# http ---> http
# You ---> You
# got ---> got
# this ---> thi
# We ---> We
# believe ---> believe
# in ---> in
# you ---> you
# That ---> That
# what ---> what
# up ---> up
# Looks ---> Look
# like ---> like
# you ---> you
# got ---> got
# a ---> a
# ton ---> ton
# of ---> of
# awesome ---> awesome
# gaming ---> gam
# ahead ---> ahea
# of ---> of
# you ---> you
# We ---> We
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Very ---> Very
# nice ---> nice
# Thanks ---> Thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedicate
# fan ---> fan
# Thanks ---> Thank
# so ---> so
# much ---> much
# Mark ---> Mark
# Glad ---> Gla
# we ---> we
# could ---> coul
# hook ---> hook
# you ---> you
# up ---> up
# with ---> with
# so ---> so
# many ---> many
# other ---> other
# awesome ---> awesome
# gamers ---> gamer
# This ---> Thi
# weekend ---> weeken
# play ---> play
# Overwatch ---> Overwatch
# T ---> T
# for ---> for
# free ---> free
# Start ---> Start
# playing ---> play
# today ---> today
# on ---> on
# XboxOne ---> XboxOne
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Thanks ---> Thank
# for ---> for
# picking ---> pick
# up ---> up
# so ---> so
# many ---> many
# cool ---> cool
# games ---> gam
# Are ---> Are
# you ---> you
# all ---> all
# set ---> set
# for ---> for
# the ---> the
# winter ---> winter
# It ---> It
# so ---> so
# hard ---> har
# to ---> to
# narrow ---> narrow
# down ---> down
# that ---> that
# wish ---> wish
# list ---> list
# Have ---> Have
# fun ---> fun
# with ---> with
# whatever ---> whatever
# you ---> you
# decide ---> decide
# to ---> to
# pick ---> pick
# up ---> up
# Scott ---> Scott
# This ---> Thi
# Week ---> Week
# on ---> on
# Xbox ---> Xbox
# join ---> join
# us ---> us
# for ---> for
# the ---> the
# release ---> release
# of ---> of
# M ---> M
# and ---> and
# a ---> a
# look ---> look
# at ---> at
# BlackFriday ---> BlackFriday
# http ---> http
# That ---> That
# what ---> what
# up ---> up
# What ---> What
# will ---> will
# you ---> you
# play ---> play
# first ---> first
# We ---> We
# looking ---> look
# forward ---> forwar
# to ---> to
# seeing ---> see
# your ---> your
# clips ---> clip
# That ---> That
# a ---> a
# good ---> goo
# problem ---> problem
# to ---> to
# have ---> have
# in ---> in
# our ---> our
# opinions ---> opinion
# D ---> D
# Thanks ---> Thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedicate
# fan ---> fan
# Here ---> Here
# to ---> to
# many ---> many
# more ---> more
# awesome ---> awesome
# gaming ---> gam
# moments ---> moment
# in ---> in
# the ---> the
# future ---> future
# This ---> Thi
# holiday ---> holiday
# make ---> make
# it ---> it
# theirs ---> their
# with ---> with
# an ---> an
# XboxDesignLab ---> XboxDesignLab
# Digital ---> Digital
# Code ---> Code
# Learn ---> Learn
# more ---> more
# at ---> at
# http ---> http
# Cry ---> Cry
# havoc ---> havoc
# and ---> and
# let ---> let
# slip ---> slip
# the ---> the
# huskies ---> huski
# of ---> of
# war ---> war
# Go ---> Go
# Gold ---> Gol
# for ---> for
# and ---> and
# enjoy ---> enjoy
# early ---> early
# access ---> acces
# to ---> to
# this ---> thi
# year ---> year
# Xbox ---> Xbox
# BlackFriday ---> BlackFriday
# savings ---> saving
# Learn ---> Learn
# more ---> more
# http ---> http
# Looks ---> Look
# like ---> like
# Player ---> Player
# has ---> has
# entered ---> entere
# the ---> the
# game ---> game
# We ---> We
# got ---> got
# some ---> some
# extra ---> extra
# deals ---> deal
# coming ---> com
# up ---> up
# next ---> next
# weekend ---> weeken
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# that ---> that
# it ---> it
# such ---> such
# a ---> a
# vivid ---> vivi
# memory ---> memory
# No ---> No
# problem ---> problem
# Everyone ---> Everyone
# getting ---> gett
# excited ---> excite
# for ---> for
# it ---> it
# Design ---> Design
# share ---> share
# and ---> and
# tag ---> tag
# a ---> a
# controller ---> controller
# with ---> with
# XboxDesignLab ---> XboxDesignLab
# and ---> and
# Sweepstakes ---> Sweepstak
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# Rules ---> Rul
# http ---> http
# So ---> So
# fresh ---> fresh
# and ---> and
# so ---> so
# clean ---> clean
# Thanks ---> Thank
# for ---> for
# the ---> the
# love ---> love
# Joe ---> Joe
# That ---> That
# great ---> great
# to ---> to
# hear ---> hear
# Hopefully ---> Hopefully
# you ---> you
# get ---> get
# some ---> some
# epic ---> epic
# games ---> gam
# with ---> with
# the ---> the
# club ---> club
# Got ---> Got
# ta ---> ta
# rep ---> rep
# the ---> the
# Ravens ---> Raven
# Flock ---> Flock
# right ---> right
# Awesome ---> Awesome
# Good ---> Goo
# luck ---> luck
# to ---> to
# you ---> you
# Lindsey ---> Lindsey
# Wishing ---> Wish
# you ---> you
# good ---> goo
# luck ---> luck
# Shawn ---> Shawn
# Nice ---> Nice
# What ---> What
# do ---> do
# you ---> you
# think ---> think
# of ---> of
# it ---> it
# so ---> so
# far ---> far
# We ---> We
# wish ---> wish
# you ---> you
# good ---> goo
# luck ---> luck
# Drew ---> Drew
# It ---> It
# for ---> for
# project ---> project
# Scorpio ---> Scorpio
# They ---> They
# tell ---> tell
# stories ---> stori
# of ---> of
# your ---> your
# time ---> time
# in ---> in
# Tamriel ---> Tamriel
# We ---> We
# already ---> already
# looking ---> look
# forward ---> forwar
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Thanks ---> Thank
# so ---> so
# much ---> much
# We ---> We
# looking ---> look
# forward ---> forwar
# to ---> to
# all ---> all
# the ---> the
# awesome ---> awesome
# stuff ---> stuff
# ahead ---> ahea
# Great ---> Great
# work ---> work
# The ---> The
# gun ---> gun
# looks ---> look
# awesome ---> awesome
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# all ---> all
# set ---> set
# to ---> to
# go ---> go
# Have ---> Have
# fun ---> fun
# We ---> We
# hope ---> hope
# to ---> to
# see ---> see
# you ---> you
# soon ---> soon
# Andrew ---> Andrew
# We ---> We
# wishing ---> wish
# you ---> you
# good ---> goo
# luck ---> luck
# Now ---> Now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# You ---> You
# have ---> have
# great ---> great
# taste ---> taste
# in ---> in
# games ---> gam
# RT ---> RT
# now ---> now
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# an ---> an
# XboxOneS ---> XboxOneS
# Battlefield ---> Battlefiel
# M ---> M
# bundle ---> bundle
# Sweepstakes ---> Sweepstak
# Rules ---> Rul
# http ---> http
# Let ---> Let
# just ---> just
# assume ---> assume
# it ---> it
# all ---> all
# the ---> the
# clips ---> clip
# Awesome ---> Awesome
# work ---> work
# Thanks ---> Thank
# Joe ---> Joe
# Good ---> Goo
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# Sounds ---> Sound
# like ---> like
# you ---> you
# on ---> on
# your ---> your
# way ---> way
# to ---> to
# your ---> your
# dream ---> dream
# We ---> We
# believe ---> believe
# in ---> in
# you ---> you
# There ---> There
# no ---> no
# words ---> word
# that ---> that
# could ---> coul
# describe ---> describe
# our ---> our
# love ---> love
# Good ---> Goo
# plan ---> plan
# Briana ---> Briana
# What ---> What
# are ---> are
# you ---> you
# playing ---> play
# right ---> right
# now ---> now
# And ---> And
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Haden ---> Haden
# Very ---> Very
# nice ---> nice
# Here ---> Here
# to ---> to
# many ---> many
# more ---> more
# rare ---> rare
# achievements ---> achievement
# in ---> in
# the ---> the
# future ---> future
# Awesome ---> Awesome
# Which ---> Which
# achievement ---> achievement
# was ---> was
# it ---> it
# Sounds ---> Sound
# like ---> like
# it ---> it
# about ---> about
# to ---> to
# be ---> be
# an ---> an
# awesome ---> awesome
# birthday ---> birthday
# We ---> We
# glad ---> gla
# you ---> you
# loving ---> lov
# it ---> it
# Joey ---> Joey
# How ---> How
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# It ---> It
# still ---> still
# as ---> as
# beautiful ---> beautiful
# as ---> as
# ever ---> ever
# Sounds ---> Sound
# like ---> like
# a ---> a
# good ---> goo
# day ---> day
# It ---> It
# definitely ---> definitely
# a ---> a
# good ---> goo
# time ---> time
# to ---> to
# be ---> be
# a ---> a
# gamer ---> gamer
# We ---> We
# hear ---> hear
# that ---> that
# At ---> At
# least ---> least
# we ---> we
# on ---> on
# the ---> the
# home ---> home
# stretch ---> stretch
# You ---> You
# ca ---> ca
# help ---> help
# but ---> but
# be ---> be
# holly ---> holly
# and ---> and
# jolly ---> jolly
# Congrats ---> Congrat
# What ---> What
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# play ---> play
# first ---> first
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# having ---> hav
# so ---> so
# much ---> much
# fun ---> fun
# You ---> You
# still ---> still
# got ---> got
# great ---> great
# skills ---> skill
# Dylan ---> Dylan
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# still ---> still
# finding ---> find
# some ---> some
# play ---> play
# time ---> time
# Emmarie ---> Emmarie
# We ---> We
# love ---> love
# that ---> that
# series ---> seri
# That ---> That
# sounds ---> sound
# like ---> like
# a ---> a
# great ---> great
# idea ---> idea
# to ---> to
# us ---> us
# Sometimes ---> Sometim
# you ---> you
# just ---> just
# got ---> got
# to ---> to
# play ---> play
# You ---> You
# got ---> got
# this ---> thi
# There ---> There
# plenty ---> plenty
# of ---> of
# great ---> great
# games ---> gam
# ahead ---> ahea
# to ---> to
# help ---> help
# you ---> you
# out ---> out
# It ---> It
# sure ---> sure
# does ---> do
# Fans ---> Fan
# like ---> like
# you ---> you
# are ---> are
# why ---> why
# we ---> we
# do ---> do
# what ---> what
# we ---> we
# do ---> do
# Right ---> Right
# back ---> back
# at ---> at
# you ---> you
# Nice ---> Nice
# What ---> What
# was ---> was
# your ---> your
# favorite ---> favorite
# game ---> game
# to ---> to
# play ---> play
# Good ---> Goo
# luck ---> luck
# to ---> to
# you ---> you
# BlackFriday ---> BlackFriday
# deals ---> deal
# are ---> are
# coming ---> com
# soon ---> soon
# Get ---> Get
# early ---> early
# access ---> acces
# with ---> with
# XboxLive ---> XboxLive
# Gold ---> Gol
# and ---> and
# learn ---> learn
# more ---> more
# at ---> at
# http ---> http
# Good ---> Goo
# luck ---> luck
# with ---> with
# your ---> your
# new ---> new
# club ---> club
# Thanks ---> Thank
# for ---> for
# the ---> the
# feedback ---> feedback
# Have ---> Have
# fun ---> fun
# with ---> with
# the ---> the
# new ---> new
# features ---> featur
# Have ---> Have
# fun ---> fun
# playing ---> play
# it ---> it
# Unlock ---> Unlock
# the ---> the
# true ---> true
# colors ---> color
# of ---> of
# your ---> your
# games ---> gam
# and ---> and
# entertainment ---> entertainment
# with ---> with
# HDR ---> HDR
# http ---> http
# XboxOneS ---> XboxOneS
# We ---> We
# ca ---> ca
# wait ---> wait
# to ---> to
# share ---> share
# the ---> the
# next ---> next
# years ---> year
# Great ---> Great
# clip ---> clip
# Nice ---> Nice
# shot ---> shot
# It ---> It
# definitely ---> definitely
# worth ---> worth
# writing ---> writ
# home ---> home
# about ---> about
# Now ---> Now
# that ---> that
# one ---> one
# look ---> look
# you ---> you
# can ---> can
# never ---> never
# outgrow ---> outgrow
# Have ---> Have
# fun ---> fun
# Commander ---> Commander
# That ---> That
# the ---> the
# plan ---> plan
# Ryan ---> Ryan
# That ---> That
# must ---> must
# been ---> been
# a ---> a
# very ---> very
# happy ---> happy
# Christmas ---> Christma
# day ---> day
# Making ---> Mak
# great ---> great
# friends ---> friend
# online ---> online
# is ---> is
# definitely ---> definitely
# our ---> our
# favorite ---> favorite
# feature ---> feature
# We ---> We
# ca ---> ca
# wait ---> wait
# for ---> for
# Scorpio ---> Scorpio
# either ---> either
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# your ---> your
# pride ---> pride
# Thanks ---> Thank
# for ---> for
# the ---> the
# birthday ---> birthday
# wishes ---> wish
# Mark ---> Mark
# We ---> We
# just ---> just
# getting ---> gett
# started ---> starte
# It ---> It
# never ---> never
# too ---> too
# late ---> late
# We ---> We
# glad ---> gla
# to ---> to
# have ---> have
# you ---> you
# with ---> with
# us ---> us
# Xbox ---> Xbox
# fans ---> fan
# can ---> can
# be ---> be
# any ---> any
# age ---> age
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# so ---> so
# long ---> long
# Thanks ---> Thank
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesome
# fan ---> fan
# We ---> We
# love ---> love
# you ---> you
# too ---> too
# Thanks ---> Thank
# Eric ---> Eric
# Game ---> Game
# on ---> on
# Sounds ---> Sound
# like ---> like
# an ---> an
# awesome ---> awesome
# club ---> club
# That ---> That
# was ---> was
# an ---> an
# epic ---> epic
# console ---> console
# too ---> too
# Game ---> Game
# on ---> on
# Welcome ---> Welcome
# back ---> back
# Glad ---> Gla
# that ---> that
# it ---> it
# held ---> hel
# such ---> such
# an ---> an
# important ---> important
# place ---> place
# in ---> in
# your ---> your
# life ---> life
# Here ---> Here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# Aww ---> Aww
# thanks ---> thank
# for ---> for
# the ---> the
# love ---> love
# What ---> What
# an ---> an
# awesome ---> awesome
# family ---> family
# portrait ---> portrait
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# it ---> it
# Have ---> Have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Blood ---> Bloo
# Dragon ---> Dragon
# M ---> M
# and ---> and
# Murdered ---> Murdere
# Soul ---> Soul
# Suspect ---> Suspect
# M ---> M
# are ---> are
# now ---> now
# on ---> on
# GamesWithGold ---> GamesWithGol
# Start ---> Start
# playing ---> play
# today ---> today
# http ---> http
# Nice ---> Nice
# to ---> to
# hear ---> hear
# Thanks ---> Thank
# for ---> for
# being ---> be
# such ---> such
# a ---> a
# dedicated ---> dedicate
# fan ---> fan
# That ---> That
# awesome ---> awesome
# Travis ---> Travi
# Sounds ---> Sound
# like ---> like
# you ---> you
# been ---> been
# a ---> a
# fan ---> fan
# for ---> for
# quite ---> quite
# some ---> some
# time ---> time
# Thanks ---> Thank
# for ---> for
# all ---> all
# the ---> the
# awesome ---> awesome
# years ---> year
# of ---> of
# gaming ---> gam
# with ---> with
# us ---> us
# And ---> And
# that ---> that
# you ---> you
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesome
# gamer ---> gamer
# and ---> and
# fan ---> fan
# Canvas ---> Canva
# does ---> do
# matter ---> matter
# without ---> without
# artists ---> artist
# like ---> like
# yourself ---> yourself
# Thanks ---> Thank
# for ---> for
# all ---> all
# your ---> your
# awesome ---> awesome
# work ---> work
# You ---> You
# very ---> very
# welcome ---> welcome
# Have ---> Have
# you ---> you
# set ---> set
# up ---> up
# your ---> your
# own ---> own
# yet ---> yet
# Or ---> Or
# have ---> have
# you ---> you
# found ---> foun
# some ---> some
# fun ---> fun
# ones ---> on
# to ---> to
# join ---> join
# Thanks ---> Thank
# much ---> much
# We ---> We
# so ---> so
# glad ---> gla
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# Thanks ---> Thank
# for ---> for
# the ---> the
# love ---> love
# Aditya ---> Aditya
# It ---> It
# been ---> been
# a ---> a
# wild ---> wil
# ride ---> ride
# Good ---> Goo
# luck ---> luck
# in ---> in
# the ---> the
# contest ---> contest
# The ---> The
# future ---> future
# is ---> is
# bright ---> bright
# Ben ---> Ben
# We ---> We
# glad ---> gla
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# this ---> thi
# time ---> time
# Thanks ---> Thank
# so ---> so
# much ---> much
# Jeff ---> Jeff
# And ---> And
# thank ---> thank
# you ---> you
# Nathan ---> Nathan
# for ---> for
# being ---> be
# an ---> an
# awesome ---> awesome
# gamer ---> gamer
# We ---> We
# wish ---> wish
# you ---> you
# good ---> goo
# luck ---> luck
# We ---> We
# glad ---> gla
# you ---> you
# like ---> like
# it ---> it
# That ---> That
# alright ---> alright
# The ---> The
# party ---> party
# still ---> still
# going ---> go
# Thank ---> Thank
# you ---> you
# LFG ---> LFG
# on ---> on
# XBL ---> XBL
# Our ---> Our
# newest ---> newest
# update ---> update
# lets ---> let
# you ---> you
# search ---> search
# for ---> for
# teammates ---> teammat
# by ---> by
# objective ---> objective
# playstyle ---> playstyle
# and ---> and
# more ---> more
# XboxLive ---> XboxLive
# http ---> http
# They ---> They
# be ---> be
# many ---> many
# more ---> more
# for ---> for
# sure ---> sure
# Jay ---> Jay
# Thanks ---> Thank
# for ---> for
# the ---> the
# greeting ---> greet
# Got ---> Got
# ta ---> ta
# agree ---> agree
# with ---> with
# you ---> you
# there ---> there
# Andrew ---> Andrew
# Here ---> Here
# to ---> to
# years ---> year
# of ---> of
# games ---> gam
# achievements ---> achievement
# friendships ---> friendship
# and ---> and
# memories ---> memori
# Thank ---> Thank
# you ---> you
# Hack ---> Hack
# Everything ---> Everyth
# M ---> M
# comes ---> com
# to ---> to
# XboxOne ---> XboxOne
# today ---> today
# http ---> http
# And ---> And
# we ---> we
# love ---> love
# you ---> you
# right ---> right
# back ---> back
# Totally ---> Totally
# radical ---> radical
# controller ---> controller
# We ---> We
# so ---> so
# thankful ---> thankful
# for ---> for
# fans ---> fan
# like ---> like
# you ---> you
# Anthony ---> Anthony
# What ---> What
# been ---> been
# your ---> your
# favorite ---> favorite
# gaming ---> gam
# moment ---> moment
# It ---> It
# a ---> a
# deathmatch ---> deathmatch
# made ---> made
# in ---> in
# heaven ---> heaven
# Here ---> Here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# RT ---> RT
# and ---> and
# Sweepstakes ---> Sweepstak
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# a ---> a
# Military ---> Military
# Green ---> Green
# XboxOneS ---> XboxOneS
# Battlefield ---> Battlefiel
# bundle ---> bundle
# Rules ---> Rul
# http ---> http
# We ---> We
# looking ---> look
# forward ---> forwar
# to ---> to
# the ---> the
# next ---> next
# From ---> From
# the ---> the
# beginning ---> beginn
# It ---> It
# great ---> great
# to ---> to
# have ---> have
# awesome ---> awesome
# fans ---> fan
# That ---> That
# awesome ---> awesome
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# your ---> your
# memory ---> memory
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# chance ---> chance
# to ---> to
# pick ---> pick
# one ---> one
# up ---> up
# Thanks ---> Thank
# Thanks ---> Thank
# for ---> for
# years ---> year
# of ---> of
# awesomeness ---> awesomenes
# Right ---> Right
# back ---> back
# at ---> at
# you ---> you
# Talan ---> Talan
# Stay ---> Stay
# awesome ---> awesome
# And ---> And
# thank ---> thank
# for ---> for
# being ---> be
# such ---> such
# an ---> an
# awesome ---> awesome
# fan ---> fan
# and ---> and
# gamer ---> gamer
# You ---> You
# know ---> know
# it ---> it
# Here ---> Here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# of ---> of
# Halo ---> Halo
# awesomeness ---> awesomenes
# Which ---> Which
# one ---> one
# did ---> did
# you ---> you
# grow ---> grow
# up ---> up
# with ---> with
# Thanks ---> Thank
# Here ---> Here
# to ---> to
# more ---> more
# That ---> That
# a ---> a
# great ---> great
# story ---> story
# Mac ---> Mac
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# The ---> The
# ride ---> ride
# not ---> not
# over ---> over
# yet ---> yet
# Christian ---> Christian
# A ---> A
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Why ---> Why
# thank ---> thank
# you ---> you
# Daniel ---> Daniel
# Here ---> Here
# to ---> to
# the ---> the
# next ---> next
# years ---> year
# If ---> If
# you ---> you
# like ---> like
# we ---> we
# highly ---> highly
# recommend ---> recommen
# Super ---> Super
# Dungeon ---> Dungeon
# Bros ---> Bro
# and ---> and
# Overcooked ---> Overcooke
# Cheers ---> Cheer
# You ---> You
# have ---> have
# very ---> very
# good ---> goo
# taste ---> taste
# in ---> in
# birthdays ---> birthday
# We ---> We
# definitely ---> definitely
# will ---> will
# You ---> You
# can ---> can
# celebrate ---> celebrate
# by ---> by
# playing ---> play
# some ---> some
# Xbox ---> Xbox
# tonight ---> tonight
# Today ---> Today
# players ---> player
# get ---> get
# a ---> a
# Ford ---> For
# Raptor ---> Raptor
# with ---> with
# livery ---> livery
# new ---> new
# Rivals ---> Rival
# events ---> event
# and ---> and
# more ---> more
# http ---> http
# Thanks ---> Thank
# Rodolfo ---> Rodolfo
# We ---> We
# glad ---> gla
# you ---> you
# kept ---> kept
# it ---> it
# all ---> all
# these ---> these
# years ---> year
# We ---> We
# forever ---> forever
# young ---> young
# Aiden ---> Aiden
# Thanks ---> Thank
# for ---> for
# being ---> be
# a ---> a
# great ---> great
# fan ---> fan
# Time ---> Time
# flies ---> fli
# but ---> but
# the ---> the
# awesome ---> awesome
# memories ---> memori
# are ---> are
# here ---> here
# to ---> to
# stay ---> stay
# We ---> We
# loving ---> lov
# the ---> the
# photo ---> photo
# Keep ---> Keep
# on ---> on
# gaming ---> gam
# and ---> and
# keep ---> keep
# on ---> on
# raging ---> rag
# Hunter ---> Hunter
# It ---> It
# gamers ---> gamer
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# moving ---> mov
# forward ---> forwar
# Thanks ---> Thank
# Zachary ---> Zachary
# A ---> A
# very ---> very
# happy ---> happy
# birthday ---> birthday
# to ---> to
# you ---> you
# Thank ---> Thank
# you ---> you
# Shaun ---> Shaun
# Thanks ---> Thank
# for ---> for
# being ---> be
# part ---> part
# of ---> of
# the ---> the
# team ---> team
# We ---> We
# appreciate ---> appreciate
# it ---> it
# With ---> With
# the ---> the
# best ---> best
# fans ---> fan
# of ---> of
# all ---> all
# time ---> time
# And ---> And
# ...
# rules ---> rul
# http ---> http
# In ---> In
# the ---> the
# last ---> last
# year ---> year
# we ---> we
# added ---> adde
# over ---> over
# games ---> gam
# to ---> to
# BackwardCompatibility ---> BackwardCompatibility
# Which ---> Which
# were ---> were
# your ---> your
# favs ---> fav
# http ---> http
# Tune ---> Tune
# in ---> in
# to ---> to
# see ---> see
# who ---> who
# qualifies ---> qualifi
# for ---> for
# the ---> the
# SMITE ---> SMITE
# T ---> T
# Console ---> Console
# World ---> Worl
# Championship ---> Championship
# http ---> http
# SmitePro ---> SmitePro
# Take ---> Take
# back ---> back
# what ---> what
# yours ---> your
# M ---> M
# is ---> is
# available ---> avail
# now ---> now
# http ---> http
# This ---> Thi
# Week ---> Week
# on ---> on
# Xbox ---> Xbox
# BackwardCompatibility ---> BackwardCompatibility
# turns ---> turn
# one ---> one
# M ---> M
# comes ---> com
# to ---> to
# Xbox ---> Xbox
# and ---> and
# more ---> more
# http ---> http
# We ---> We
# most ---> most
# certainly ---> certainly
# okay ---> okay
# with ---> with
# this ---> thi
# We ---> We
# ca ---> ca
# wait ---> wait
# for ---> for
# December ---> December
# We ---> We
# see ---> see
# if ---> if
# the ---> the
# other ---> other
# Koopa ---> Koopa
# keep ---> keep
# up ---> up
# XboxOne ---> XboxOne
# EASPORTSUFC ---> EASPORTSUFC
# T ---> T
# is ---> is
# now ---> now
# in ---> in
# the ---> the
# EAAccess ---> EAAcces
# Vault ---> Vault
# Get ---> Get
# a ---> a
# round ---> roun
# in ---> in
# http ---> http
# Time ---> Time
# to ---> to
# start ---> start
# marathoning ---> marathon
# in ---> in
# your ---> your
# Batcave ---> Batcave
# XboxOne ---> XboxOne
# Catch ---> Catch
# today ---> today
# T ---> T
# Twitch ---> Twitch
# stream ---> stream
# at ---> at
# PM ---> PM
# PT ---> PT
# PM ---> PM
# ET ---> ET
# Tune ---> Tune
# in ---> in
# at ---> at
# http ---> http
# That ---> That
# always ---> alway
# a ---> a
# great ---> great
# feeling ---> feel
# What ---> What
# games ---> gam
# are ---> are
# you ---> you
# playing ---> play
# You ---> You
# never ---> never
# gon ---> gon
# na ---> na
# have ---> have
# a ---> a
# good ---> goo
# sauce ---> sauce
# again ---> again
# M ---> M
# http ---> http
# Follow ---> Follow
# RT ---> RT
# for ---> for
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# an ---> an
# EAAccess ---> EAAcces
# code ---> code
# MassEffect ---> MassEffect
# M ---> M
# M ---> M
# and ---> and
# M ---> M
# are ---> are
# waiting ---> wait
# http ---> http
# Sweepstakes ---> Sweepstak
# Dishonored ---> Dishonore
# M ---> M
# is ---> is
# live ---> live
# on ---> on
# Twitch ---> Twitch
# Join ---> Join
# the ---> the
# stream ---> stream
# for ---> for
# gameplay ---> gameplay
# chat ---> chat
# and ---> and
# a ---> a
# chance ---> chance
# to ---> to
# win ---> win
# a ---> a
# prize ---> prize
# http ---> http
# STEEP ---> STEEP
# T ---> T
# Early ---> Early
# Access ---> Acces
# beta ---> beta
# is ---> is
# live ---> live
# Watch ---> Watch
# the ---> the
# trailer ---> trailer
# and ---> and
# start ---> start
# your ---> your
# descent ---> descent
# at ---> at
# http ---> http
# The ---> The
# feeling ---> feel
# is ---> is
# mutual ---> mutual
# You ---> You
# welcome ---> welcome
# so ---> so
# much ---> much
# Jennifer ---> Jennifer
# Grab ---> Grab
# your ---> your
# running ---> runn
# gear ---> gear
# MirrorsEdge ---> MirrorsEdge
# T ---> T
# and ---> and
# MirrorsEdgeCatalyst ---> MirrorsEdgeCatalyst
# T ---> T
# are ---> are
# now ---> now
# part ---> part
# of ---> of
# EAAccess ---> EAAcces
# http ---> http
# That ---> That
# great ---> great
# to ---> to
# hear ---> hear
# Will ---> Will
# you ---> you
# be ---> be
# streaming ---> stream
# the ---> the
# game ---> game
# It ---> It
# a ---> a
# very ---> very
# important ---> important
# aspect ---> aspect
# of ---> of
# his ---> his
# character ---> character
# that ---> that
# people ---> people
# must ---> must
# know ---> know
# We ---> We
# know ---> know
# that ---> that
# feeling ---> feel
# Got ---> Got
# your ---> your
# copy ---> copy
# preordered ---> preordere
# yet ---> yet
# Talk ---> Talk
# about ---> about
# a ---> a
# blast ---> blast
# from ---> from
# the ---> the
# past ---> past
# Stay ---> Stay
# awesome ---> awesome
# birthday ---> birthday
# buddy ---> buddy
# As ---> As
# a ---> a
# journalist ---> journalist
# Frank ---> Frank
# is ---> is
# naturally ---> naturally
# witty ---> witty
# He ---> He
# covered ---> covere
# wars ---> war
# you ---> you
# know ---> know
# Glad ---> Gla
# that ---> that
# you ---> you
# liking ---> lik
# what ---> what
# you ---> you
# seeing ---> see
# What ---> What
# part ---> part
# are ---> are
# you ---> you
# most ---> most
# excited ---> excite
# for ---> for
# It ---> It
# not ---> not
# too ---> too
# terrible ---> terrible
# of ---> of
# a ---> a
# problem ---> problem
# to ---> to
# have ---> have
# That ---> That
# because ---> because
# you ---> you
# are ---> are
# Glad ---> Gla
# you ---> you
# think ---> think
# so ---> so
# We ---> We
# guess ---> gues
# you ---> you
# still ---> still
# got ---> got
# the ---> the
# flick ---> flick
# then ---> then
# That ---> That
# awesome ---> awesome
# to ---> to
# hear ---> hear
# You ---> You
# going ---> go
# to ---> to
# have ---> have
# an ---> an
# amazing ---> amaz
# holiday ---> holiday
# season ---> season
# Looking ---> Look
# good ---> goo
# Aaron ---> Aaron
# What ---> What
# game ---> game
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# break ---> break
# it ---> it
# in ---> in
# with ---> with
# Xbox ---> Xbox
# is ---> is
# love ---> love
# It ---> It
# been ---> been
# a ---> a
# great ---> great
# day ---> day
# for ---> for
# Backwards ---> Backward
# Compatibility ---> Compatibility
# D ---> D
# Shoutouts ---> Shoutout
# to ---> to
# your ---> your
# son ---> son
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# The ---> The
# anticipation ---> anticipation
# is ---> is
# already ---> already
# getting ---> gett
# hard ---> har
# to ---> to
# handle ---> handle
# We ---> We
# guessing ---> guess
# someone ---> someone
# excited ---> excite
# The ---> The
# first ---> first
# of ---> of
# many ---> many
# We ---> We
# glad ---> gla
# you ---> you
# like ---> like
# the ---> the
# feature ---> feature
# Thanks ---> Thank
# for ---> for
# the ---> the
# shout ---> shout
# out ---> out
# Woot ---> Woot
# woot ---> woot
# Have ---> Have
# fun ---> fun
# T ---> T
# is ---> is
# now ---> now
# playable ---> play
# on ---> on
# XboxOne ---> XboxOne
# via ---> via
# BackwardCompatibility ---> BackwardCompatibility
# Buy ---> Buy
# it ---> it
# today ---> today
# and ---> and
# save ---> save
# http ---> http
# Happy ---> Happy
# birthday ---> birthday
# in ---> in
# advance ---> advance
# Dear ---> Dear
# Chris ---> Chri
# Thank ---> Thank
# you ---> you
# for ---> for
# taking ---> tak
# the ---> the
# time ---> time
# to ---> to
# slay ---> slay
# bosses ---> boss
# with ---> with
# us ---> us
# It ---> It
# has ---> has
# been ---> been
# too ---> too
# long ---> long
# and ---> and
# we ---> we
# missed ---> misse
# you ---> you
# Love ---> Love
# Xbox ---> Xbox
# We ---> We
# glad ---> gla
# you ---> you
# like ---> like
# it ---> it
# You ---> You
# better ---> better
# believe ---> believe
# it ---> it
# Here ---> Here
# to ---> to
# that ---> that
# birthday ---> birthday
# twin ---> twin
# We ---> We
# hope ---> hope
# you ---> you
# had ---> had
# a ---> a
# great ---> great
# night ---> night
# Great ---> Great
# work ---> work
# Meet ---> Meet
# XboxLive ---> XboxLive
# newest ---> newest
# features ---> featur
# Looking ---> Look
# for ---> for
# Group ---> Group
# and ---> and
# Clubs ---> Club
# http ---> http
# FUS ---> FUS
# RO ---> RO
# MOD ---> MOD
# Skyrim ---> Skyrim
# Special ---> Special
# Edition ---> Edition
# M ---> M
# is ---> is
# now ---> now
# available ---> avail
# and ---> and
# moddable ---> modd
# on ---> on
# XboxOne ---> XboxOne
# http ---> http
# Have ---> Have
# fun ---> fun
# playing ---> play
# it ---> it
# again ---> again
# Playing ---> Play
# games ---> gam
# is ---> is
# a ---> a
# great ---> great
# way ---> way
# to ---> to
# unwind ---> unwin
# We ---> We
# hope ---> hope
# you ---> you
# feel ---> feel
# better ---> better
# afterward ---> afterwar
# Sounds ---> Sound
# like ---> like
# the ---> the
# perfect ---> perfect
# way ---> way
# to ---> to
# unwind ---> unwin
# Fight ---> Fight
# like ---> like
# hell ---> hell
# Intense ---> Intense
# Thanks ---> Thank
# for ---> for
# sharing ---> shar
# the ---> the
# clip ---> clip
# That ---> That
# probably ---> probably
# because ---> because
# it ---> it
# is ---> is
# We ---> We
# know ---> know
# that ---> that
# feeling ---> feel
# well ---> well
# We ---> We
# got ---> got
# your ---> your
# back ---> back
# Very ---> Very
# nice ---> nice
# choice ---> choice
# So ---> So
# much ---> much
# replay ---> replay
# value ---> value
# Great ---> Great
# work ---> work
# Shane ---> Shane
# Keep ---> Keep
# up ---> up
# the ---> the
# good ---> goo
# work ---> work
# What ---> What
# game ---> game
# is ---> is
# up ---> up
# next ---> next
# Good ---> Goo
# call ---> call
# We ---> We
# hope ---> hope
# you ---> you
# have ---> have
# a ---> a
# chance ---> chance
# to ---> to
# pick ---> pick
# it ---> it
# up ---> up
# soon ---> soon
# You ---> You
# welcome ---> welcome
# Are ---> Are
# you ---> you
# going ---> go
# Paragon ---> Paragon
# or ---> or
# Renegade ---> Renegade
# Very ---> Very
# nice ---> nice
# Standby ---> Standby
# for ---> for
# awesomeness ---> awesomenes
# Now ---> Now
# that ---> that
# what ---> what
# we ---> we
# talking ---> talk
# about ---> about
# Absolutely ---> Absolutely
# What ---> What
# games ---> gam
# are ---> are
# you ---> you
# working ---> work
# on ---> on
# We ---> We
# glad ---> gla
# that ---> that
# you ---> you
# enjoying ---> enjoy
# the ---> the
# game ---> game
# Nice ---> Nice
# Have ---> Have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# all ---> all
# of ---> of
# them ---> them
# You ---> You
# know ---> know
# it ---> it
# Have ---> Have
# fun ---> fun
# and ---> and
# good ---> goo
# luck ---> luck
# on ---> on
# your ---> your
# test ---> test
# Now ---> Now
# that ---> that
# what ---> what
# we ---> we
# call ---> call
# an ---> an
# army ---> army
# of ---> of
# two ---> two
# XboxOne ---> XboxOne
# It ---> It
# fans ---> fan
# like ---> like
# you ---> you
# that ---> that
# keep ---> keep
# us ---> us
# going ---> go
# It ---> It
# great ---> great
# seeing ---> see
# those ---> those
# enemies ---> enemi
# just ---> just
# hanging ---> hang
# up ---> up
# there ---> there
# We ---> We
# like ---> like
# the ---> the
# way ---> way
# you ---> you
# think ---> think
# No ---> No
# problem ---> problem
# But ---> But
# with ---> with
# your ---> your
# skill ---> skill
# we ---> we
# think ---> think
# you ---> you
# got ---> got
# this ---> thi
# Game ---> Game
# on ---> on
# Nathan ---> Nathan
# We ---> We
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# videos ---> video
# Awesome ---> Awesome
# Have ---> Have
# you ---> you
# been ---> been
# playing ---> play
# Infinite ---> Infinite
# Warfare ---> Warfare
# Welcome ---> Welcome
# to ---> to
# the ---> the
# Xbox ---> Xbox
# Family ---> Family
# What ---> What
# games ---> gam
# are ---> are
# you ---> you
# going ---> go
# to ---> to
# be ---> be
# playing ---> play
# You ---> You
# have ---> have
# great ---> great
# taste ---> taste
# in ---> in
# games ---> gam
# Leah ---> Leah
# Good ---> Goo
# luck ---> luck
# against ---> against
# the ---> the
# hordes ---> hord
# Alex ---> Alex
# Massive ---> Massive
# You ---> You
# welcome ---> welcome
# Korie ---> Korie
# A ---> A
# good ---> goo
# night ---> night
# indeed ---> indee
# We ---> We
# glad ---> gla
# to ---> to
# hear ---> hear
# you ---> you
# had ---> had
# a ---> a
# blast ---> blast
# There ---> There
# a ---> a
# lot ---> lot
# of ---> of
# stuff ---> stuff
# to ---> to
# take ---> take
# care ---> care
# of ---> of
# in ---> in
# Gotham ---> Gotham
# Good ---> Goo
# luck ---> luck
# We ---> We
# glad ---> gla
# that ---> that
# you ---> you
# love ---> love
# it ---> it
# so ---> so
# much ---> much
# What ---> What
# your ---> your
# favorite ---> favorite
# game ---> game
# to ---> to
# play ---> play
# on ---> on
# it ---> it
# This ---> Thi
# week ---> week
# XboxCharityChallenge ---> XboxCharityChallenge
# throws ---> throw
# back ---> back
# to ---> to
# with ---> with
# Watch ---> Watch
# live ---> live
# now ---> now
# http ---> http
# It ---> It
# nothing ---> noth
# but ---> but
# love ---> love
# here ---> here
# Clifton ---> Clifton
# Stay ---> Stay
# awesome ---> awesome
# Well ---> Well
# the ---> the
# colors ---> color
# do ---> do
# match ---> match
# your ---> your
# avatar ---> avatar
# so ---> so
# we ---> we
# think ---> think
# they ---> they
# cool ---> cool
# Have ---> Have
# a ---> a
# great ---> great
# stream ---> stream
# Nyree ---> Nyree
# Glad ---> Gla
# to ---> to
# hear ---> hear
# it ---> it
# How ---> How
# far ---> far
# have ---> have
# you ---> you
# gotten ---> gotten
# so ---> so
# far ---> far
# It ---> It
# really ---> really
# is ---> is
# worth ---> worth
# it ---> it
# Keith ---> Keith
# Terminal ---> Terminal
# was ---> was
# easily ---> easily
# one ---> one
# of ---> of
# our ---> our
# favorite ---> favorite
# maps ---> map
# You ---> You
# have ---> have
# good ---> goo
# taste ---> taste
# If ---> If
# not ---> not
# you ---> you
# can ---> can
# always ---> alway
# grab ---> grab
# an ---> an
# external ---> external
# hard ---> har
# drive ---> drive
# How ---> How
# are ---> are
# you ---> you
# liking ---> lik
# it ---> it
# so ---> so
# far ---> far
# Nice ---> Nice
# plan ---> plan
# Which ---> Which
# squad ---> squa
# mate ---> mate
# are ---> are
# you ---> you
# looking ---> look
# forward ---> forwar
# to ---> to
# seeing ---> see
# again ---> again
# the ---> the
# most ---> most
# What ---> What
# up ---> up
# Troy ---> Troy
# That ---> That
# an ---> an
# excellent ---> excellent
# option ---> option
# Good ---> Goo
# luck ---> luck
# Breaks ---> Break
# your ---> your
# heart ---> heart
# and ---> and
# forces ---> forc
# a ---> a
# restart ---> restart
# from ---> from
# the ---> the
# beginning ---> beginn
# We ---> We
# also ---> also
# make ---> make
# sure ---> sure
# that ---> that
# it ---> it
# a ---> a
# Suicide ---> Suicide
# Mission ---> Mission
# in ---> in
# name ---> name
# only ---> only
# Mass ---> Mas
# Effect ---> Effect
# and ---> and
# are ---> are
# available ---> avail
# digitally ---> digitally
# through ---> through
# EA ---> EA
# Access ---> Acces
# here ---> here
# Thank ---> Thank
# goodness ---> goodnes
# Whatcha ---> Whatcha
# playing ---> play
# We ---> We
# love ---> love
# Jack ---> Jack
# Though ---> Though
# we ---> we
# ca ---> ca
# really ---> really
# repeat ---> repeat
# any ---> any
# of ---> of
# our ---> our
# favorite ---> favorite
# quotes ---> quot
# though ---> though
# There ---> There
# is ---> is
# an ---> an
# option ---> option
# to ---> to
# go ---> go
# back ---> back
# to ---> to
# Xbox ---> Xbox
# commands ---> command
# You ---> You
# can ---> can
# find ---> fin
# out ---> out
# how ---> how
# here ---> here
# http ---> http
# You ---> You
# mean ---> mean
# that ---> that
# out ---> out
# of ---> of
# all ---> all
# your ---> your
# pinend ---> pinen
# apps ---> app
# it ---> it
# First ---> First
# We ---> We
# love ---> love
# how ---> how
# it ---> it
# brings ---> bring
# people ---> people
# together ---> together
# Say ---> Say
# whattt ---> whattt
# The ---> The
# day ---> day
# not ---> not
# over ---> over
# yet ---> yet
# Now ---> Now
# that ---> that
# sounds ---> sound
# like ---> like
# a ---> a
# plan ---> plan
# We ---> We
# sure ---> sure
# you ---> you
# love ---> love
# it ---> it
# Let ---> Let
# us ---> us
# know ---> know
# what ---> what
# you ---> you
# think ---> think
# Welcome ---> Welcome
# back ---> back
# Michelle ---> Michelle
# It ---> It
# like ---> like
# riding ---> rid
# a ---> a
# bicycle ---> bicycle
# Made ---> Made
# out ---> out
# of ---> of
# guns ---> gun
# Sounds ---> Sound
# like ---> like
# a ---> a
# Monday ---> Monday
# well ---> well
# spent ---> spent
# to ---> to
# us ---> us
# We ---> We
# applaud ---> applau
# his ---> his
# dedication ---> dedication
# Epic ---> Epic
# clip ---> clip
# We ---> We
# ca ---> ca
# wait ---> wait
# to ---> to
# see ---> see
# more ---> more
# Have ---> Have
# a ---> a
# great ---> great
# time ---> time
# playing ---> play
# through ---> through
# them ---> them
# Thanks ---> Thank
# Jon ---> Jon
# Will ---> Will
# you ---> you
# be ---> be
# playing ---> play
# Mass ---> Mas
# Effect ---> Effect
# soon ---> soon
# A ---> A
# great ---> great
# day ---> day
# indeed ---> indee
# Are ---> Are
# you ---> you
# playing ---> play
# Mass ---> Mas
# Effect ---> Effect
# right ---> right
# now ---> now
# Incredible ---> Incredible
# Your ---> Your
# gamerscore ---> gamerscore
# must ---> must
# be ---> be
# crazy ---> crazy
# Awesome ---> Awesome
# What ---> What
# game ---> game
# were ---> were
# you ---> you
# streaming ---> stream
# And ---> And
# then ---> then
# we ---> we
# responded ---> responde
# on ---> on
# yours ---> your
# Everyone ---> Everyone
# can ---> can
# enjoy ---> enjoy
# Xbox ---> Xbox
# But ---> But
# it ---> it
# great ---> great
# to ---> to
# hear ---> hear
# that ---> that
# we ---> we
# can ---> can
# bring ---> br
# generations ---> generation
# together ---> together
# Someone ---> Someone
# in ---> in
# for ---> for
# a ---> a
# very ---> very
# bad ---> bad
# day ---> day
# She ---> She
# looks ---> look
# like ---> like
# a ---> a
# serious ---> seriou
# piece ---> piece
# of ---> of
# hardware ---> hardware
# Mel ---> Mel
